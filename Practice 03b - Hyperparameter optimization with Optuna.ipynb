# %% [markdown]
# `Notebook last edit: 2023/24`

# %% [markdown]
# # Recommender Systems 2026/27
#
# ### Practice 3b - Hyperparameter optimization with Optuna
#
# ### Hyperparameter optimization is essential to achieve the best recommendation quality!!

# %% [markdown]
# ## How does it work
# * Split the data in training, validation and test. Ensure that the distribution of the three sets is similar (e.g., the validation data you use should be split with the same approach used for the test data; if you know the test data contains cold items or users, ensure the validation data does too...)
# * Choose a recommender model, identify its hyperparameters and choose a value range and distribution for each.
# * Select a hyperparameter configuration and fit your model using the training data. Evaluate it using the validation data.
# * Repeat the previous step by exploring many possible hyperparameter configurations. Several exploration strategies are possible.
# * Select the hyperparameter configuration with the best recommendation quality on the validation data. Use that configuration to fit the model on the union of training and validation data. Evaluate the final model on the test data and report that result (or submit to the course challenge).
#
# Using directly or indirectly any information on the composition of the test data at any stage of the training or optimization process will result in *information leakage* and cause you to overestimate the quality of your model.
#
#
#
# ## Hyperparameter optimization strategies
#
# ### Grid-search
# For each hyperparameter define a list of possible values, then explore *all* possible combinations. For example, in a KNN using tversky similarity you could choose these values:
# * number of neighbors: [10, 50, 100, 150, 200, 250]
# * shrink term: [0, 10, 20, 50, 100]
# * alpha: [0.1, 0.3, 0.5, 0.7, 0.9, 1.1, 1.3, 1.5]
# * beta: [0.1, 0.3, 0.5, 0.7, 0.9, 1.1, 1.3, 1.5]
#
# You end up with *1920* possible hyperparameter configurations. Furthermore, you cannot easily fine-tune. Say that you found the optimal number of neighbors is 200, but in that area of the search space you were using a step of 50. What if there is an even better result at 215? You have to define a *new* hyperparameter range around the optimal one you found and use a smaller step, e.g., [180, 190, 200, 210, 220] and so on.
#
# Overall, grid-search is very sensitive to the range and distribution you choose, very rigid, and often unpractically slow due to how the number of cases grows combinatorially. It has been known for more than 20 years that it is generally a bad idea.
#
# ### Random-search
# In a random search you define the range and distribution of possible values, and then you pick at random from it each hyperparameter configuration you explore.
# For example, in a KNN using tversky similarity you could choose these values:
# * number of neighbors: uniform random from 10 to 500
# * shrink term: uniform random from 0 to 500
# * alpha: uniform random from 0.1 to 1.5
# * beta: uniform random from 0.1 to 1.5
#
# It is very parallelizable and effective (definitely better than Grid-search if you do not wish to fine-tune manually).
#
#
# ### Bayesian-search
# More advanced strategy that uses a gaussian process to try to model the interdependencies between hyperparameters based on how they affect the result. It contains a part of random search where the search space is explored, then a second part that uses the gaussian process to choose the next hyperparameter configuration. It combines exploration with exploitation.
#
# Bayesian-search is less parallelizable (the gaussian process is sequential) but has a good exploration-exploitation tradeoff. It is the strategy used in our research activity.
#
#
# ### Other strategies
# There is no shortage of hyperparameter optimization strategies, for example the Tree-Structured Parzen Estimator with Optuna (in this notebook), as well as techniques that use previous optimization runs to attempt transfer learning between models and datasets. All those are beyond the scope of the course.
#
#
#
# ### In the course repository you will find a BayesianSearch object in the HyperparameterTuning folder. That is a simple wrapper of another library and its purpose is to provide a very simple way to tune some of the most common hyperparameters.
#
#
#
#
# ## Hyperparameter sensitivity
#
# One of the most important problems you encounter when doing hyperparameter tuning is how to select the range and distribution of the hyperparameters. There is no universal rule and some of those decisions are based on experience. Generally the suggestions we can give you are:
# * Keep the search space on the larger side, better have more room to manouver than less.
# * Hyperparameters like the number of neighbors, the shrink term, the number of latent dimensions of matrix factorization models etc. work well with a uniform random distribution
# * Hyperparameters like the learning rate and l1 l2 regularizations work better with a log-uniform distribution as the training tends to be affected by the orders of magnitude rather than the absolute values. You need to be able to explore maybe from 10^-9 to 10^-3, while the difference between 2\*10^-3 or 1.5\*10^-3 will be negligible.
#
# ### In the course repository you will find a script called run_hyperparameter_search that contains a list of commonly used hyperparameters with the corresponding range and distribution.
#
# ### Hint: If you see that the optimization yields a hyperparameter that has a value at either end of the range (min or max) this may indicate that in that scenario you need to expand the search space.
#
#
#
# ## Early-stopping
#
# A special hyperparameter is the number of epochs you should train a machine learning model for.
# It is possible to put this number as a hyperparameter, but that is not a super-effective strategy. A common strategy is *early-stopping*. It works as follows:
# * Select a maximum number of epochs, say 500
# * Train the model for a certain number of epochs, say 5
# * Evaluate the recommendation quality of the model on the validation data. Create a clone of the model.
# * Continue training and evaluate the model periodically. Every time you find a better recommendation quality update the model clone, which will then represent the "best" model you have.
# * If the recommendation quality does not improve for a certain number of consecutive validation steps, say 5, stop the training. If you reach the maximum number of epochs, stop the training.
# * Use the "best" model clone to generate the recommendations on the validation data.
# * When you train the model on the union of training and validation data, use the optimal number of epochs selected by the early-stopping at the previous step.
#
# Usually early-stopping allows to save a lot of computational time and fine-tune the optimal number of epochs, unless the validation step takes a very large amount of time. In those cases, it can be better to either use early-stopping on the algorithm loss function (which is however a different problem then recommendation and does not guarantee you that the best absolute loss will correspond to the model with the best recommendation quality) or just select the number of epochs as any other hyperparameter.

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Data_manager.Movielens.Movielens1MReader import Movielens1MReader

data_reader = Movielens1MReader()
data_loaded = data_reader.load_data()

URM_all = data_loaded.get_URM_all()
ICM_all = data_loaded.get_ICM_from_name("ICM_genres")
# Out:
# Movielens1M: Verifying data consistency...
# Movielens1M: Verifying data consistency... Passed!
# DataReader: current dataset is: Movielens1M
# 	Number of items: 3883
# 	Number of users: 6040
# 	Number of interactions in URM_all: 1000209
# 	Value range in URM_all: 1.00-5.00
# 	Interaction density: 4.26E-02
# 	Interactions per user:
# 		 Min: 2.00E+01
# 		 Avg: 1.66E+02
# 		 Max: 2.31E+03
# 	Interactions per item:
# 		 Min: 0.00E+00
# 		 Avg: 2.58E+02
# 		 Max: 3.43E+03
# 	Gini Index: 0.53
#
# 	ICM name: ICM_genres, Value range: 1.00 / 1.00, Num features: 18, feature occurrences: 6408, density 9.17E-02
# 	ICM name: ICM_year, Value range: 1.92E+03 / 2.00E+03, Num features: 1, feature occurrences: 3883, density 1.00E+00
#
#
# 	UCM name: UCM_all, Value range: 1.00 / 1.00, Num features: 3469, feature occurrences: 24160, density 1.15E-03

# %% [markdown]
# ### How do we perform hyperparameter optimization?
# * Split the data in three *disjoint* sets: training, validation and testing data
# * Define a set of hyperparameters with the range and distribution
# * Explore hyperparameter space and select those with the best recommendation quality on the *validation* data (including the number of epochs for ML algorithms)
# * Given the best hyperparameters, fit the model again using the union of training and validation data.
# * Evaluate this last model on the testing data.

# %% [markdown]
# ### Step 1: Split the data and create the evaluator objects

# %%
from Evaluation.Evaluator import EvaluatorHoldout

URM_train_validation, URM_test = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.8)
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_train_validation, train_percentage = 0.8)

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=[10])
# Out:
# Warning: 2 (0.03 %) of 6040 users have no sampled items
# Warning: 11 (0.18 %) of 6040 users have no sampled items
# EvaluatorHoldout: Ignoring 11 ( 0.2%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 2 ( 0.0%) Users that have less than 1 test interactions

# %% [markdown]
# ### Step 2: Define the objective function that will be run by the optimizer
#
# The obective function should:
# * Use the optuna trial instance to acquire the hyperparameter values required
# * Fit the model
# * Evaluate on the validation and return the result of a desired metric

# %%
import optuna
import pandas as pd
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender

def objective_function(optuna_trial):
    
    recommender_instance = ItemKNNCFRecommender(URM_train)
    recommender_instance.fit(topK = optuna_trial.suggest_int("topK", 5, 1000),
                             shrink = optuna_trial.suggest_int("shrink", 0, 1000),
                             similarity = "cosine",
                             normalize = optuna_trial.suggest_categorical("normalize", [True, False])
                            )
    
    result_df, _ = evaluator_validation.evaluateRecommender(recommender_instance)
    
    return result_df.loc[10]["MAP"]

# %% [markdown]
# ### Step 3: Create an object/function that will be called after every call of the objective function to log the results in a dataframe for easier readability

# %%
class SaveResults(object):
    
    def __init__(self):
        self.results_df = pd.DataFrame(columns = ["result"])
    
    def __call__(self, optuna_study, optuna_trial):
        hyperparam_dict = optuna_trial.params.copy()
        hyperparam_dict["result"] = optuna_trial.values[0]
        
        self.results_df = self.results_df.append(hyperparam_dict, ignore_index=True)

# %% [markdown]
# ### Step 4: Create an optuna Study and run

# %%
optuna_study = optuna.create_study(direction="maximize")
        
save_results = SaveResults()
        
optuna_study.optimize(objective_function,
                      callbacks=[save_results],
                      n_trials = 50)
# Out:
# [I 2023-11-24 14:49:20,393] A new study created in memory with name: no-name-78083e1f-ee00-451d-ac32-379d3d1f388e
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 3910.53 column/sec. Elapsed time 0.99 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.48 sec. Users per second: 1100
# [I 2023-11-24 14:49:27,014] Trial 0 finished with value: 0.07222996917017498 and parameters: {'topK': 574, 'shrink': 583, 'normalize': False}. Best is trial 0 with value: 0.07222996917017498.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4211.31 column/sec. Elapsed time 0.92 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.28 sec. Users per second: 1141
# [I 2023-11-24 14:49:33,374] Trial 1 finished with value: 0.1015801009406914 and parameters: {'topK': 719, 'shrink': 916, 'normalize': True}. Best is trial 1 with value: 0.1015801009406914.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4197.62 column/sec. Elapsed time 0.93 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.50 sec. Users per second: 1096
# [I 2023-11-24 14:49:39,954] Trial 2 finished with value: 0.10312860196879094 and parameters: {'topK': 700, 'shrink': 305, 'normalize': True}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4572.72 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.13 sec. Users per second: 1176
# [I 2023-11-24 14:49:46,056] Trial 3 finished with value: 0.0723865931068619 and parameters: {'topK': 594, 'shrink': 475, 'normalize': False}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4472.81 column/sec. Elapsed time 0.87 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.50 sec. Users per second: 1097
# [I 2023-11-24 14:49:52,525] Trial 4 finished with value: 0.07184863108731104 and parameters: {'topK': 676, 'shrink': 313, 'normalize': False}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4457.22 column/sec. Elapsed time 0.87 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.45 sec. Users per second: 1106
# [I 2023-11-24 14:49:58,982] Trial 5 finished with value: 0.07129649814257569 and parameters: {'topK': 783, 'shrink': 573, 'normalize': False}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4459.89 column/sec. Elapsed time 0.87 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.48 sec. Users per second: 1101
# [I 2023-11-24 14:50:05,458] Trial 6 finished with value: 0.07126389777451335 and parameters: {'topK': 830, 'shrink': 387, 'normalize': False}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4605.78 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.47 sec. Users per second: 1350
# [I 2023-11-24 14:50:10,846] Trial 7 finished with value: 0.07527343369481414 and parameters: {'topK': 271, 'shrink': 386, 'normalize': False}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4534.00 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.09 sec. Users per second: 1475
# [I 2023-11-24 14:50:15,860] Trial 8 finished with value: 0.07799867439650184 and parameters: {'topK': 131, 'shrink': 211, 'normalize': False}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4302.67 column/sec. Elapsed time 0.90 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.14 sec. Users per second: 1174
# [I 2023-11-24 14:50:21,990] Trial 9 finished with value: 0.07231918741953591 and parameters: {'topK': 584, 'shrink': 602, 'normalize': False}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4378.38 column/sec. Elapsed time 0.89 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.30 sec. Users per second: 1138
# [I 2023-11-24 14:50:28,356] Trial 10 finished with value: 0.1017865831023068 and parameters: {'topK': 991, 'shrink': 5, 'normalize': True}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4406.45 column/sec. Elapsed time 0.88 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.27 sec. Users per second: 1143
# [I 2023-11-24 14:50:34,689] Trial 11 finished with value: 0.10190535427971151 and parameters: {'topK': 950, 'shrink': 36, 'normalize': True}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4461.82 column/sec. Elapsed time 0.87 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.23 sec. Users per second: 1154
# [I 2023-11-24 14:50:40,958] Trial 12 finished with value: 0.10171844681920977 and parameters: {'topK': 998, 'shrink': 5, 'normalize': True}. Best is trial 2 with value: 0.10312860196879094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4607.32 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.43 sec. Users per second: 1360
# [I 2023-11-24 14:50:46,332] Trial 13 finished with value: 0.10548245648676875 and parameters: {'topK': 383, 'shrink': 166, 'normalize': True}. Best is trial 13 with value: 0.10548245648676875.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4623.93 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.47 sec. Users per second: 1350
# [I 2023-11-24 14:50:51,743] Trial 14 finished with value: 0.10563397941694438 and parameters: {'topK': 418, 'shrink': 143, 'normalize': True}. Best is trial 14 with value: 0.10563397941694438.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4654.45 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.44 sec. Users per second: 1357
# [I 2023-11-24 14:50:57,128] Trial 15 finished with value: 0.10562194104157906 and parameters: {'topK': 407, 'shrink': 150, 'normalize': True}. Best is trial 14 with value: 0.10563397941694438.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4521.32 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.47 sec. Users per second: 1348
# [I 2023-11-24 14:51:02,552] Trial 16 finished with value: 0.10524914632187776 and parameters: {'topK': 434, 'shrink': 163, 'normalize': True}. Best is trial 14 with value: 0.10563397941694438.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4622.67 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.33 sec. Users per second: 1392
# [I 2023-11-24 14:51:07,803] Trial 17 finished with value: 0.10575506743859676 and parameters: {'topK': 275, 'shrink': 765, 'normalize': True}. Best is trial 17 with value: 0.10575506743859676.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4666.24 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.57 sec. Users per second: 1689
# [I 2023-11-24 14:51:12,267] Trial 18 finished with value: 0.09783875948787218 and parameters: {'topK': 33, 'shrink': 805, 'normalize': True}. Best is trial 17 with value: 0.10575506743859676.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4623.94 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.30 sec. Users per second: 1402
# [I 2023-11-24 14:51:17,499] Trial 19 finished with value: 0.10583355711942499 and parameters: {'topK': 263, 'shrink': 714, 'normalize': True}. Best is trial 19 with value: 0.10583355711942499.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4625.01 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.27 sec. Users per second: 1413
# [I 2023-11-24 14:51:22,689] Trial 20 finished with value: 0.10546839087268675 and parameters: {'topK': 241, 'shrink': 751, 'normalize': True}. Best is trial 19 with value: 0.10583355711942499.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4462.22 column/sec. Elapsed time 0.87 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.34 sec. Users per second: 1389
# [I 2023-11-24 14:51:27,974] Trial 21 finished with value: 0.10573886927469561 and parameters: {'topK': 279, 'shrink': 743, 'normalize': True}. Best is trial 19 with value: 0.10583355711942499.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4478.73 column/sec. Elapsed time 0.87 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.34 sec. Users per second: 1389
# [I 2023-11-24 14:51:33,262] Trial 22 finished with value: 0.10582523096041058 and parameters: {'topK': 264, 'shrink': 728, 'normalize': True}. Best is trial 19 with value: 0.10583355711942499.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4611.29 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.05 sec. Users per second: 1490
# [I 2023-11-24 14:51:38,231] Trial 23 finished with value: 0.10509366106148292 and parameters: {'topK': 158, 'shrink': 981, 'normalize': True}. Best is trial 19 with value: 0.10583355711942499.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4526.08 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.42 sec. Users per second: 1364
# [I 2023-11-24 14:51:43,591] Trial 24 finished with value: 0.10512206873129079 and parameters: {'topK': 320, 'shrink': 687, 'normalize': True}. Best is trial 19 with value: 0.10583355711942499.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4660.42 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.99 sec. Users per second: 1512
# [I 2023-11-24 14:51:48,507] Trial 25 finished with value: 0.1059460293765314 and parameters: {'topK': 142, 'shrink': 848, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4404.73 column/sec. Elapsed time 0.88 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.59 sec. Users per second: 1679
# [I 2023-11-24 14:51:53,046] Trial 26 finished with value: 0.09774291980296268 and parameters: {'topK': 34, 'shrink': 886, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4541.13 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.06 sec. Users per second: 1486
# [I 2023-11-24 14:51:58,044] Trial 27 finished with value: 0.1051055414701954 and parameters: {'topK': 154, 'shrink': 863, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4666.01 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.11 sec. Users per second: 1468
# [I 2023-11-24 14:52:03,062] Trial 28 finished with value: 0.10522734692373084 and parameters: {'topK': 194, 'shrink': 667, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4670.74 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.93 sec. Users per second: 1532
# [I 2023-11-24 14:52:07,906] Trial 29 finished with value: 0.10338423150539565 and parameters: {'topK': 95, 'shrink': 998, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4531.89 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.74 sec. Users per second: 1273
# [I 2023-11-24 14:52:13,614] Trial 30 finished with value: 0.10430962648784849 and parameters: {'topK': 502, 'shrink': 553, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4652.92 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.46 sec. Users per second: 1351
# [I 2023-11-24 14:52:19,016] Trial 31 finished with value: 0.10455076258401828 and parameters: {'topK': 337, 'shrink': 839, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4568.09 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.18 sec. Users per second: 1443
# [I 2023-11-24 14:52:24,124] Trial 32 finished with value: 0.1057183007000554 and parameters: {'topK': 219, 'shrink': 743, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4747.51 column/sec. Elapsed time 0.82 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.84 sec. Users per second: 1571
# [I 2023-11-24 14:52:28,845] Trial 33 finished with value: 0.10326719796117673 and parameters: {'topK': 87, 'shrink': 665, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4624.06 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.55 sec. Users per second: 1325
# [I 2023-11-24 14:52:34,341] Trial 34 finished with value: 0.10532529941262686 and parameters: {'topK': 358, 'shrink': 802, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4596.85 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.71 sec. Users per second: 1281
# [I 2023-11-24 14:52:40,009] Trial 35 finished with value: 0.10460481350720217 and parameters: {'topK': 461, 'shrink': 931, 'normalize': True}. Best is trial 25 with value: 0.1059460293765314.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4613.11 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.28 sec. Users per second: 1409
# [I 2023-11-24 14:52:45,231] Trial 36 finished with value: 0.10600708348800839 and parameters: {'topK': 267, 'shrink': 623, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4611.98 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.79 sec. Users per second: 1260
# [I 2023-11-24 14:52:50,981] Trial 37 finished with value: 0.10421366174600545 and parameters: {'topK': 519, 'shrink': 471, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4752.16 column/sec. Elapsed time 0.82 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.42 sec. Users per second: 1765
# [I 2023-11-24 14:52:55,279] Trial 38 finished with value: 0.06904514423671847 and parameters: {'topK': 5, 'shrink': 619, 'normalize': False}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4635.49 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.12 sec. Users per second: 1464
# [I 2023-11-24 14:53:00,324] Trial 39 finished with value: 0.10531233956511746 and parameters: {'topK': 199, 'shrink': 521, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4560.97 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.16 sec. Users per second: 1169
# [I 2023-11-24 14:53:06,462] Trial 40 finished with value: 0.0719965602761259 and parameters: {'topK': 646, 'shrink': 694, 'normalize': False}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4663.16 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.40 sec. Users per second: 1371
# [I 2023-11-24 14:53:11,780] Trial 41 finished with value: 0.10549555455509962 and parameters: {'topK': 292, 'shrink': 796, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4600.00 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.22 sec. Users per second: 1429
# [I 2023-11-24 14:53:16,940] Trial 42 finished with value: 0.10552480471372502 and parameters: {'topK': 240, 'shrink': 636, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4613.15 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.89 sec. Users per second: 1552
# [I 2023-11-24 14:53:21,748] Trial 43 finished with value: 0.1040061133094802 and parameters: {'topK': 105, 'shrink': 923, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4606.24 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.38 sec. Users per second: 1377
# [I 2023-11-24 14:53:27,061] Trial 44 finished with value: 0.10533072951633214 and parameters: {'topK': 318, 'shrink': 716, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4609.19 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.37 sec. Users per second: 1379
# [I 2023-11-24 14:53:32,364] Trial 45 finished with value: 0.07546159830659782 and parameters: {'topK': 251, 'shrink': 784, 'normalize': False}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4658.88 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.06 sec. Users per second: 1484
# [I 2023-11-24 14:53:37,341] Trial 46 finished with value: 0.1048450478770601 and parameters: {'topK': 185, 'shrink': 479, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4713.44 column/sec. Elapsed time 0.82 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.95 sec. Users per second: 1528
# [I 2023-11-24 14:53:42,196] Trial 47 finished with value: 0.10416253320590672 and parameters: {'topK': 125, 'shrink': 836, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4602.64 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.49 sec. Users per second: 1342
# [I 2023-11-24 14:53:47,620] Trial 48 finished with value: 0.07521922480497734 and parameters: {'topK': 297, 'shrink': 577, 'normalize': False}. Best is trial 36 with value: 0.10600708348800839.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4671.51 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.83 sec. Users per second: 1576
# [I 2023-11-24 14:53:52,353] Trial 49 finished with value: 0.10142025185150028 and parameters: {'topK': 63, 'shrink': 639, 'normalize': True}. Best is trial 36 with value: 0.10600708348800839.

# %% [markdown]
# ### Step 3: Given the best hyperparameters, train on the union of URM_train and validation, to evaluate on test

# %%
pruned_trials = [t for t in optuna_study.trials if t.state == optuna.trial.TrialState.PRUNED]
complete_trials = [t for t in optuna_study.trials if t.state == optuna.trial.TrialState.COMPLETE]

print("Study statistics: ")
print("  Number of finished trials: ", len(optuna_study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
print("  Value Validation: ", optuna_study.best_trial.value)
# Out:
# Study statistics:
#   Number of finished trials:  50
#   Number of pruned trials:  0
#   Number of complete trials:  50
# Best trial:
#   Value Validation:  0.10600708348800839

# %%
optuna_study.best_trial
# Out:
# FrozenTrial(number=36, state=TrialState.COMPLETE, values=[0.10600708348800839], datetime_start=datetime.datetime(2023, 11, 24, 14, 52, 40, 19594), datetime_complete=datetime.datetime(2023, 11, 24, 14, 52, 45, 231897), params={'topK': 267, 'shrink': 623, 'normalize': True}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'topK': IntDistribution(high=1000, log=False, low=5, step=1), 'shrink': IntDistribution(high=1000, log=False, low=0, step=1), 'normalize': CategoricalDistribution(choices=(True, False))}, trial_id=36, value=None)

# %%
optuna_study.best_trial.params
# Out:
# {'topK': 267, 'shrink': 623, 'normalize': True}

# %%
save_results.results_df
# Out:
#       result  normalize  shrink   topK
# 0   0.072230        0.0   583.0  574.0
# 1   0.101580        1.0   916.0  719.0
# 2   0.103129        1.0   305.0  700.0
# 3   0.072387        0.0   475.0  594.0
# 4   0.071849        0.0   313.0  676.0
# 5   0.071296        0.0   573.0  783.0
# 6   0.071264        0.0   387.0  830.0
# 7   0.075273        0.0   386.0  271.0
# 8   0.077999        0.0   211.0  131.0
# 9   0.072319        0.0   602.0  584.0
# 10  0.101787        1.0     5.0  991.0
# 11  0.101905        1.0    36.0  950.0
# 12  0.101718        1.0     5.0  998.0
# 13  0.105482        1.0   166.0  383.0
# 14  0.105634        1.0   143.0  418.0
# 15  0.105622        1.0   150.0  407.0
# 16  0.105249        1.0   163.0  434.0
# 17  0.105755        1.0   765.0  275.0
# 18  0.097839        1.0   805.0   33.0
# 19  0.105834        1.0   714.0  263.0
# 20  0.105468        1.0   751.0  241.0
# 21  0.105739        1.0   743.0  279.0
# 22  0.105825        1.0   728.0  264.0
# 23  0.105094        1.0   981.0  158.0
# 24  0.105122        1.0   687.0  320.0
# 25  0.105946        1.0   848.0  142.0
# 26  0.097743        1.0   886.0   34.0
# 27  0.105106        1.0   863.0  154.0
# 28  0.105227        1.0   667.0  194.0
# 29  0.103384        1.0   998.0   95.0
# 30  0.104310        1.0   553.0  502.0
# 31  0.104551        1.0   839.0  337.0
# 32  0.105718        1.0   743.0  219.0
# 33  0.103267        1.0   665.0   87.0
# 34  0.105325        1.0   802.0  358.0
# 35  0.104605        1.0   931.0  461.0
# 36  0.106007        1.0   623.0  267.0
# 37  0.104214        1.0   471.0  519.0
# 38  0.069045        0.0   619.0    5.0
# 39  0.105312        1.0   521.0  199.0
# 40  0.071997        0.0   694.0  646.0
# 41  0.105496        1.0   796.0  292.0
# 42  0.105525        1.0   636.0  240.0
# 43  0.104006        1.0   923.0  105.0
# 44  0.105331        1.0   716.0  318.0
# 45  0.075462        0.0   784.0  251.0
# 46  0.104845        1.0   479.0  185.0
# 47  0.104163        1.0   836.0  125.0
# 48  0.075219        0.0   577.0  297.0
# 49  0.101420        1.0   639.0   63.0

# %%
recommender_instance = ItemKNNCFRecommender(URM_train + URM_validation)
recommender_instance.fit(**optuna_study.best_trial.params)

result_df, _ = evaluator_test.evaluateRecommender(recommender_instance)
result_df
# Out:
# ItemKNNCFRecommender: URM Detected 204 ( 5.3%) items with no interactions.
# Similarity column 3883 (100.0%), 3372.80 column/sec. Elapsed time 1.15 sec
# EvaluatorHoldout: Processed 6038 (100.0%) in 4.66 sec. Users per second: 1295
#        PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.332295                 0.354219  0.146567  0.240715    0.251668
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.612097  0.302554  0.203414  0.875455      1.149056  ...
#
#        COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
# cutoff
# 10          0.999669          0.875166    0.999669       0.044333
#
#        SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
# cutoff
# 10            7.775025                   0.993044             0.126745
#
#        RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
# cutoff
# 10                  0.719014                 1.854436      0.064835
#
# [1 rows x 27 columns]

# %% [markdown]
# ### Hint. You can train a regressor to use the hyperparameter values to estimate the model results. This will give you a rough indication of which are the most important hyperparameters.

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

def _feature_importance(result_df):

    regr = RandomForestRegressor(max_depth=2)

    result_df = result_df.copy()
    result_df = (result_df - result_df.mean())/(result_df.std() +1e-6)

    y_train = result_df["result"]
    X_train = result_df.copy()
    X_train = X_train.drop(columns=["result"])

    regr.fit(X_train, y_train)
    
    plt.bar(X_train.columns, regr.feature_importances_)
    plt.show()

# %%
_feature_importance(save_results.results_df)

# %% [markdown]
# In this case the normalize hyperparameter is super important, indeed we have good results only when normalize=True, the other two are less important.
#
# If we isolate only the cases when normalize=True, we can see that the second most important hyperparameter is topk by a lot

# %%
results_df = save_results.results_df.copy()
results_df = results_df[results_df["normalize"]==1.0]
results_df = results_df.drop(["normalize"], axis=1)

_feature_importance(results_df)

# %% [markdown]
# ### Optuna supports various tools such as a database to store the results which can be used for nice visualizations, try them!
#
#
# Optuna also supports conditional hyperparameters, which may be required only based on another hyperparameter value. In the following function several similarity heuristics are optimized.

# %%
def objective_function_KNN_similarities(optuna_trial):
    
    recommender_instance = ItemKNNCFRecommender(URM_train)
    similarity = optuna_trial.suggest_categorical("similarity", ['cosine', 'dice', 'jaccard', 'asymmetric', 'tversky', 'euclidean'])
    
    full_hyperp = {"similarity": similarity,
                   "topK": optuna_trial.suggest_int("topK", 5, 1000),
                   "shrink": optuna_trial.suggest_int("shrink", 0, 1000),
                  }
    
    if similarity == "asymmetric":
        full_hyperp["asymmetric_alpha"] = optuna_trial.suggest_float("asymmetric_alpha", 0, 2, log=False)
        full_hyperp["normalize"] = True     

    elif similarity == "tversky":
        full_hyperp["tversky_alpha"] = optuna_trial.suggest_float("tversky_alpha", 0, 2, log=False)
        full_hyperp["tversky_beta"] = optuna_trial.suggest_float("tversky_beta", 0, 2, log=False)
        full_hyperp["normalize"] = True 

    elif similarity == "euclidean":
        full_hyperp["normalize_avg_row"] = optuna_trial.suggest_categorical("normalize_avg_row", [True, False])
        full_hyperp["similarity_from_distance_mode"] = optuna_trial.suggest_categorical("similarity_from_distance_mode", ["lin", "log", "exp"])
        full_hyperp["normalize"] = optuna_trial.suggest_categorical("normalize", [True, False])
        
    
    recommender_instance.fit(**full_hyperp)
    
    result_df, _ = evaluator_validation.evaluateRecommender(recommender_instance)
    
    return result_df.loc[10]["MAP"]

# %%
optuna_study = optuna.create_study(direction="maximize")
        
save_results = SaveResults()
        
optuna_study.optimize(objective_function_KNN_similarities,
                      callbacks=[save_results],
                      n_trials = 50)
# Out:
# [I 2023-11-24 14:54:00,173] A new study created in memory with name: no-name-ab6c298f-1c35-4e58-9704-71753054dbdc
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4747.50 column/sec. Elapsed time 0.82 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.20 sec. Users per second: 1436
# [I 2023-11-24 14:54:05,299] Trial 0 finished with value: 0.09180638817145713 and parameters: {'similarity': 'tversky', 'topK': 111, 'shrink': 884, 'tversky_alpha': 1.356177149713638, 'tversky_beta': 0.07110177200086643}. Best is trial 0 with value: 0.09180638817145713.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4500.36 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.14 sec. Users per second: 1174
# [I 2023-11-24 14:54:11,449] Trial 1 finished with value: 0.10301071935381094 and parameters: {'similarity': 'cosine', 'topK': 785, 'shrink': 93}. Best is trial 1 with value: 0.10301071935381094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4607.68 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.24 sec. Users per second: 1423
# [I 2023-11-24 14:54:16,635] Trial 2 finished with value: 0.09925147501362445 and parameters: {'similarity': 'dice', 'topK': 156, 'shrink': 824}. Best is trial 1 with value: 0.10301071935381094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4555.76 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.65 sec. Users per second: 1068
# [I 2023-11-24 14:54:23,292] Trial 3 finished with value: 0.01840662327849258 and parameters: {'similarity': 'asymmetric', 'topK': 960, 'shrink': 983, 'asymmetric_alpha': 1.19533423108744}. Best is trial 1 with value: 0.10301071935381094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4449.11 column/sec. Elapsed time 0.87 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.19 sec. Users per second: 1162
# [I 2023-11-24 14:54:29,517] Trial 4 finished with value: 0.08727186982494685 and parameters: {'similarity': 'tversky', 'topK': 664, 'shrink': 920, 'tversky_alpha': 0.48560512582469384, 'tversky_beta': 1.8041510480640255}. Best is trial 1 with value: 0.10301071935381094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 590.52 column/sec. Elapsed time 6.58 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.37 sec. Users per second: 1379
# [I 2023-11-24 14:54:40,589] Trial 5 finished with value: 0.05743622096375486 and parameters: {'similarity': 'euclidean', 'topK': 910, 'shrink': 16, 'normalize_avg_row': True, 'similarity_from_distance_mode': 'lin', 'normalize': True}. Best is trial 1 with value: 0.10301071935381094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4499.39 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.73 sec. Users per second: 1276
# [I 2023-11-24 14:54:46,318] Trial 6 finished with value: 0.09546425741192706 and parameters: {'similarity': 'tversky', 'topK': 497, 'shrink': 280, 'tversky_alpha': 1.8436167628759952, 'tversky_beta': 1.420190490736325}. Best is trial 1 with value: 0.10301071935381094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4585.09 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.31 sec. Users per second: 1136
# [I 2023-11-24 14:54:52,633] Trial 7 finished with value: 0.09524509842638917 and parameters: {'similarity': 'dice', 'topK': 669, 'shrink': 834}. Best is trial 1 with value: 0.10301071935381094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4557.05 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.31 sec. Users per second: 1135
# [I 2023-11-24 14:54:58,909] Trial 8 finished with value: 0.014772541183222875 and parameters: {'similarity': 'asymmetric', 'topK': 610, 'shrink': 705, 'asymmetric_alpha': 1.9600274188047948}. Best is trial 1 with value: 0.10301071935381094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4500.25 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.46 sec. Users per second: 1104
# [I 2023-11-24 14:55:05,404] Trial 9 finished with value: 0.0874925492395226 and parameters: {'similarity': 'tversky', 'topK': 799, 'shrink': 959, 'tversky_alpha': 0.45620214715305774, 'tversky_beta': 0.4734019447415978}. Best is trial 1 with value: 0.10301071935381094.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4564.93 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.68 sec. Users per second: 1289
# [I 2023-11-24 14:55:11,034] Trial 10 finished with value: 0.10524280790991677 and parameters: {'similarity': 'cosine', 'topK': 420, 'shrink': 347}. Best is trial 10 with value: 0.10524280790991677.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4552.10 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.53 sec. Users per second: 1330
# [I 2023-11-24 14:55:16,513] Trial 11 finished with value: 0.10575785818280398 and parameters: {'similarity': 'cosine', 'topK': 357, 'shrink': 293}. Best is trial 11 with value: 0.10575785818280398.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4404.44 column/sec. Elapsed time 0.88 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.62 sec. Users per second: 1306
# [I 2023-11-24 14:55:22,108] Trial 12 finished with value: 0.1056516058626689 and parameters: {'similarity': 'cosine', 'topK': 367, 'shrink': 423}. Best is trial 11 with value: 0.10575785818280398.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4500.67 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.70 sec. Users per second: 1058
# [I 2023-11-24 14:55:28,813] Trial 13 finished with value: 0.09964904417010921 and parameters: {'similarity': 'jaccard', 'topK': 334, 'shrink': 531}. Best is trial 11 with value: 0.10575785818280398.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4168.85 column/sec. Elapsed time 0.93 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.50 sec. Users per second: 1340
# [I 2023-11-24 14:55:34,336] Trial 14 finished with value: 0.10617461370571296 and parameters: {'similarity': 'cosine', 'topK': 266, 'shrink': 432}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4557.42 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.32 sec. Users per second: 1396
# [I 2023-11-24 14:55:39,613] Trial 15 finished with value: 0.10552346199717222 and parameters: {'similarity': 'cosine', 'topK': 245, 'shrink': 211}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4613.89 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.30 sec. Users per second: 1826
# [I 2023-11-24 14:55:43,840] Trial 16 finished with value: 0.1057072693621043 and parameters: {'similarity': 'cosine', 'topK': 243, 'shrink': 587}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 2091.36 column/sec. Elapsed time 1.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.27 sec. Users per second: 1845
# [I 2023-11-24 14:55:49,021] Trial 17 finished with value: 0.08026529841217263 and parameters: {'similarity': 'euclidean', 'topK': 5, 'shrink': 188, 'normalize_avg_row': False, 'similarity_from_distance_mode': 'log', 'normalize': False}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4600.23 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.37 sec. Users per second: 1381
# [I 2023-11-24 14:55:54,361] Trial 18 finished with value: 0.10129954558259364 and parameters: {'similarity': 'jaccard', 'topK': 270, 'shrink': 419}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4604.46 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.78 sec. Users per second: 1260
# [I 2023-11-24 14:56:00,110] Trial 19 finished with value: 0.10460468845026819 and parameters: {'similarity': 'cosine', 'topK': 451, 'shrink': 637}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4596.30 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.95 sec. Users per second: 1219
# [I 2023-11-24 14:56:06,031] Trial 20 finished with value: 0.10386754364486989 and parameters: {'similarity': 'cosine', 'topK': 556, 'shrink': 492}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4614.30 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.23 sec. Users per second: 1424
# [I 2023-11-24 14:56:11,186] Trial 21 finished with value: 0.1044052489686093 and parameters: {'similarity': 'cosine', 'topK': 186, 'shrink': 609}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4564.77 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.41 sec. Users per second: 1369
# [I 2023-11-24 14:56:16,525] Trial 22 finished with value: 0.10570588715388841 and parameters: {'similarity': 'cosine', 'topK': 282, 'shrink': 342}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4603.25 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.94 sec. Users per second: 1531
# [I 2023-11-24 14:56:21,377] Trial 23 finished with value: 0.10353699184102173 and parameters: {'similarity': 'cosine', 'topK': 80, 'shrink': 730}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4494.16 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.65 sec. Users per second: 1296
# [I 2023-11-24 14:56:27,014] Trial 24 finished with value: 0.10581595700147671 and parameters: {'similarity': 'cosine', 'topK': 390, 'shrink': 531}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4560.42 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.66 sec. Users per second: 1293
# [I 2023-11-24 14:56:32,637] Trial 25 finished with value: 0.10553737622654485 and parameters: {'similarity': 'cosine', 'topK': 403, 'shrink': 459}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# C:\Users\MaurizioFD\PycharmProjects\RecSys_Course_AT_PoliMi\Recommenders\Similarity\Compute_Similarity_Euclidean.py:167: RuntimeWarning: overflow encountered in exp
#   item_similarity = 1/(np.exp(item_distance) + self.shrink + 1e-9)
# Similarity column 3883 (100.0%), 1055.70 column/sec. Elapsed time 3.68 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.93 sec. Users per second: 1532
# [I 2023-11-24 14:56:40,323] Trial 26 finished with value: 0.07146480502965852 and parameters: {'similarity': 'euclidean', 'topK': 324, 'shrink': 346, 'normalize_avg_row': False, 'similarity_from_distance_mode': 'exp', 'normalize': True}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4397.57 column/sec. Elapsed time 0.88 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.05 sec. Users per second: 1490
# [I 2023-11-24 14:56:45,367] Trial 27 finished with value: 0.10373123158701195 and parameters: {'similarity': 'asymmetric', 'topK': 489, 'shrink': 222, 'asymmetric_alpha': 0.05765689448259392}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4608.34 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.23 sec. Users per second: 1426
# [I 2023-11-24 14:56:50,569] Trial 28 finished with value: 0.10065722026080305 and parameters: {'similarity': 'dice', 'topK': 194, 'shrink': 548}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4664.55 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.72 sec. Users per second: 1619
# [I 2023-11-24 14:56:55,234] Trial 29 finished with value: 0.09956856016028331 and parameters: {'similarity': 'jaccard', 'topK': 68, 'shrink': 132}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4609.69 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.87 sec. Users per second: 1238
# [I 2023-11-24 14:57:01,081] Trial 30 finished with value: 0.10394805398247098 and parameters: {'similarity': 'cosine', 'topK': 555, 'shrink': 273}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4565.42 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.37 sec. Users per second: 1379
# [I 2023-11-24 14:57:06,396] Trial 31 finished with value: 0.1057528295776762 and parameters: {'similarity': 'cosine', 'topK': 228, 'shrink': 629}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 3898.15 column/sec. Elapsed time 1.00 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.70 sec. Users per second: 1282
# [I 2023-11-24 14:57:12,206] Trial 32 finished with value: 0.10553010976049608 and parameters: {'similarity': 'cosine', 'topK': 362, 'shrink': 394}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4654.15 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.13 sec. Users per second: 1461
# [I 2023-11-24 14:57:17,237] Trial 33 finished with value: 0.10409399542423223 and parameters: {'similarity': 'cosine', 'topK': 130, 'shrink': 668}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4557.73 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.18 sec. Users per second: 1443
# [I 2023-11-24 14:57:22,360] Trial 34 finished with value: 0.10541641326182687 and parameters: {'similarity': 'cosine', 'topK': 212, 'shrink': 778}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4555.26 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.38 sec. Users per second: 1376
# [I 2023-11-24 14:57:27,696] Trial 35 finished with value: 0.10543925260710754 and parameters: {'similarity': 'cosine', 'topK': 305, 'shrink': 560}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4555.23 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.73 sec. Users per second: 1275
# [I 2023-11-24 14:57:33,426] Trial 36 finished with value: 0.10000319882472795 and parameters: {'similarity': 'dice', 'topK': 409, 'shrink': 486}. Best is trial 14 with value: 0.10617461370571296.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4606.64 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.65 sec. Users per second: 1651
# [I 2023-11-24 14:57:38,010] Trial 37 finished with value: 0.10652225223588643 and parameters: {'similarity': 'asymmetric', 'topK': 153, 'shrink': 274, 'asymmetric_alpha': 0.07704026305087841}. Best is trial 37 with value: 0.10652225223588643.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4608.01 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.54 sec. Users per second: 1704
# [I 2023-11-24 14:57:42,481] Trial 38 finished with value: 0.09716794093100284 and parameters: {'similarity': 'asymmetric', 'topK': 128, 'shrink': 87, 'asymmetric_alpha': 0.06647579227934189}. Best is trial 37 with value: 0.10652225223588643.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4612.02 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.70 sec. Users per second: 1629
# [I 2023-11-24 14:57:47,096] Trial 39 finished with value: 0.0887723950640689 and parameters: {'similarity': 'asymmetric', 'topK': 29, 'shrink': 274, 'asymmetric_alpha': 0.5941022520125943}. Best is trial 37 with value: 0.10652225223588643.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4531.18 column/sec. Elapsed time 0.86 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.49 sec. Users per second: 1343
# [I 2023-11-24 14:57:52,527] Trial 40 finished with value: 0.08575829917304452 and parameters: {'similarity': 'asymmetric', 'topK': 182, 'shrink': 309, 'asymmetric_alpha': 0.6631601018018185}. Best is trial 37 with value: 0.10652225223588643.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4552.81 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.25 sec. Users per second: 1419
# [I 2023-11-24 14:57:57,764] Trial 41 finished with value: 0.09683882399092185 and parameters: {'similarity': 'tversky', 'topK': 240, 'shrink': 388, 'tversky_alpha': 0.0929369022279356, 'tversky_beta': 0.8910821271624274}. Best is trial 37 with value: 0.10652225223588643.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4552.86 column/sec. Elapsed time 0.85 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.71 sec. Users per second: 1623
# [I 2023-11-24 14:58:02,419] Trial 42 finished with value: 0.10887136117232304 and parameters: {'similarity': 'asymmetric', 'topK': 145, 'shrink': 452, 'asymmetric_alpha': 0.0967263194468786}. Best is trial 42 with value: 0.10887136117232304.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4612.36 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.55 sec. Users per second: 1698
# [I 2023-11-24 14:58:06,890] Trial 43 finished with value: 0.10200923051810436 and parameters: {'similarity': 'asymmetric', 'topK': 75, 'shrink': 445, 'asymmetric_alpha': 0.017633268123771417}. Best is trial 42 with value: 0.10887136117232304.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4671.14 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.05 sec. Users per second: 1490
# [I 2023-11-24 14:58:11,857] Trial 44 finished with value: 0.10648416910856771 and parameters: {'similarity': 'asymmetric', 'topK': 150, 'shrink': 523, 'asymmetric_alpha': 0.43639715240893884}. Best is trial 42 with value: 0.10887136117232304.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4661.43 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.01 sec. Users per second: 1504
# [I 2023-11-24 14:58:16,789] Trial 45 finished with value: 0.10624167055001332 and parameters: {'similarity': 'asymmetric', 'topK': 153, 'shrink': 503, 'asymmetric_alpha': 0.3923950838442256}. Best is trial 42 with value: 0.10887136117232304.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4653.75 column/sec. Elapsed time 0.83 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 4.02 sec. Users per second: 1500
# [I 2023-11-24 14:58:21,731] Trial 46 finished with value: 0.1061879223962486 and parameters: {'similarity': 'asymmetric', 'topK': 152, 'shrink': 374, 'asymmetric_alpha': 0.3542588203198769}. Best is trial 42 with value: 0.10887136117232304.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 3811.34 column/sec. Elapsed time 1.02 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.99 sec. Users per second: 1513
# [I 2023-11-24 14:58:26,842] Trial 47 finished with value: 0.10612730269306797 and parameters: {'similarity': 'asymmetric', 'topK': 151, 'shrink': 379, 'asymmetric_alpha': 0.3552404834925272}. Best is trial 42 with value: 0.10887136117232304.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4599.39 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.87 sec. Users per second: 1558
# [I 2023-11-24 14:58:31,640] Trial 48 finished with value: 0.10619279961666721 and parameters: {'similarity': 'asymmetric', 'topK': 104, 'shrink': 488, 'asymmetric_alpha': 0.37421190413939476}. Best is trial 42 with value: 0.10887136117232304.
# ItemKNNCFRecommender: URM Detected 240 ( 6.2%) items with no interactions.
# Similarity column 3883 (100.0%), 4607.47 column/sec. Elapsed time 0.84 sec
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.80 sec. Users per second: 1585
# [I 2023-11-24 14:58:36,369] Trial 49 finished with value: 0.106262048248281 and parameters: {'similarity': 'asymmetric', 'topK': 98, 'shrink': 500, 'asymmetric_alpha': 0.3253251774081455}. Best is trial 42 with value: 0.10887136117232304.

# %%
save_results.results_df
# Out:
#       result  shrink  similarity   topK  tversky_alpha  tversky_beta  \
# 0   0.091806   884.0     tversky  111.0       1.356177      0.071102
# 1   0.103011    93.0      cosine  785.0            NaN           NaN
# 2   0.099251   824.0        dice  156.0            NaN           NaN
# 3   0.018407   983.0  asymmetric  960.0            NaN           NaN
# 4   0.087272   920.0     tversky  664.0       0.485605      1.804151
# 5   0.057436    16.0   euclidean  910.0            NaN           NaN
# 6   0.095464   280.0     tversky  497.0       1.843617      1.420190
# 7   0.095245   834.0        dice  669.0            NaN           NaN
# 8   0.014773   705.0  asymmetric  610.0            NaN           NaN
# 9   0.087493   959.0     tversky  799.0       0.456202      0.473402
# 10  0.105243   347.0      cosine  420.0            NaN           NaN
# 11  0.105758   293.0      cosine  357.0            NaN           NaN
# 12  0.105652   423.0      cosine  367.0            NaN           NaN
# 13  0.099649   531.0     jaccard  334.0            NaN           NaN
# 14  0.106175   432.0      cosine  266.0            NaN           NaN
# 15  0.105523   211.0      cosine  245.0            NaN           NaN
# 16  0.105707   587.0      cosine  243.0            NaN           NaN
# 17  0.080265   188.0   euclidean    5.0            NaN           NaN
# 18  0.101300   419.0     jaccard  270.0            NaN           NaN
# 19  0.104605   637.0      cosine  451.0            NaN           NaN
# 20  0.103868   492.0      cosine  556.0            NaN           NaN
# 21  0.104405   609.0      cosine  186.0            NaN           NaN
# 22  0.105706   342.0      cosine  282.0            NaN           NaN
# 23  0.103537   730.0      cosine   80.0            NaN           NaN
# 24  0.105816   531.0      cosine  390.0            NaN           NaN
# 25  0.105537   459.0      cosine  403.0            NaN           NaN
# 26  0.071465   346.0   euclidean  324.0            NaN           NaN
# 27  0.103731   222.0  asymmetric  489.0            NaN           NaN
# 28  0.100657   548.0        dice  194.0            NaN           NaN
# 29  0.099569   132.0     jaccard   68.0            NaN           NaN
# 30  0.103948   273.0      cosine  555.0            NaN           NaN
# 31  0.105753   629.0      cosine  228.0            NaN           NaN
# 32  0.105530   394.0      cosine  362.0            NaN           NaN
# 33  0.104094   668.0      cosine  130.0            NaN           NaN
# 34  0.105416   778.0      cosine  212.0            NaN           NaN
# 35  0.105439   560.0      cosine  305.0            NaN           NaN
# 36  0.100003   486.0        dice  409.0            NaN           NaN
# 37  0.106522   274.0  asymmetric  153.0            NaN           NaN
# 38  0.097168    87.0  asymmetric  128.0            NaN           NaN
# 39  0.088772   274.0  asymmetric   29.0            NaN           NaN
# 40  0.085758   309.0  asymmetric  182.0            NaN           NaN
# 41  0.096839   388.0     tversky  240.0       0.092937      0.891082
# 42  0.108871   452.0  asymmetric  145.0            NaN           NaN
# 43  0.102009   445.0  asymmetric   75.0            NaN           NaN
# 44  0.106484   523.0  asymmetric  150.0            NaN           NaN
# 45  0.106242   503.0  asymmetric  153.0            NaN           NaN
# 46  0.106188   374.0  asymmetric  152.0            NaN           NaN
# 47  0.106127   379.0  asymmetric  151.0            NaN           NaN
# 48  0.106193   488.0  asymmetric  104.0            NaN           NaN
# 49  0.106262   500.0  asymmetric   98.0            NaN           NaN
#
#     asymmetric_alpha  normalize  normalize_avg_row  \
# 0                NaN        NaN                NaN
# 1                NaN        NaN                NaN
# 2                NaN        NaN                NaN
# 3           1.195334        NaN                NaN
# 4                NaN        NaN                NaN
# 5                NaN        1.0                1.0
# 6                NaN        NaN                NaN
# 7                NaN        NaN                NaN
# 8           1.960027        NaN                NaN
# 9                NaN        NaN                NaN
# 10               NaN        NaN                NaN
# 11               NaN        NaN                NaN
# 12               NaN        NaN                NaN
# 13               NaN        NaN                NaN
# 14               NaN        NaN                NaN
# 15               NaN        NaN                NaN
# 16               NaN        NaN                NaN
# 17               NaN        0.0                0.0
# 18               NaN        NaN                NaN
# 19               NaN        NaN                NaN
# 20               NaN        NaN                NaN
# 21               NaN        NaN                NaN
# 22               NaN        NaN                NaN
# 23               NaN        NaN                NaN
# 24               NaN        NaN                NaN
# 25               NaN        NaN                NaN
# 26               NaN        1.0                0.0
# 27          0.057657        NaN                NaN
# 28               NaN        NaN                NaN
# 29               NaN        NaN                NaN
# 30               NaN        NaN                NaN
# 31               NaN        NaN                NaN
# 32               NaN        NaN                NaN
# 33               NaN        NaN                NaN
# 34               NaN        NaN                NaN
# 35               NaN        NaN                NaN
# 36               NaN        NaN                NaN
# 37          0.077040        NaN                NaN
# 38          0.066476        NaN                NaN
# 39          0.594102        NaN                NaN
# 40          0.663160        NaN                NaN
# 41               NaN        NaN                NaN
# 42          0.096726        NaN                NaN
# 43          0.017633        NaN                NaN
# 44          0.436397        NaN                NaN
# 45          0.392395        NaN                NaN
# 46          0.354259        NaN                NaN
# 47          0.355240        NaN                NaN
# 48          0.374212        NaN                NaN
# 49          0.325325        NaN                NaN
#
#    similarity_from_distance_mode
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            lin
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           log
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           exp
# 27                           NaN
# 28                           NaN
# 29                           NaN
# 30                           NaN
# 31                           NaN
# 32                           NaN
# 33                           NaN
# 34                           NaN
# 35                           NaN
# 36                           NaN
# 37                           NaN
# 38                           NaN
# 39                           NaN
# 40                           NaN
# 41                           NaN
# 42                           NaN
# 43                           NaN
# 44                           NaN
# 45                           NaN
# 46                           NaN
# 47                           NaN
# 48                           NaN
# 49                           NaN

# %%
optuna_study.best_trial.params
# Out:
# {'similarity': 'asymmetric',
#  'topK': 145,
#  'shrink': 452,
#  'asymmetric_alpha': 0.0967263194468786}

# %%
recommender_instance = ItemKNNCFRecommender(URM_train + URM_validation)
recommender_instance.fit(**optuna_study.best_trial.params)

result_df, _ = evaluator_test.evaluateRecommender(recommender_instance)
result_df
# Out:
# ItemKNNCFRecommender: URM Detected 204 ( 5.3%) items with no interactions.
# Similarity column 3883 (100.0%), 3332.55 column/sec. Elapsed time 1.17 sec
# EvaluatorHoldout: Processed 6038 (100.0%) in 3.81 sec. Users per second: 1583
#        PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.339748                 0.362464  0.149985  0.245904    0.257506
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.623351  0.317127  0.208101  0.883902      1.170736  ...
#
#        COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
# cutoff
# 10          0.999669          0.883609    0.999669       0.047767
#
#        SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
# cutoff
# 10            7.949859                   0.994743             0.136562
#
#        RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
# cutoff
# 10                  0.735182                  1.71452      0.065643
#
# [1 rows x 27 columns]

# %% [markdown]
# ### An example with earlystopping, for SVD++
#
# When training machine learning models that require iterative training for a certain number of epochs one also has to select this value. There are two strategies:
# * Consider the number of epochs as another hyperparameter to be determined by our optimizer
# * Fix a maximum number of epochs and periodically evaluate the model during the training process. If the recommendation quality does not improve after a certain number of epochs (20, 50 ...) stop the training and select the number of epochs that gave the best result. This is called earlystopping.

# %%
from Recommenders.MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_SVDpp_Cython
import time 

class SaveResults(object):
    
    def __init__(self):
        self.results_df = pd.DataFrame(columns=["result", "train_time (min)"])
    
    def __call__(self, optuna_study, optuna_trial):
        hyperparam_dict = optuna_trial.params.copy()
        hyperparam_dict["result"] = optuna_trial.values[0]
        
        # Retrieve the optimal number of epochs and training time from the "user attributes" of the trial
        hyperparam_dict["epochs"] = optuna_trial.user_attrs["epochs"]
        hyperparam_dict["train_time (min)"] = optuna_trial.user_attrs["train_time (min)"]
        
        self.results_df = self.results_df.append(hyperparam_dict, ignore_index=True)
        
        
def objective_function_funksvd(optuna_trial):

    # Earlystopping hyperparameters available in the framework
    full_hyperp = {"validation_every_n": 5,
                   "stop_on_validation": True,
                   "evaluator_object": evaluator_validation,
                   "lower_validations_allowed": 5,   # Higher values will result in a more "patient" earlystopping
                   "validation_metric": "MAP",
                   
                   # MAX number of epochs (usually 500)
                   "epochs": 500,
                  }
                          
    start_time = time.time()    
    recommender_instance = MatrixFactorization_SVDpp_Cython(URM_train)
    recommender_instance.fit(num_factors = optuna_trial.suggest_int("num_factors", 1, 200),
                             sgd_mode = optuna_trial.suggest_categorical("sgd_mode", ["sgd", "adagrad", "adam"]),
                             batch_size = optuna_trial.suggest_categorical("batch_size", [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]),
                             item_reg = optuna_trial.suggest_float("item_reg", 1e-5, 1e-2, log=True),
                             user_reg =  optuna_trial.suggest_float("user_reg", 1e-5, 1e-2, log=True),
                             learning_rate = optuna_trial.suggest_float("learning_rate", 1e-4, 1e-1, log=True),
                             ** full_hyperp)
        
    # Add the number of epochs selected by earlystopping as a "user attribute" of the optuna trial
    epochs = recommender_instance.get_early_stopping_final_epochs_dict()["epochs"]
    optuna_trial.set_user_attr("epochs", epochs) 
    optuna_trial.set_user_attr("train_time (min)", (time.time() - start_time)/60) 
        
    result_df, _ = evaluator_validation.evaluateRecommender(recommender_instance)
    
    return result_df.loc[10]["MAP"]

# %%
optuna_study = optuna.create_study(direction="maximize")
        
save_results = SaveResults()
        
optuna_study.optimize(objective_function_funksvd,
                      callbacks=[save_results],
                      n_trials = 50)
# Out:
# [I 2023-11-24 14:58:41,567] A new study created in memory with name: no-name-45701efd-2a50-4ce8-916a-7b32aef636f1
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 240 ( 6.2%) items with no interactions.
# SVD++: Processed 641024 (100.0%) in 3.05 sec. MSE loss 1.16E+01. Sample per second: 209879
# SVD++: Epoch 1 of 500. Elapsed time 2.42 sec
# SVD++: Processed 641024 (100.0%) in 2.46 sec. MSE loss 6.93E+00. Sample per second: 260677
# SVD++: Epoch 2 of 500. Elapsed time 4.83 sec
# SVD++: Processed 641024 (100.0%) in 2.97 sec. MSE loss 4.39E+00. Sample per second: 216021
# SVD++: Epoch 3 of 500. Elapsed time 7.34 sec
# SVD++: Processed 641024 (100.0%) in 3.36 sec. MSE loss 2.97E+00. Sample per second: 190551
# SVD++: Epoch 4 of 500. Elapsed time 9.73 sec
# SVD++: Processed 641024 (100.0%) in 2.76 sec. MSE loss 2.20E+00. Sample per second: 232208
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.39 sec. Users per second: 1780
# SVD++: CUTOFF: 10 - PRECISION: 0.0080776, PRECISION_RECALL_MIN_DEN: 0.0085469, RECALL: 0.0030707, MAP: 0.0025093, MAP_MIN_DEN: 0.0026291, MRR: 0.0229315, NDCG: 0.0044823, F1: 0.0044498, HIT_RATE: 0.0739758, ARHR_ALL_HITS: 0.0239718, NOVELTY: 0.0319148, AVERAGE_POPULARITY: 0.0755768, DIVERSITY_MEAN_INTER_LIST: 0.9962881, DIVERSITY_HERFINDAHL: 0.9996123, COVERAGE_ITEM: 0.9915014, COVERAGE_ITEM_HIT: 0.1009529, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0738411, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6227291, SHANNON_ENTROPY: 11.5832067, RATIO_DIVERSITY_HERFINDAHL: 1.0004287, RATIO_DIVERSITY_GINI: 1.7798684, RATIO_SHANNON_ENTROPY: 1.0711752, RATIO_AVERAGE_POPULARITY: 0.2723395, RATIO_NOVELTY: 0.1081329,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 5 of 500. Elapsed time 15.53 sec
# SVD++: Processed 641024 (100.0%) in 2.56 sec. MSE loss 1.76E+00. Sample per second: 250074
# SVD++: Epoch 6 of 500. Elapsed time 17.93 sec
# SVD++: Processed 641024 (100.0%) in 2.96 sec. MSE loss 1.53E+00. Sample per second: 216602
# SVD++: Epoch 7 of 500. Elapsed time 20.33 sec
# SVD++: Processed 641024 (100.0%) in 3.36 sec. MSE loss 1.40E+00. Sample per second: 191013
# SVD++: Epoch 8 of 500. Elapsed time 22.73 sec
# SVD++: Processed 641024 (100.0%) in 2.75 sec. MSE loss 1.32E+00. Sample per second: 232228
# SVD++: Epoch 9 of 500. Elapsed time 25.13 sec
# SVD++: Processed 641024 (100.0%) in 3.17 sec. MSE loss 1.28E+00. Sample per second: 202324
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.36 sec. Users per second: 1797
# SVD++: CUTOFF: 10 - PRECISION: 0.0082435, PRECISION_RECALL_MIN_DEN: 0.0087127, RECALL: 0.0031249, MAP: 0.0025973, MAP_MIN_DEN: 0.0027221, MRR: 0.0237287, NDCG: 0.0046391, F1: 0.0045319, HIT_RATE: 0.0753027, ARHR_ALL_HITS: 0.0248115, NOVELTY: 0.0318726, AVERAGE_POPULARITY: 0.0775218, DIVERSITY_MEAN_INTER_LIST: 0.9962842, DIVERSITY_HERFINDAHL: 0.9996119, COVERAGE_ITEM: 0.9912439, COVERAGE_ITEM_HIT: 0.1022405, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0751656, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6220793, SHANNON_ENTROPY: 11.5819911, RATIO_DIVERSITY_HERFINDAHL: 1.0004283, RATIO_DIVERSITY_GINI: 1.7780110, RATIO_SHANNON_ENTROPY: 1.0710628, RATIO_AVERAGE_POPULARITY: 0.2793484, RATIO_NOVELTY: 0.1079896,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 10 of 500. Elapsed time 30.90 sec
# SVD++: Processed 641024 (100.0%) in 2.93 sec. MSE loss 1.26E+00. Sample per second: 219062
# SVD++: Epoch 11 of 500. Elapsed time 33.30 sec
# SVD++: Processed 641024 (100.0%) in 3.33 sec. MSE loss 1.25E+00. Sample per second: 192392
# SVD++: Epoch 12 of 500. Elapsed time 35.70 sec
# SVD++: Processed 641024 (100.0%) in 2.74 sec. MSE loss 1.24E+00. Sample per second: 234165
# SVD++: Epoch 13 of 500. Elapsed time 38.11 sec
# SVD++: Processed 641024 (100.0%) in 3.14 sec. MSE loss 1.24E+00. Sample per second: 204036
# SVD++: Epoch 14 of 500. Elapsed time 40.51 sec
# SVD++: Processed 641024 (100.0%) in 2.55 sec. MSE loss 1.23E+00. Sample per second: 251293
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.36 sec. Users per second: 1796
# SVD++: CUTOFF: 10 - PRECISION: 0.0083762, PRECISION_RECALL_MIN_DEN: 0.0088454, RECALL: 0.0031981, MAP: 0.0026202, MAP_MIN_DEN: 0.0027488, MRR: 0.0239173, NDCG: 0.0048001, F1: 0.0046289, HIT_RATE: 0.0764638, ARHR_ALL_HITS: 0.0250204, NOVELTY: 0.0318538, AVERAGE_POPULARITY: 0.0785346, DIVERSITY_MEAN_INTER_LIST: 0.9962794, DIVERSITY_HERFINDAHL: 0.9996114, COVERAGE_ITEM: 0.9909864, COVERAGE_ITEM_HIT: 0.1024981, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0763245, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6214035, SHANNON_ENTROPY: 11.5808215, RATIO_DIVERSITY_HERFINDAHL: 1.0004279, RATIO_DIVERSITY_GINI: 1.7760797, RATIO_SHANNON_ENTROPY: 1.0709546, RATIO_AVERAGE_POPULARITY: 0.2829979, RATIO_NOVELTY: 0.1079262,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 15 of 500. Elapsed time 46.29 sec
# SVD++: Processed 641024 (100.0%) in 3.32 sec. MSE loss 1.24E+00. Sample per second: 192909
# SVD++: Epoch 16 of 500. Elapsed time 48.69 sec
# SVD++: Processed 641024 (100.0%) in 2.72 sec. MSE loss 1.23E+00. Sample per second: 235576
# SVD++: Epoch 17 of 500. Elapsed time 51.09 sec
# SVD++: Processed 641024 (100.0%) in 3.12 sec. MSE loss 1.24E+00. Sample per second: 205623
# SVD++: Epoch 18 of 500. Elapsed time 53.49 sec
# SVD++: Processed 641024 (100.0%) in 2.52 sec. MSE loss 1.23E+00. Sample per second: 253954
# SVD++: Epoch 19 of 500. Elapsed time 55.89 sec
# SVD++: Processed 641024 (100.0%) in 2.92 sec. MSE loss 1.23E+00. Sample per second: 219472
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.37 sec. Users per second: 1791
# SVD++: CUTOFF: 10 - PRECISION: 0.0085255, PRECISION_RECALL_MIN_DEN: 0.0090018, RECALL: 0.0032521, MAP: 0.0026694, MAP_MIN_DEN: 0.0028021, MRR: 0.0242840, NDCG: 0.0049507, F1: 0.0047082, HIT_RATE: 0.0776248, ARHR_ALL_HITS: 0.0254499, NOVELTY: 0.0318379, AVERAGE_POPULARITY: 0.0796522, DIVERSITY_MEAN_INTER_LIST: 0.9962724, DIVERSITY_HERFINDAHL: 0.9996107, COVERAGE_ITEM: 0.9909864, COVERAGE_ITEM_HIT: 0.1032707, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0774834, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6205406, SHANNON_ENTROPY: 11.5793218, RATIO_DIVERSITY_HERFINDAHL: 1.0004272, RATIO_DIVERSITY_GINI: 1.7736132, RATIO_SHANNON_ENTROPY: 1.0708160, RATIO_AVERAGE_POPULARITY: 0.2870251, RATIO_NOVELTY: 0.1078721,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 20 of 500. Elapsed time 1.03 min
# SVD++: Processed 641024 (100.0%) in 2.73 sec. MSE loss 1.23E+00. Sample per second: 234736
# SVD++: Epoch 21 of 500. Elapsed time 1.07 min
# SVD++: Processed 641024 (100.0%) in 3.16 sec. MSE loss 1.23E+00. Sample per second: 202849
# SVD++: Epoch 22 of 500. Elapsed time 1.11 min
# SVD++: Processed 641024 (100.0%) in 2.56 sec. MSE loss 1.23E+00. Sample per second: 249916
# SVD++: Epoch 23 of 500. Elapsed time 1.15 min
# SVD++: Processed 641024 (100.0%) in 2.97 sec. MSE loss 1.23E+00. Sample per second: 215583
# SVD++: Epoch 24 of 500. Elapsed time 1.19 min
# SVD++: Processed 641024 (100.0%) in 3.74 sec. MSE loss 1.23E+00. Sample per second: 171492
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.78 sec. Users per second: 1596
# SVD++: CUTOFF: 10 - PRECISION: 0.0087577, PRECISION_RECALL_MIN_DEN: 0.0092411, RECALL: 0.0033505, MAP: 0.0027290, MAP_MIN_DEN: 0.0028547, MRR: 0.0247636, NDCG: 0.0051518, F1: 0.0048467, HIT_RATE: 0.0796152, ARHR_ALL_HITS: 0.0259878, NOVELTY: 0.0318175, AVERAGE_POPULARITY: 0.0808200, DIVERSITY_MEAN_INTER_LIST: 0.9962653, DIVERSITY_HERFINDAHL: 0.9996100, COVERAGE_ITEM: 0.9909864, COVERAGE_ITEM_HIT: 0.1035282, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0794702, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6198700, SHANNON_ENTROPY: 11.5781709, RATIO_DIVERSITY_HERFINDAHL: 1.0004265, RATIO_DIVERSITY_GINI: 1.7716966, RATIO_SHANNON_ENTROPY: 1.0707095, RATIO_AVERAGE_POPULARITY: 0.2912333, RATIO_NOVELTY: 0.1078030,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 25 of 500. Elapsed time 1.30 min
# SVD++: Processed 641024 (100.0%) in 3.04 sec. MSE loss 1.23E+00. Sample per second: 210806
# SVD++: Epoch 26 of 500. Elapsed time 1.34 min
# SVD++: Processed 641024 (100.0%) in 2.44 sec. MSE loss 1.23E+00. Sample per second: 262802
# SVD++: Epoch 27 of 500. Elapsed time 1.38 min
# SVD++: Processed 641024 (100.0%) in 2.84 sec. MSE loss 1.24E+00. Sample per second: 226107
# SVD++: Epoch 28 of 500. Elapsed time 1.42 min
# SVD++: Processed 641024 (100.0%) in 3.23 sec. MSE loss 1.23E+00. Sample per second: 198335
# SVD++: Epoch 29 of 500. Elapsed time 1.46 min
# SVD++: Processed 641024 (100.0%) in 2.63 sec. MSE loss 1.23E+00. Sample per second: 243955
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.46 sec. Users per second: 1742
# SVD++: CUTOFF: 10 - PRECISION: 0.0089069, PRECISION_RECALL_MIN_DEN: 0.0093975, RECALL: 0.0034345, MAP: 0.0027797, MAP_MIN_DEN: 0.0029098, MRR: 0.0251863, NDCG: 0.0053245, F1: 0.0049574, HIT_RATE: 0.0807762, ARHR_ALL_HITS: 0.0264526, NOVELTY: 0.0317921, AVERAGE_POPULARITY: 0.0821871, DIVERSITY_MEAN_INTER_LIST: 0.9962513, DIVERSITY_HERFINDAHL: 0.9996086, COVERAGE_ITEM: 0.9909864, COVERAGE_ITEM_HIT: 0.1035282, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0806291, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6186230, SHANNON_ENTROPY: 11.5756605, RATIO_DIVERSITY_HERFINDAHL: 1.0004251, RATIO_DIVERSITY_GINI: 1.7681324, RATIO_SHANNON_ENTROPY: 1.0704774, RATIO_AVERAGE_POPULARITY: 0.2961597, RATIO_NOVELTY: 0.1077170,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 30 of 500. Elapsed time 1.56 min
# SVD++: Processed 641024 (100.0%) in 2.52 sec. MSE loss 1.23E+00. Sample per second: 254870
# SVD++: Epoch 31 of 500. Elapsed time 1.60 min
# SVD++: Processed 641024 (100.0%) in 2.90 sec. MSE loss 1.24E+00. Sample per second: 220968
# SVD++: Epoch 32 of 500. Elapsed time 1.64 min
# SVD++: Processed 641024 (100.0%) in 3.30 sec. MSE loss 1.23E+00. Sample per second: 193905
# SVD++: Epoch 33 of 500. Elapsed time 1.68 min
# SVD++: Processed 641024 (100.0%) in 2.70 sec. MSE loss 1.23E+00. Sample per second: 237003
# SVD++: Epoch 34 of 500. Elapsed time 1.72 min
# SVD++: Processed 641024 (100.0%) in 3.13 sec. MSE loss 1.23E+00. Sample per second: 204710
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.39 sec. Users per second: 1781
# SVD++: CUTOFF: 10 - PRECISION: 0.0091060, PRECISION_RECALL_MIN_DEN: 0.0097209, RECALL: 0.0036019, MAP: 0.0028748, MAP_MIN_DEN: 0.0030325, MRR: 0.0259598, NDCG: 0.0055976, F1: 0.0051620, HIT_RATE: 0.0821032, ARHR_ALL_HITS: 0.0273112, NOVELTY: 0.0317731, AVERAGE_POPULARITY: 0.0832097, DIVERSITY_MEAN_INTER_LIST: 0.9962404, DIVERSITY_HERFINDAHL: 0.9996075, COVERAGE_ITEM: 0.9907288, COVERAGE_ITEM_HIT: 0.1043008, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0819536, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6176625, SHANNON_ENTROPY: 11.5736322, RATIO_DIVERSITY_HERFINDAHL: 1.0004240, RATIO_DIVERSITY_GINI: 1.7653873, RATIO_SHANNON_ENTROPY: 1.0702898, RATIO_AVERAGE_POPULARITY: 0.2998445, RATIO_NOVELTY: 0.1076526,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 35 of 500. Elapsed time 1.81 min
# SVD++: Processed 641024 (100.0%) in 2.92 sec. MSE loss 1.23E+00. Sample per second: 219786
# SVD++: Epoch 36 of 500. Elapsed time 1.85 min
# SVD++: Processed 641024 (100.0%) in 3.30 sec. MSE loss 1.23E+00. Sample per second: 194351
# SVD++: Epoch 37 of 500. Elapsed time 1.89 min
# SVD++: Processed 641024 (100.0%) in 2.70 sec. MSE loss 1.23E+00. Sample per second: 236632
# SVD++: Epoch 38 of 500. Elapsed time 1.93 min
# SVD++: Processed 641024 (100.0%) in 3.10 sec. MSE loss 1.23E+00. Sample per second: 206452
# SVD++: Epoch 39 of 500. Elapsed time 1.97 min
# SVD++: Processed 641024 (100.0%) in 2.50 sec. MSE loss 1.23E+00. Sample per second: 256640
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.41 sec. Users per second: 1767
# SVD++: CUTOFF: 10 - PRECISION: 0.0092884, PRECISION_RECALL_MIN_DEN: 0.0099283, RECALL: 0.0037001, MAP: 0.0029317, MAP_MIN_DEN: 0.0031018, MRR: 0.0264363, NDCG: 0.0057662, F1: 0.0052921, HIT_RATE: 0.0835960, ARHR_ALL_HITS: 0.0278351, NOVELTY: 0.0317499, AVERAGE_POPULARITY: 0.0844498, DIVERSITY_MEAN_INTER_LIST: 0.9962237, DIVERSITY_HERFINDAHL: 0.9996058, COVERAGE_ITEM: 0.9907288, COVERAGE_ITEM_HIT: 0.1040433, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0834437, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6165123, SHANNON_ENTROPY: 11.5710923, RATIO_DIVERSITY_HERFINDAHL: 1.0004223, RATIO_DIVERSITY_GINI: 1.7620998, RATIO_SHANNON_ENTROPY: 1.0700549, RATIO_AVERAGE_POPULARITY: 0.3043133, RATIO_NOVELTY: 0.1075741,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 40 of 500. Elapsed time 2.07 min
# SVD++: Processed 641024 (100.0%) in 3.40 sec. MSE loss 1.23E+00. Sample per second: 188315
# SVD++: Epoch 41 of 500. Elapsed time 2.11 min
# SVD++: Processed 641024 (100.0%) in 2.81 sec. MSE loss 1.23E+00. Sample per second: 228445
# SVD++: Epoch 42 of 500. Elapsed time 2.15 min
# SVD++: Processed 641024 (100.0%) in 3.19 sec. MSE loss 1.23E+00. Sample per second: 200898
# SVD++: Epoch 43 of 500. Elapsed time 2.19 min
# SVD++: Processed 641024 (100.0%) in 2.59 sec. MSE loss 1.23E+00. Sample per second: 247938
# SVD++: Epoch 44 of 500. Elapsed time 2.23 min
# SVD++: Processed 641024 (100.0%) in 2.99 sec. MSE loss 1.23E+00. Sample per second: 214611
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.41 sec. Users per second: 1768
# SVD++: CUTOFF: 10 - PRECISION: 0.0094045, PRECISION_RECALL_MIN_DEN: 0.0100720, RECALL: 0.0037992, MAP: 0.0029915, MAP_MIN_DEN: 0.0031683, MRR: 0.0269610, NDCG: 0.0059145, F1: 0.0054121, HIT_RATE: 0.0847570, ARHR_ALL_HITS: 0.0283962, NOVELTY: 0.0317348, AVERAGE_POPULARITY: 0.0858904, DIVERSITY_MEAN_INTER_LIST: 0.9961978, DIVERSITY_HERFINDAHL: 0.9996033, COVERAGE_ITEM: 0.9907288, COVERAGE_ITEM_HIT: 0.1037857, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0846026, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6146346, SHANNON_ENTROPY: 11.5669291, RATIO_DIVERSITY_HERFINDAHL: 1.0004197, RATIO_DIVERSITY_GINI: 1.7567328, RATIO_SHANNON_ENTROPY: 1.0696699, RATIO_AVERAGE_POPULARITY: 0.3095046, RATIO_NOVELTY: 0.1075229,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 45 of 500. Elapsed time 2.33 min
# SVD++: Processed 641024 (100.0%) in 2.82 sec. MSE loss 1.23E+00. Sample per second: 227600
# SVD++: Epoch 46 of 500. Elapsed time 2.37 min
# SVD++: Processed 641024 (100.0%) in 3.20 sec. MSE loss 1.23E+00. Sample per second: 200113
# SVD++: Epoch 47 of 500. Elapsed time 2.41 min
# SVD++: Processed 641024 (100.0%) in 2.62 sec. MSE loss 1.23E+00. Sample per second: 244355
# SVD++: Epoch 48 of 500. Elapsed time 2.45 min
# SVD++: Processed 641024 (100.0%) in 3.02 sec. MSE loss 1.23E+00. Sample per second: 212280
# SVD++: Epoch 49 of 500. Elapsed time 2.49 min
# SVD++: Processed 641024 (100.0%) in 2.42 sec. MSE loss 1.23E+00. Sample per second: 264563
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.41 sec. Users per second: 1770
# SVD++: CUTOFF: 10 - PRECISION: 0.0096036, PRECISION_RECALL_MIN_DEN: 0.0102948, RECALL: 0.0039269, MAP: 0.0030990, MAP_MIN_DEN: 0.0032910, MRR: 0.0279232, NDCG: 0.0061600, F1: 0.0055744, HIT_RATE: 0.0865815, ARHR_ALL_HITS: 0.0294151, NOVELTY: 0.0317106, AVERAGE_POPULARITY: 0.0874842, DIVERSITY_MEAN_INTER_LIST: 0.9961706, DIVERSITY_HERFINDAHL: 0.9996005, COVERAGE_ITEM: 0.9904713, COVERAGE_ITEM_HIT: 0.1037857, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0864238, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6132305, SHANNON_ENTROPY: 11.5632841, RATIO_DIVERSITY_HERFINDAHL: 1.0004170, RATIO_DIVERSITY_GINI: 1.7527196, RATIO_SHANNON_ENTROPY: 1.0693328, RATIO_AVERAGE_POPULARITY: 0.3152478, RATIO_NOVELTY: 0.1074410,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 50 of 500. Elapsed time 2.59 min
# SVD++: Processed 641024 (100.0%) in 3.28 sec. MSE loss 1.23E+00. Sample per second: 195444
# SVD++: Epoch 51 of 500. Elapsed time 2.63 min
# SVD++: Processed 641024 (100.0%) in 2.91 sec. MSE loss 1.23E+00. Sample per second: 220152
# SVD++: Epoch 52 of 500. Elapsed time 2.67 min
# SVD++: Processed 641024 (100.0%) in 3.35 sec. MSE loss 1.23E+00. Sample per second: 191124
# SVD++: Epoch 53 of 500. Elapsed time 2.71 min
# SVD++: Processed 641024 (100.0%) in 2.82 sec. MSE loss 1.23E+00. Sample per second: 227437
# SVD++: Epoch 54 of 500. Elapsed time 2.75 min
# SVD++: Processed 641024 (100.0%) in 3.22 sec. MSE loss 1.23E+00. Sample per second: 198400
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.41 sec. Users per second: 1767
# SVD++: CUTOFF: 10 - PRECISION: 0.0098192, PRECISION_RECALL_MIN_DEN: 0.0105214, RECALL: 0.0040247, MAP: 0.0031907, MAP_MIN_DEN: 0.0033854, MRR: 0.0287391, NDCG: 0.0064014, F1: 0.0057092, HIT_RATE: 0.0885719, ARHR_ALL_HITS: 0.0302816, NOVELTY: 0.0316772, AVERAGE_POPULARITY: 0.0891584, DIVERSITY_MEAN_INTER_LIST: 0.9961382, DIVERSITY_HERFINDAHL: 0.9995973, COVERAGE_ITEM: 0.9902138, COVERAGE_ITEM_HIT: 0.1043008, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0884106, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6115292, SHANNON_ENTROPY: 11.5591600, RATIO_DIVERSITY_HERFINDAHL: 1.0004137, RATIO_DIVERSITY_GINI: 1.7478571, RATIO_SHANNON_ENTROPY: 1.0689515, RATIO_AVERAGE_POPULARITY: 0.3212807, RATIO_NOVELTY: 0.1073277,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 55 of 500. Elapsed time 2.85 min
# SVD++: Processed 641024 (100.0%) in 3.06 sec. MSE loss 1.23E+00. Sample per second: 209497
# SVD++: Epoch 56 of 500. Elapsed time 2.89 min
# SVD++: Processed 641024 (100.0%) in 2.45 sec. MSE loss 1.23E+00. Sample per second: 261947
# SVD++: Epoch 57 of 500. Elapsed time 2.93 min
# SVD++: Processed 641024 (100.0%) in 2.83 sec. MSE loss 1.22E+00. Sample per second: 226458
# SVD++: Epoch 58 of 500. Elapsed time 2.97 min
# SVD++: Processed 641024 (100.0%) in 3.26 sec. MSE loss 1.23E+00. Sample per second: 196890
# SVD++: Epoch 59 of 500. Elapsed time 3.01 min
# SVD++: Processed 641024 (100.0%) in 2.77 sec. MSE loss 1.23E+00. Sample per second: 231378
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.41 sec. Users per second: 1767
# SVD++: CUTOFF: 10 - PRECISION: 0.0099851, PRECISION_RECALL_MIN_DEN: 0.0107234, RECALL: 0.0041437, MAP: 0.0033081, MAP_MIN_DEN: 0.0035209, MRR: 0.0299049, NDCG: 0.0066912, F1: 0.0058568, HIT_RATE: 0.0902306, ARHR_ALL_HITS: 0.0314510, NOVELTY: 0.0316444, AVERAGE_POPULARITY: 0.0911464, DIVERSITY_MEAN_INTER_LIST: 0.9960885, DIVERSITY_HERFINDAHL: 0.9995923, COVERAGE_ITEM: 0.9894412, COVERAGE_ITEM_HIT: 0.1040433, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0900662, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6093243, SHANNON_ENTROPY: 11.5531284, RATIO_DIVERSITY_HERFINDAHL: 1.0004088, RATIO_DIVERSITY_GINI: 1.7415552, RATIO_SHANNON_ENTROPY: 1.0683937, RATIO_AVERAGE_POPULARITY: 0.3284444, RATIO_NOVELTY: 0.1072166,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 60 of 500. Elapsed time 3.11 min
# SVD++: Processed 641024 (100.0%) in 2.61 sec. MSE loss 1.23E+00. Sample per second: 245440
# SVD++: Epoch 61 of 500. Elapsed time 3.15 min
# SVD++: Processed 641024 (100.0%) in 3.01 sec. MSE loss 1.23E+00. Sample per second: 213290
# SVD++: Epoch 62 of 500. Elapsed time 3.19 min
# SVD++: Processed 641024 (100.0%) in 2.40 sec. MSE loss 1.23E+00. Sample per second: 267199
# SVD++: Epoch 63 of 500. Elapsed time 3.23 min
# SVD++: Processed 641024 (100.0%) in 2.79 sec. MSE loss 1.22E+00. Sample per second: 229545
# SVD++: Epoch 64 of 500. Elapsed time 3.27 min
# SVD++: Processed 641024 (100.0%) in 3.21 sec. MSE loss 1.22E+00. Sample per second: 199902
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.41 sec. Users per second: 1769
# SVD++: CUTOFF: 10 - PRECISION: 0.0102836, PRECISION_RECALL_MIN_DEN: 0.0110635, RECALL: 0.0042985, MAP: 0.0034241, MAP_MIN_DEN: 0.0036536, MRR: 0.0308843, NDCG: 0.0069856, F1: 0.0060627, HIT_RATE: 0.0928844, ARHR_ALL_HITS: 0.0325126, NOVELTY: 0.0316142, AVERAGE_POPULARITY: 0.0930772, DIVERSITY_MEAN_INTER_LIST: 0.9960370, DIVERSITY_HERFINDAHL: 0.9995872, COVERAGE_ITEM: 0.9889261, COVERAGE_ITEM_HIT: 0.1040433, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0927152, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6071540, SHANNON_ENTROPY: 11.5471431, RATIO_DIVERSITY_HERFINDAHL: 1.0004036, RATIO_DIVERSITY_GINI: 1.7353519, RATIO_SHANNON_ENTROPY: 1.0678402, RATIO_AVERAGE_POPULARITY: 0.3354020, RATIO_NOVELTY: 0.1071142,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 65 of 500. Elapsed time 3.37 min
# SVD++: Processed 641024 (100.0%) in 3.02 sec. MSE loss 1.23E+00. Sample per second: 212233
# SVD++: Epoch 66 of 500. Elapsed time 3.41 min
# SVD++: Processed 641024 (100.0%) in 2.42 sec. MSE loss 1.23E+00. Sample per second: 265147
# SVD++: Epoch 67 of 500. Elapsed time 3.45 min
# SVD++: Processed 641024 (100.0%) in 2.81 sec. MSE loss 1.22E+00. Sample per second: 227877
# SVD++: Epoch 68 of 500. Elapsed time 3.49 min
# SVD++: Processed 641024 (100.0%) in 3.21 sec. MSE loss 1.22E+00. Sample per second: 199833
# SVD++: Epoch 69 of 500. Elapsed time 3.53 min
# SVD++: Processed 641024 (100.0%) in 2.59 sec. MSE loss 1.23E+00. Sample per second: 247114
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.41 sec. Users per second: 1767
# SVD++: CUTOFF: 10 - PRECISION: 0.0105490, PRECISION_RECALL_MIN_DEN: 0.0113459, RECALL: 0.0044744, MAP: 0.0035249, MAP_MIN_DEN: 0.0037641, MRR: 0.0317983, NDCG: 0.0072653, F1: 0.0062836, HIT_RATE: 0.0953724, ARHR_ALL_HITS: 0.0334737, NOVELTY: 0.0315855, AVERAGE_POPULARITY: 0.0951416, DIVERSITY_MEAN_INTER_LIST: 0.9959681, DIVERSITY_HERFINDAHL: 0.9995803, COVERAGE_ITEM: 0.9886686, COVERAGE_ITEM_HIT: 0.1040433, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0951987, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6046095, SHANNON_ENTROPY: 11.5397688, RATIO_DIVERSITY_HERFINDAHL: 1.0003967, RATIO_DIVERSITY_GINI: 1.7280793, RATIO_SHANNON_ENTROPY: 1.0671582, RATIO_AVERAGE_POPULARITY: 0.3428411, RATIO_NOVELTY: 0.1070169,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 70 of 500. Elapsed time 3.62 min
# SVD++: Processed 641024 (100.0%) in 2.43 sec. MSE loss 1.22E+00. Sample per second: 263926
# SVD++: Epoch 71 of 500. Elapsed time 3.66 min
# SVD++: Processed 641024 (100.0%) in 2.82 sec. MSE loss 1.22E+00. Sample per second: 226974
# SVD++: Epoch 72 of 500. Elapsed time 3.70 min
# SVD++: Processed 641024 (100.0%) in 3.23 sec. MSE loss 1.22E+00. Sample per second: 198491
# SVD++: Epoch 73 of 500. Elapsed time 3.74 min
# SVD++: Processed 641024 (100.0%) in 2.64 sec. MSE loss 1.22E+00. Sample per second: 242074
# SVD++: Epoch 74 of 500. Elapsed time 3.78 min
# SVD++: Processed 641024 (100.0%) in 3.05 sec. MSE loss 1.23E+00. Sample per second: 209831
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.42 sec. Users per second: 1763
# SVD++: CUTOFF: 10 - PRECISION: 0.0107812, PRECISION_RECALL_MIN_DEN: 0.0116140, RECALL: 0.0046296, MAP: 0.0036457, MAP_MIN_DEN: 0.0038928, MRR: 0.0329104, NDCG: 0.0076059, F1: 0.0064776, HIT_RATE: 0.0975286, ARHR_ALL_HITS: 0.0346364, NOVELTY: 0.0315525, AVERAGE_POPULARITY: 0.0971404, DIVERSITY_MEAN_INTER_LIST: 0.9958972, DIVERSITY_HERFINDAHL: 0.9995732, COVERAGE_ITEM: 0.9884110, COVERAGE_ITEM_HIT: 0.1035282, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0973510, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.6021385, SHANNON_ENTROPY: 11.5324223, RATIO_DIVERSITY_HERFINDAHL: 1.0003896, RATIO_DIVERSITY_GINI: 1.7210170, RATIO_SHANNON_ENTROPY: 1.0664789, RATIO_AVERAGE_POPULARITY: 0.3500437, RATIO_NOVELTY: 0.1069051,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 75 of 500. Elapsed time 3.88 min
# SVD++: Processed 641024 (100.0%) in 2.89 sec. MSE loss 1.22E+00. Sample per second: 221756
# SVD++: Epoch 76 of 500. Elapsed time 3.92 min
# SVD++: Processed 641024 (100.0%) in 3.28 sec. MSE loss 1.22E+00. Sample per second: 195597
# SVD++: Epoch 77 of 500. Elapsed time 3.96 min
# SVD++: Processed 641024 (100.0%) in 2.67 sec. MSE loss 1.22E+00. Sample per second: 239955
# SVD++: Epoch 78 of 500. Elapsed time 4.00 min
# SVD++: Processed 641024 (100.0%) in 3.07 sec. MSE loss 1.22E+00. Sample per second: 207978
# SVD++: Epoch 79 of 500. Elapsed time 4.04 min
# SVD++: Processed 641024 (100.0%) in 2.48 sec. MSE loss 1.22E+00. Sample per second: 258813
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.47 sec. Users per second: 1735
# SVD++: CUTOFF: 10 - PRECISION: 0.0110466, PRECISION_RECALL_MIN_DEN: 0.0119031, RECALL: 0.0047741, MAP: 0.0037444, MAP_MIN_DEN: 0.0040110, MRR: 0.0337117, NDCG: 0.0078693, F1: 0.0066669, HIT_RATE: 0.0998507, ARHR_ALL_HITS: 0.0355216, NOVELTY: 0.0315150, AVERAGE_POPULARITY: 0.0994910, DIVERSITY_MEAN_INTER_LIST: 0.9957985, DIVERSITY_HERFINDAHL: 0.9995633, COVERAGE_ITEM: 0.9878960, COVERAGE_ITEM_HIT: 0.1030131, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.0996689, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5991985, SHANNON_ENTROPY: 11.5231199, RATIO_DIVERSITY_HERFINDAHL: 1.0003798, RATIO_DIVERSITY_GINI: 1.7126140, RATIO_SHANNON_ENTROPY: 1.0656186, RATIO_AVERAGE_POPULARITY: 0.3585140, RATIO_NOVELTY: 0.1067780,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 80 of 500. Elapsed time 4.14 min
# SVD++: Processed 641024 (100.0%) in 3.36 sec. MSE loss 1.22E+00. Sample per second: 191010
# SVD++: Epoch 81 of 500. Elapsed time 4.18 min
# SVD++: Processed 641024 (100.0%) in 2.75 sec. MSE loss 1.22E+00. Sample per second: 233113
# SVD++: Epoch 82 of 500. Elapsed time 4.22 min
# SVD++: Processed 641024 (100.0%) in 3.13 sec. MSE loss 1.22E+00. Sample per second: 204537
# SVD++: Epoch 83 of 500. Elapsed time 4.26 min
# SVD++: Processed 641024 (100.0%) in 2.53 sec. MSE loss 1.22E+00. Sample per second: 253618
# SVD++: Epoch 84 of 500. Elapsed time 4.30 min
# SVD++: Processed 641024 (100.0%) in 2.95 sec. MSE loss 1.22E+00. Sample per second: 217206
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.42 sec. Users per second: 1762
# SVD++: CUTOFF: 10 - PRECISION: 0.0113618, PRECISION_RECALL_MIN_DEN: 0.0122431, RECALL: 0.0049159, MAP: 0.0038657, MAP_MIN_DEN: 0.0041376, MRR: 0.0346901, NDCG: 0.0081704, F1: 0.0068626, HIT_RATE: 0.1025046, ARHR_ALL_HITS: 0.0366237, NOVELTY: 0.0314735, AVERAGE_POPULARITY: 0.1019054, DIVERSITY_MEAN_INTER_LIST: 0.9956930, DIVERSITY_HERFINDAHL: 0.9995528, COVERAGE_ITEM: 0.9871234, COVERAGE_ITEM_HIT: 0.1027556, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1023179, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5962658, SHANNON_ENTROPY: 11.5135324, RATIO_DIVERSITY_HERFINDAHL: 1.0003692, RATIO_DIVERSITY_GINI: 1.7042316, RATIO_SHANNON_ENTROPY: 1.0647320, RATIO_AVERAGE_POPULARITY: 0.3672141, RATIO_NOVELTY: 0.1066374,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 85 of 500. Elapsed time 4.40 min
# SVD++: Processed 641024 (100.0%) in 2.79 sec. MSE loss 1.22E+00. Sample per second: 229846
# SVD++: Epoch 86 of 500. Elapsed time 4.44 min
# SVD++: Processed 641024 (100.0%) in 3.20 sec. MSE loss 1.22E+00. Sample per second: 200019
# SVD++: Epoch 87 of 500. Elapsed time 4.48 min
# SVD++: Processed 641024 (100.0%) in 2.59 sec. MSE loss 1.22E+00. Sample per second: 247752
# SVD++: Epoch 88 of 500. Elapsed time 4.52 min
# SVD++: Processed 641024 (100.0%) in 2.99 sec. MSE loss 1.22E+00. Sample per second: 214249
# SVD++: Epoch 89 of 500. Elapsed time 4.56 min
# SVD++: Processed 641024 (100.0%) in 3.40 sec. MSE loss 1.22E+00. Sample per second: 188759
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.39 sec. Users per second: 1776
# SVD++: CUTOFF: 10 - PRECISION: 0.0117930, PRECISION_RECALL_MIN_DEN: 0.0127015, RECALL: 0.0051679, MAP: 0.0040048, MAP_MIN_DEN: 0.0042880, MRR: 0.0358442, NDCG: 0.0086105, F1: 0.0071866, HIT_RATE: 0.1063195, ARHR_ALL_HITS: 0.0378938, NOVELTY: 0.0314295, AVERAGE_POPULARITY: 0.1044922, DIVERSITY_MEAN_INTER_LIST: 0.9955625, DIVERSITY_HERFINDAHL: 0.9995397, COVERAGE_ITEM: 0.9871234, COVERAGE_ITEM_HIT: 0.1030131, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1061258, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5931294, SHANNON_ENTROPY: 11.5027908, RATIO_DIVERSITY_HERFINDAHL: 1.0003561, RATIO_DIVERSITY_GINI: 1.6952672, RATIO_SHANNON_ENTROPY: 1.0637386, RATIO_AVERAGE_POPULARITY: 0.3765357, RATIO_NOVELTY: 0.1064886,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 90 of 500. Elapsed time 4.65 min
# SVD++: Processed 641024 (100.0%) in 3.20 sec. MSE loss 1.22E+00. Sample per second: 200224
# SVD++: Epoch 91 of 500. Elapsed time 4.69 min
# SVD++: Processed 641024 (100.0%) in 2.61 sec. MSE loss 1.22E+00. Sample per second: 245961
# SVD++: Epoch 92 of 500. Elapsed time 4.73 min
# SVD++: Processed 641024 (100.0%) in 3.01 sec. MSE loss 1.22E+00. Sample per second: 213173
# SVD++: Epoch 93 of 500. Elapsed time 4.77 min
# SVD++: Processed 641024 (100.0%) in 2.40 sec. MSE loss 1.22E+00. Sample per second: 267072
# SVD++: Epoch 94 of 500. Elapsed time 4.81 min
# SVD++: Processed 641024 (100.0%) in 2.82 sec. MSE loss 1.22E+00. Sample per second: 226966
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.39 sec. Users per second: 1776
# SVD++: CUTOFF: 10 - PRECISION: 0.0119423, PRECISION_RECALL_MIN_DEN: 0.0129190, RECALL: 0.0053266, MAP: 0.0040962, MAP_MIN_DEN: 0.0044009, MRR: 0.0367175, NDCG: 0.0088869, F1: 0.0073672, HIT_RATE: 0.1076464, ARHR_ALL_HITS: 0.0387872, NOVELTY: 0.0313861, AVERAGE_POPULARITY: 0.1069886, DIVERSITY_MEAN_INTER_LIST: 0.9954257, DIVERSITY_HERFINDAHL: 0.9995261, COVERAGE_ITEM: 0.9868658, COVERAGE_ITEM_HIT: 0.1030131, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1074503, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5899471, SHANNON_ENTROPY: 11.4919010, RATIO_DIVERSITY_HERFINDAHL: 1.0003424, RATIO_DIVERSITY_GINI: 1.6861718, RATIO_SHANNON_ENTROPY: 1.0627316, RATIO_AVERAGE_POPULARITY: 0.3855316, RATIO_NOVELTY: 0.1063415,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 95 of 500. Elapsed time 4.91 min
# SVD++: Processed 641024 (100.0%) in 2.63 sec. MSE loss 1.22E+00. Sample per second: 243711
# SVD++: Epoch 96 of 500. Elapsed time 4.95 min
# SVD++: Processed 641024 (100.0%) in 3.02 sec. MSE loss 1.22E+00. Sample per second: 212106
# SVD++: Epoch 97 of 500. Elapsed time 4.99 min
# SVD++: Processed 641024 (100.0%) in 2.43 sec. MSE loss 1.22E+00. Sample per second: 263313
# SVD++: Epoch 98 of 500. Elapsed time 5.03 min
# SVD++: Processed 641024 (100.0%) in 2.84 sec. MSE loss 1.22E+00. Sample per second: 225875
# SVD++: Epoch 99 of 500. Elapsed time 5.07 min
# SVD++: Processed 641024 (100.0%) in 3.30 sec. MSE loss 1.22E+00. Sample per second: 194291
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.39 sec. Users per second: 1778
# SVD++: CUTOFF: 10 - PRECISION: 0.0122408, PRECISION_RECALL_MIN_DEN: 0.0132286, RECALL: 0.0054331, MAP: 0.0042088, MAP_MIN_DEN: 0.0045227, MRR: 0.0376665, NDCG: 0.0092121, F1: 0.0075258, HIT_RATE: 0.1101344, ARHR_ALL_HITS: 0.0398246, NOVELTY: 0.0313462, AVERAGE_POPULARITY: 0.1097127, DIVERSITY_MEAN_INTER_LIST: 0.9952712, DIVERSITY_HERFINDAHL: 0.9995106, COVERAGE_ITEM: 0.9868658, COVERAGE_ITEM_HIT: 0.1032707, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1099338, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5865099, SHANNON_ENTROPY: 11.4799315, RATIO_DIVERSITY_HERFINDAHL: 1.0003270, RATIO_DIVERSITY_GINI: 1.6763477, RATIO_SHANNON_ENTROPY: 1.0616247, RATIO_AVERAGE_POPULARITY: 0.3953477, RATIO_NOVELTY: 0.1062062,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 100 of 500. Elapsed time 5.17 min
# SVD++: Processed 641024 (100.0%) in 3.10 sec. MSE loss 1.22E+00. Sample per second: 206513
# SVD++: Epoch 101 of 500. Elapsed time 5.21 min
# SVD++: Processed 641024 (100.0%) in 2.49 sec. MSE loss 1.22E+00. Sample per second: 257340
# SVD++: Epoch 102 of 500. Elapsed time 5.25 min
# SVD++: Processed 641024 (100.0%) in 2.88 sec. MSE loss 1.22E+00. Sample per second: 222197
# SVD++: Epoch 103 of 500. Elapsed time 5.29 min
# SVD++: Processed 641024 (100.0%) in 3.29 sec. MSE loss 1.22E+00. Sample per second: 195111
# SVD++: Epoch 104 of 500. Elapsed time 5.33 min
# SVD++: Processed 641024 (100.0%) in 2.68 sec. MSE loss 1.22E+00. Sample per second: 239050
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.41 sec. Users per second: 1770
# SVD++: CUTOFF: 10 - PRECISION: 0.0125726, PRECISION_RECALL_MIN_DEN: 0.0136255, RECALL: 0.0056543, MAP: 0.0043726, MAP_MIN_DEN: 0.0047138, MRR: 0.0391793, NDCG: 0.0096521, F1: 0.0078005, HIT_RATE: 0.1134517, ARHR_ALL_HITS: 0.0414001, NOVELTY: 0.0313056, AVERAGE_POPULARITY: 0.1126746, DIVERSITY_MEAN_INTER_LIST: 0.9950711, DIVERSITY_HERFINDAHL: 0.9994906, COVERAGE_ITEM: 0.9860932, COVERAGE_ITEM_HIT: 0.1030131, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1132450, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5826623, SHANNON_ENTROPY: 11.4655768, RATIO_DIVERSITY_HERFINDAHL: 1.0003070, RATIO_DIVERSITY_GINI: 1.6653505, RATIO_SHANNON_ENTROPY: 1.0602972, RATIO_AVERAGE_POPULARITY: 0.4060209, RATIO_NOVELTY: 0.1060686,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 105 of 500. Elapsed time 5.42 min
# SVD++: Processed 641024 (100.0%) in 2.51 sec. MSE loss 1.22E+00. Sample per second: 255571
# SVD++: Epoch 106 of 500. Elapsed time 5.46 min
# SVD++: Processed 641024 (100.0%) in 2.91 sec. MSE loss 1.22E+00. Sample per second: 220012
# SVD++: Epoch 107 of 500. Elapsed time 5.50 min
# SVD++: Processed 641024 (100.0%) in 3.39 sec. MSE loss 1.21E+00. Sample per second: 188839
# SVD++: Epoch 108 of 500. Elapsed time 5.55 min
# SVD++: Processed 641024 (100.0%) in 2.80 sec. MSE loss 1.21E+00. Sample per second: 229137
# SVD++: Epoch 109 of 500. Elapsed time 5.59 min
# SVD++: Processed 641024 (100.0%) in 3.20 sec. MSE loss 1.22E+00. Sample per second: 200273
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.38 sec. Users per second: 1781
# SVD++: CUTOFF: 10 - PRECISION: 0.0128877, PRECISION_RECALL_MIN_DEN: 0.0140170, RECALL: 0.0059028, MAP: 0.0045198, MAP_MIN_DEN: 0.0048767, MRR: 0.0404236, NDCG: 0.0100412, F1: 0.0080971, HIT_RATE: 0.1159396, ARHR_ALL_HITS: 0.0427407, NOVELTY: 0.0312530, AVERAGE_POPULARITY: 0.1159073, DIVERSITY_MEAN_INTER_LIST: 0.9948380, DIVERSITY_HERFINDAHL: 0.9994673, COVERAGE_ITEM: 0.9858357, COVERAGE_ITEM_HIT: 0.1024981, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1157285, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5786844, SHANNON_ENTROPY: 11.4501379, RATIO_DIVERSITY_HERFINDAHL: 1.0002836, RATIO_DIVERSITY_GINI: 1.6539808, RATIO_SHANNON_ENTROPY: 1.0588695, RATIO_AVERAGE_POPULARITY: 0.4176699, RATIO_NOVELTY: 0.1058905,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 110 of 500. Elapsed time 5.68 min
# SVD++: Processed 641024 (100.0%) in 3.02 sec. MSE loss 1.22E+00. Sample per second: 211996
# SVD++: Epoch 111 of 500. Elapsed time 5.72 min
# SVD++: Processed 641024 (100.0%) in 2.43 sec. MSE loss 1.22E+00. Sample per second: 263945
# SVD++: Epoch 112 of 500. Elapsed time 5.76 min
# SVD++: Processed 641024 (100.0%) in 2.84 sec. MSE loss 1.22E+00. Sample per second: 225668
# SVD++: Epoch 113 of 500. Elapsed time 5.80 min
# SVD++: Processed 641024 (100.0%) in 3.23 sec. MSE loss 1.22E+00. Sample per second: 198155
# SVD++: Epoch 114 of 500. Elapsed time 5.84 min
# SVD++: Processed 641024 (100.0%) in 2.62 sec. MSE loss 1.22E+00. Sample per second: 244630
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.36 sec. Users per second: 1792
# SVD++: CUTOFF: 10 - PRECISION: 0.0135014, PRECISION_RECALL_MIN_DEN: 0.0146906, RECALL: 0.0062002, MAP: 0.0046997, MAP_MIN_DEN: 0.0050817, MRR: 0.0418260, NDCG: 0.0106276, F1: 0.0084979, HIT_RATE: 0.1210814, ARHR_ALL_HITS: 0.0443158, NOVELTY: 0.0311880, AVERAGE_POPULARITY: 0.1194387, DIVERSITY_MEAN_INTER_LIST: 0.9945612, DIVERSITY_HERFINDAHL: 0.9994396, COVERAGE_ITEM: 0.9860932, COVERAGE_ITEM_HIT: 0.1022405, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1208609, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5745927, SHANNON_ENTROPY: 11.4329683, RATIO_DIVERSITY_HERFINDAHL: 1.0002559, RATIO_DIVERSITY_GINI: 1.6422860, RATIO_SHANNON_ENTROPY: 1.0572817, RATIO_AVERAGE_POPULARITY: 0.4303953, RATIO_NOVELTY: 0.1056702,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 115 of 500. Elapsed time 5.94 min
# SVD++: Processed 641024 (100.0%) in 2.41 sec. MSE loss 1.22E+00. Sample per second: 265890
# SVD++: Epoch 116 of 500. Elapsed time 5.98 min
# SVD++: Processed 641024 (100.0%) in 2.81 sec. MSE loss 1.22E+00. Sample per second: 228261
# SVD++: Epoch 117 of 500. Elapsed time 6.02 min
# SVD++: Processed 641024 (100.0%) in 3.22 sec. MSE loss 1.21E+00. Sample per second: 198810
# SVD++: Epoch 118 of 500. Elapsed time 6.06 min
# SVD++: Processed 641024 (100.0%) in 2.66 sec. MSE loss 1.22E+00. Sample per second: 241014
# SVD++: Epoch 119 of 500. Elapsed time 6.10 min
# SVD++: Processed 641024 (100.0%) in 3.34 sec. MSE loss 1.22E+00. Sample per second: 192001
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.38 sec. Users per second: 1786
# SVD++: CUTOFF: 10 - PRECISION: 0.0139658, PRECISION_RECALL_MIN_DEN: 0.0151758, RECALL: 0.0064445, MAP: 0.0048767, MAP_MIN_DEN: 0.0052783, MRR: 0.0433765, NDCG: 0.0111462, F1: 0.0088193, HIT_RATE: 0.1253939, ARHR_ALL_HITS: 0.0459634, NOVELTY: 0.0311363, AVERAGE_POPULARITY: 0.1226984, DIVERSITY_MEAN_INTER_LIST: 0.9942480, DIVERSITY_HERFINDAHL: 0.9994083, COVERAGE_ITEM: 0.9855782, COVERAGE_ITEM_HIT: 0.1019830, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1251656, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5708268, SHANNON_ENTROPY: 11.4159924, RATIO_DIVERSITY_HERFINDAHL: 1.0002246, RATIO_DIVERSITY_GINI: 1.6315227, RATIO_SHANNON_ENTROPY: 1.0557118, RATIO_AVERAGE_POPULARITY: 0.4421416, RATIO_NOVELTY: 0.1054951,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 120 of 500. Elapsed time 6.20 min
# SVD++: Processed 641024 (100.0%) in 3.13 sec. MSE loss 1.21E+00. Sample per second: 204848
# SVD++: Epoch 121 of 500. Elapsed time 6.24 min
# SVD++: Processed 641024 (100.0%) in 2.53 sec. MSE loss 1.21E+00. Sample per second: 253090
# SVD++: Epoch 122 of 500. Elapsed time 6.28 min
# SVD++: Processed 641024 (100.0%) in 2.94 sec. MSE loss 1.22E+00. Sample per second: 218034
# SVD++: Epoch 123 of 500. Elapsed time 6.32 min
# SVD++: Processed 641024 (100.0%) in 3.33 sec. MSE loss 1.22E+00. Sample per second: 192288
# SVD++: Epoch 124 of 500. Elapsed time 6.36 min
# SVD++: Processed 641024 (100.0%) in 2.73 sec. MSE loss 1.22E+00. Sample per second: 234709
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.37 sec. Users per second: 1790
# SVD++: CUTOFF: 10 - PRECISION: 0.0144966, PRECISION_RECALL_MIN_DEN: 0.0159282, RECALL: 0.0069111, MAP: 0.0050945, MAP_MIN_DEN: 0.0055370, MRR: 0.0453411, NDCG: 0.0117411, F1: 0.0093599, HIT_RATE: 0.1302040, ARHR_ALL_HITS: 0.0480315, NOVELTY: 0.0310794, AVERAGE_POPULARITY: 0.1261372, DIVERSITY_MEAN_INTER_LIST: 0.9939121, DIVERSITY_HERFINDAHL: 0.9993747, COVERAGE_ITEM: 0.9848056, COVERAGE_ITEM_HIT: 0.1022405, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1299669, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5664730, SHANNON_ENTROPY: 11.3972441, RATIO_DIVERSITY_HERFINDAHL: 1.0001910, RATIO_DIVERSITY_GINI: 1.6190788, RATIO_SHANNON_ENTROPY: 1.0539780, RATIO_AVERAGE_POPULARITY: 0.4545332, RATIO_NOVELTY: 0.1053024,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 125 of 500. Elapsed time 6.46 min
# SVD++: Processed 641024 (100.0%) in 2.51 sec. MSE loss 1.22E+00. Sample per second: 254988
# SVD++: Epoch 126 of 500. Elapsed time 6.50 min
# SVD++: Processed 641024 (100.0%) in 2.91 sec. MSE loss 1.21E+00. Sample per second: 220297
# SVD++: Epoch 127 of 500. Elapsed time 6.54 min
# SVD++: Processed 641024 (100.0%) in 3.31 sec. MSE loss 1.21E+00. Sample per second: 193899
# SVD++: Epoch 128 of 500. Elapsed time 6.58 min
# SVD++: Processed 641024 (100.0%) in 2.75 sec. MSE loss 1.22E+00. Sample per second: 232275
# SVD++: Epoch 129 of 500. Elapsed time 6.62 min
# SVD++: Processed 641024 (100.0%) in 3.18 sec. MSE loss 1.21E+00. Sample per second: 201759
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.38 sec. Users per second: 1786
# SVD++: CUTOFF: 10 - PRECISION: 0.0149942, PRECISION_RECALL_MIN_DEN: 0.0165524, RECALL: 0.0072784, MAP: 0.0053342, MAP_MIN_DEN: 0.0058537, MRR: 0.0474125, NDCG: 0.0124269, F1: 0.0097998, HIT_RATE: 0.1343506, ARHR_ALL_HITS: 0.0502474, NOVELTY: 0.0310160, AVERAGE_POPULARITY: 0.1300192, DIVERSITY_MEAN_INTER_LIST: 0.9934937, DIVERSITY_HERFINDAHL: 0.9993329, COVERAGE_ITEM: 0.9842905, COVERAGE_ITEM_HIT: 0.1019830, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1341060, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5618130, SHANNON_ENTROPY: 11.3762266, RATIO_DIVERSITY_HERFINDAHL: 1.0001491, RATIO_DIVERSITY_GINI: 1.6057595, RATIO_SHANNON_ENTROPY: 1.0520344, RATIO_AVERAGE_POPULARITY: 0.4685219, RATIO_NOVELTY: 0.1050876,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 130 of 500. Elapsed time 6.72 min
# SVD++: Processed 641024 (100.0%) in 2.96 sec. MSE loss 1.21E+00. Sample per second: 216675
# SVD++: Epoch 131 of 500. Elapsed time 6.76 min
# SVD++: Processed 641024 (100.0%) in 3.37 sec. MSE loss 1.22E+00. Sample per second: 190021
# SVD++: Epoch 132 of 500. Elapsed time 6.80 min
# SVD++: Processed 641024 (100.0%) in 2.79 sec. MSE loss 1.21E+00. Sample per second: 229878
# SVD++: Epoch 133 of 500. Elapsed time 6.84 min
# SVD++: Processed 641024 (100.0%) in 3.21 sec. MSE loss 1.21E+00. Sample per second: 199559
# SVD++: Epoch 134 of 500. Elapsed time 6.88 min
# SVD++: Processed 641024 (100.0%) in 2.61 sec. MSE loss 1.21E+00. Sample per second: 245599
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.38 sec. Users per second: 1782
# SVD++: CUTOFF: 10 - PRECISION: 0.0154420, PRECISION_RECALL_MIN_DEN: 0.0171412, RECALL: 0.0076690, MAP: 0.0055170, MAP_MIN_DEN: 0.0060745, MRR: 0.0491664, NDCG: 0.0129871, F1: 0.0102483, HIT_RATE: 0.1391607, ARHR_ALL_HITS: 0.0520282, NOVELTY: 0.0309381, AVERAGE_POPULARITY: 0.1344584, DIVERSITY_MEAN_INTER_LIST: 0.9930001, DIVERSITY_HERFINDAHL: 0.9992835, COVERAGE_ITEM: 0.9840330, COVERAGE_ITEM_HIT: 0.1012104, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1389073, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5566399, SHANNON_ENTROPY: 11.3519613, RATIO_DIVERSITY_HERFINDAHL: 1.0000997, RATIO_DIVERSITY_GINI: 1.5909739, RATIO_SHANNON_ENTROPY: 1.0497904, RATIO_AVERAGE_POPULARITY: 0.4845185, RATIO_NOVELTY: 0.1048234,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 135 of 500. Elapsed time 6.97 min
# SVD++: Processed 641024 (100.0%) in 2.41 sec. MSE loss 1.21E+00. Sample per second: 265927
# SVD++: Epoch 136 of 500. Elapsed time 7.01 min
# SVD++: Processed 641024 (100.0%) in 2.81 sec. MSE loss 1.21E+00. Sample per second: 228375
# SVD++: Epoch 137 of 500. Elapsed time 7.05 min
# SVD++: Processed 641024 (100.0%) in 3.24 sec. MSE loss 1.22E+00. Sample per second: 197627
# SVD++: Epoch 138 of 500. Elapsed time 7.09 min
# SVD++: Processed 641024 (100.0%) in 2.67 sec. MSE loss 1.21E+00. Sample per second: 240097
# SVD++: Epoch 139 of 500. Elapsed time 7.13 min
# SVD++: Processed 641024 (100.0%) in 3.06 sec. MSE loss 1.22E+00. Sample per second: 209210
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.40 sec. Users per second: 1776
# SVD++: CUTOFF: 10 - PRECISION: 0.0160391, PRECISION_RECALL_MIN_DEN: 0.0177816, RECALL: 0.0080291, MAP: 0.0058012, MAP_MIN_DEN: 0.0063944, MRR: 0.0516047, NDCG: 0.0137100, F1: 0.0107012, HIT_RATE: 0.1441367, ARHR_ALL_HITS: 0.0546637, NOVELTY: 0.0308675, AVERAGE_POPULARITY: 0.1388887, DIVERSITY_MEAN_INTER_LIST: 0.9924659, DIVERSITY_HERFINDAHL: 0.9992301, COVERAGE_ITEM: 0.9840330, COVERAGE_ITEM_HIT: 0.1004378, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1438742, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5511358, SHANNON_ENTROPY: 11.3261810, RATIO_DIVERSITY_HERFINDAHL: 1.0000463, RATIO_DIVERSITY_GINI: 1.5752422, RATIO_SHANNON_ENTROPY: 1.0474064, RATIO_AVERAGE_POPULARITY: 0.5004831, RATIO_NOVELTY: 0.1045843,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 140 of 500. Elapsed time 7.23 min
# SVD++: Processed 641024 (100.0%) in 2.88 sec. MSE loss 1.21E+00. Sample per second: 222843
# SVD++: Epoch 141 of 500. Elapsed time 7.27 min
# SVD++: Processed 641024 (100.0%) in 3.29 sec. MSE loss 1.21E+00. Sample per second: 194649
# SVD++: Epoch 142 of 500. Elapsed time 7.31 min
# SVD++: Processed 641024 (100.0%) in 2.71 sec. MSE loss 1.21E+00. Sample per second: 236773
# SVD++: Epoch 143 of 500. Elapsed time 7.35 min
# SVD++: Processed 641024 (100.0%) in 3.10 sec. MSE loss 1.21E+00. Sample per second: 206710
# SVD++: Epoch 144 of 500. Elapsed time 7.39 min
# SVD++: Processed 641024 (100.0%) in 2.50 sec. MSE loss 1.21E+00. Sample per second: 256575
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.38 sec. Users per second: 1782
# SVD++: CUTOFF: 10 - PRECISION: 0.0165533, PRECISION_RECALL_MIN_DEN: 0.0183747, RECALL: 0.0083677, MAP: 0.0060598, MAP_MIN_DEN: 0.0066917, MRR: 0.0537730, NDCG: 0.0143555, F1: 0.0111162, HIT_RATE: 0.1481174, ARHR_ALL_HITS: 0.0570233, NOVELTY: 0.0308017, AVERAGE_POPULARITY: 0.1431332, DIVERSITY_MEAN_INTER_LIST: 0.9919131, DIVERSITY_HERFINDAHL: 0.9991749, COVERAGE_ITEM: 0.9840330, COVERAGE_ITEM_HIT: 0.1009529, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1478477, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5462422, SHANNON_ENTROPY: 11.3016463, RATIO_DIVERSITY_HERFINDAHL: 0.9999910, RATIO_DIVERSITY_GINI: 1.5612555, RATIO_SHANNON_ENTROPY: 1.0451375, RATIO_AVERAGE_POPULARITY: 0.5157778, RATIO_NOVELTY: 0.1043613,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 145 of 500. Elapsed time 7.49 min
# SVD++: Processed 641024 (100.0%) in 3.29 sec. MSE loss 1.21E+00. Sample per second: 194857
# SVD++: Epoch 146 of 500. Elapsed time 7.53 min
# SVD++: Processed 641024 (100.0%) in 2.69 sec. MSE loss 1.22E+00. Sample per second: 238722
# SVD++: Epoch 147 of 500. Elapsed time 7.57 min
# SVD++: Processed 641024 (100.0%) in 3.10 sec. MSE loss 1.21E+00. Sample per second: 206673
# SVD++: Epoch 148 of 500. Elapsed time 7.61 min
# SVD++: Processed 641024 (100.0%) in 2.49 sec. MSE loss 1.21E+00. Sample per second: 257746
# SVD++: Epoch 149 of 500. Elapsed time 7.65 min
# SVD++: Processed 641024 (100.0%) in 2.92 sec. MSE loss 1.21E+00. Sample per second: 218902
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 3.38 sec. Users per second: 1781
# SVD++: CUTOFF: 10 - PRECISION: 0.0171173, PRECISION_RECALL_MIN_DEN: 0.0190189, RECALL: 0.0086965, MAP: 0.0063080, MAP_MIN_DEN: 0.0069726, MRR: 0.0558406, NDCG: 0.0150419, F1: 0.0115334, HIT_RATE: 0.1524299, ARHR_ALL_HITS: 0.0592621, NOVELTY: 0.0307347, AVERAGE_POPULARITY: 0.1474654, DIVERSITY_MEAN_INTER_LIST: 0.9913078, DIVERSITY_HERFINDAHL: 0.9991143, COVERAGE_ITEM: 0.9835179, COVERAGE_ITEM_HIT: 0.1001803, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.1521523, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.5406945, SHANNON_ENTROPY: 11.2745069, RATIO_DIVERSITY_HERFINDAHL: 0.9999304, RATIO_DIVERSITY_GINI: 1.5453991, RATIO_SHANNON_ENTROPY: 1.0426277, RATIO_AVERAGE_POPULARITY: 0.5313889, RATIO_NOVELTY: 0.1041343,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 150 of 500. Elapsed time 7.74 min
# SVD++: Processed 641024 (100.0%) in 2.76 sec. MSE loss 1.21E+00. Sample per second: 232577
# SVD++: Epoch 151 of 500. Elapsed time 7.79 min
# SVD++: Processed 641024 (100.0%) in 3.17 sec. MSE loss 1.21E+00. Sample per second: 202145
# SVD++: Epoch 152 of 500. Elapsed time 7.83 min
# SVD++: Processed 641024 (100.0%) in 2.56 sec. MSE loss 1.21E+00. Sample per second: 250816
# SVD++: Epoch 153 of 500. Elapsed time 7.87 min
# SVD++: Processed 641024 (100.0%) in 2.97 sec. MSE loss 1.21E+00. Sample per second: 215905
# SVD++: Epoch 154 of 500. Elapsed time 7.91 min
# ...
# SVD++: Processed 640512 (100.0%) in 0.87 sec. MSE loss 8.37E+00. Sample per second: 732574
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.42 sec. Users per second: 1113
# SVD++: CUTOFF: 10 - PRECISION: 0.1139658, PRECISION_RECALL_MIN_DEN: 0.1257907, RECALL: 0.0581222, MAP: 0.0531933, MAP_MIN_DEN: 0.0576127, MRR: 0.2649188, NDCG: 0.1057795, F1: 0.0769832, HIT_RATE: 0.5821861, ARHR_ALL_HITS: 0.3692919, NOVELTY: 0.0221693, AVERAGE_POPULARITY: 0.7543881, DIVERSITY_MEAN_INTER_LIST: 0.5366549, DIVERSITY_HERFINDAHL: 0.9536566, COVERAGE_ITEM: 0.0146794, COVERAGE_ITEM_HIT: 0.0118465, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.5811258, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0052450, SHANNON_ENTROPY: 4.6140859, RATIO_DIVERSITY_HERFINDAHL: 0.9544355, RATIO_DIVERSITY_GINI: 0.0149911, RATIO_SHANNON_ENTROPY: 0.4266948, RATIO_AVERAGE_POPULARITY: 2.7184238, RATIO_NOVELTY: 0.0751134,
#
# SVD++: Epoch 210 of 500. Elapsed time 5.23 min
# SVD++: Processed 640512 (100.0%) in 0.58 sec. MSE loss 8.36E+00. Sample per second: 1095447
# SVD++: Epoch 211 of 500. Elapsed time 5.23 min
# SVD++: Processed 640512 (100.0%) in 0.96 sec. MSE loss 8.35E+00. Sample per second: 669137
# SVD++: Epoch 212 of 500. Elapsed time 5.24 min
# SVD++: Processed 640512 (100.0%) in 1.39 sec. MSE loss 8.34E+00. Sample per second: 460739
# SVD++: Epoch 213 of 500. Elapsed time 5.25 min
# SVD++: Processed 640512 (100.0%) in 0.82 sec. MSE loss 8.33E+00. Sample per second: 778477
# SVD++: Epoch 214 of 500. Elapsed time 5.25 min
# SVD++: Processed 640512 (100.0%) in 1.26 sec. MSE loss 8.32E+00. Sample per second: 510149
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.83 sec. Users per second: 1035
# SVD++: CUTOFF: 10 - PRECISION: 0.1140156, PRECISION_RECALL_MIN_DEN: 0.1258695, RECALL: 0.0581874, MAP: 0.0532237, MAP_MIN_DEN: 0.0576508, MRR: 0.2650766, NDCG: 0.1058940, F1: 0.0770517, HIT_RATE: 0.5821861, ARHR_ALL_HITS: 0.3694639, NOVELTY: 0.0221686, AVERAGE_POPULARITY: 0.7545124, DIVERSITY_MEAN_INTER_LIST: 0.5358596, DIVERSITY_HERFINDAHL: 0.9535771, COVERAGE_ITEM: 0.0144218, COVERAGE_ITEM_HIT: 0.0118465, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.5811258, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0052360, SHANNON_ENTROPY: 4.6115971, RATIO_DIVERSITY_HERFINDAHL: 0.9543559, RATIO_DIVERSITY_GINI: 0.0149655, RATIO_SHANNON_ENTROPY: 0.4264647, RATIO_AVERAGE_POPULARITY: 2.7188717, RATIO_NOVELTY: 0.0751111,
#
# SVD++: Epoch 215 of 500. Elapsed time 5.36 min
# SVD++: Processed 640512 (100.0%) in 0.53 sec. MSE loss 8.30E+00. Sample per second: 1214436
# SVD++: Epoch 216 of 500. Elapsed time 5.37 min
# SVD++: Processed 640512 (100.0%) in 0.97 sec. MSE loss 8.28E+00. Sample per second: 660204
# SVD++: Epoch 217 of 500. Elapsed time 5.37 min
# SVD++: Processed 640512 (100.0%) in 1.40 sec. MSE loss 8.28E+00. Sample per second: 456411
# SVD++: Epoch 218 of 500. Elapsed time 5.38 min
# SVD++: Processed 640512 (100.0%) in 0.85 sec. MSE loss 8.27E+00. Sample per second: 757026
# SVD++: Epoch 219 of 500. Elapsed time 5.39 min
# SVD++: Processed 640512 (100.0%) in 1.15 sec. MSE loss 8.25E+00. Sample per second: 557624
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.26 sec. Users per second: 1147
# SVD++: CUTOFF: 10 - PRECISION: 0.1140985, PRECISION_RECALL_MIN_DEN: 0.1259708, RECALL: 0.0582750, MAP: 0.0532145, MAP_MIN_DEN: 0.0576456, MRR: 0.2652480, NDCG: 0.1059575, F1: 0.0771475, HIT_RATE: 0.5828496, ARHR_ALL_HITS: 0.3695421, NOVELTY: 0.0221683, AVERAGE_POPULARITY: 0.7545665, DIVERSITY_MEAN_INTER_LIST: 0.5354174, DIVERSITY_HERFINDAHL: 0.9535329, COVERAGE_ITEM: 0.0144218, COVERAGE_ITEM_HIT: 0.0118465, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.5817881, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0052306, SHANNON_ENTROPY: 4.6095387, RATIO_DIVERSITY_HERFINDAHL: 0.9543117, RATIO_DIVERSITY_GINI: 0.0149500, RATIO_SHANNON_ENTROPY: 0.4262743, RATIO_AVERAGE_POPULARITY: 2.7190666, RATIO_NOVELTY: 0.0751100,
#
# SVD++: Epoch 220 of 500. Elapsed time 5.48 min
# SVD++: Processed 640512 (100.0%) in 0.85 sec. MSE loss 8.25E+00. Sample per second: 747215
# SVD++: Epoch 221 of 500. Elapsed time 5.49 min
# SVD++: Processed 640512 (100.0%) in 1.28 sec. MSE loss 8.23E+00. Sample per second: 499710
# SVD++: Epoch 222 of 500. Elapsed time 5.50 min
# SVD++: Processed 640512 (100.0%) in 0.72 sec. MSE loss 8.22E+00. Sample per second: 886509
# SVD++: Epoch 223 of 500. Elapsed time 5.50 min
# SVD++: Processed 640512 (100.0%) in 1.16 sec. MSE loss 8.21E+00. Sample per second: 553529
# SVD++: Epoch 224 of 500. Elapsed time 5.51 min
# SVD++: Processed 640512 (100.0%) in 0.59 sec. MSE loss 8.19E+00. Sample per second: 1085380
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.09 sec. Users per second: 1184
# SVD++: CUTOFF: 10 - PRECISION: 0.1142312, PRECISION_RECALL_MIN_DEN: 0.1260998, RECALL: 0.0583348, MAP: 0.0532570, MAP_MIN_DEN: 0.0576814, MRR: 0.2652577, NDCG: 0.1059934, F1: 0.0772302, HIT_RATE: 0.5828496, ARHR_ALL_HITS: 0.3697252, NOVELTY: 0.0221677, AVERAGE_POPULARITY: 0.7546857, DIVERSITY_MEAN_INTER_LIST: 0.5347816, DIVERSITY_HERFINDAHL: 0.9534693, COVERAGE_ITEM: 0.0144218, COVERAGE_ITEM_HIT: 0.0118465, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.5817881, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0052235, SHANNON_ENTROPY: 4.6078122, RATIO_DIVERSITY_HERFINDAHL: 0.9542481, RATIO_DIVERSITY_GINI: 0.0149296, RATIO_SHANNON_ENTROPY: 0.4261147, RATIO_AVERAGE_POPULARITY: 2.7194961, RATIO_NOVELTY: 0.0751079,
#
# SVD++: Convergence reached! Terminating at epoch 225. Best value for 'MAP' at epoch 200 is 0.0533. Elapsed time 5.60 min
# SVD++: Epoch 225 of 500. Elapsed time 5.60 min
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.70 sec. Users per second: 1058
# [I 2023-11-25 12:30:38,401] Trial 48 finished with value: 0.05326087271310378 and parameters: {'num_factors': 1, 'sgd_mode': 'adagrad', 'batch_size': 512, 'item_reg': 0.007394509272837415, 'user_reg': 1.5110447211782247e-05, 'learning_rate': 0.0005929594846377632}. Best is trial 22 with value: 0.05505480784673042.
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 240 ( 6.2%) items with no interactions.
# SVD++: Processed 640256 (100.0%) in 4.56 sec. MSE loss 7.82E+00. Sample per second: 140558
# SVD++: Epoch 1 of 500. Elapsed time 4.06 sec
# SVD++: Processed 640256 (100.0%) in 5.14 sec. MSE loss 1.69E+00. Sample per second: 124662
# SVD++: Epoch 2 of 500. Elapsed time 8.63 sec
# SVD++: Processed 640256 (100.0%) in 4.27 sec. MSE loss 1.05E+00. Sample per second: 149959
# SVD++: Epoch 3 of 500. Elapsed time 12.77 sec
# SVD++: Processed 640256 (100.0%) in 4.86 sec. MSE loss 9.94E-01. Sample per second: 131747
# SVD++: Epoch 4 of 500. Elapsed time 17.37 sec
# SVD++: Processed 640256 (100.0%) in 5.40 sec. MSE loss 9.45E-01. Sample per second: 118570
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.20 sec. Users per second: 1160
# SVD++: CUTOFF: 10 - PRECISION: 0.0919887, PRECISION_RECALL_MIN_DEN: 0.1023975, RECALL: 0.0478214, MAP: 0.0405104, MAP_MIN_DEN: 0.0442245, MRR: 0.2153592, NDCG: 0.0904097, F1: 0.0629286, HIT_RATE: 0.5166694, ARHR_ALL_HITS: 0.2915592, NOVELTY: 0.0229453, AVERAGE_POPULARITY: 0.6296262, DIVERSITY_MEAN_INTER_LIST: 0.5604029, DIVERSITY_HERFINDAHL: 0.9560310, COVERAGE_ITEM: 0.0254958, COVERAGE_ITEM_HIT: 0.0193150, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.5157285, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0060575, SHANNON_ENTROPY: 4.9289920, RATIO_DIVERSITY_HERFINDAHL: 0.9568119, RATIO_DIVERSITY_GINI: 0.0173133, RATIO_SHANNON_ENTROPY: 0.4558163, RATIO_AVERAGE_POPULARITY: 2.2688464, RATIO_NOVELTY: 0.0777425,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 5 of 500. Elapsed time 27.11 sec
# SVD++: Processed 640256 (100.0%) in 5.14 sec. MSE loss 9.02E-01. Sample per second: 124602
# SVD++: Epoch 6 of 500. Elapsed time 31.64 sec
# SVD++: Processed 640256 (100.0%) in 4.24 sec. MSE loss 8.62E-01. Sample per second: 150998
# SVD++: Epoch 7 of 500. Elapsed time 35.74 sec
# SVD++: Processed 640256 (100.0%) in 4.81 sec. MSE loss 8.22E-01. Sample per second: 133165
# SVD++: Epoch 8 of 500. Elapsed time 40.31 sec
# SVD++: Processed 640256 (100.0%) in 4.84 sec. MSE loss 7.86E-01. Sample per second: 132227
# SVD++: Epoch 9 of 500. Elapsed time 44.34 sec
# SVD++: Processed 640256 (100.0%) in 5.26 sec. MSE loss 7.54E-01. Sample per second: 121671
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.09 sec. Users per second: 1183
# SVD++: CUTOFF: 10 - PRECISION: 0.0760159, PRECISION_RECALL_MIN_DEN: 0.0843903, RECALL: 0.0391134, MAP: 0.0335638, MAP_MIN_DEN: 0.0367153, MRR: 0.1994537, NDCG: 0.0775965, F1: 0.0516504, HIT_RATE: 0.4582850, ARHR_ALL_HITS: 0.2562989, NOVELTY: 0.0238476, AVERAGE_POPULARITY: 0.5184228, DIVERSITY_MEAN_INTER_LIST: 0.7850799, DIVERSITY_HERFINDAHL: 0.9784950, COVERAGE_ITEM: 0.0628380, COVERAGE_ITEM_HIT: 0.0329642, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.4574503, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0132526, SHANNON_ENTROPY: 6.0858021, RATIO_DIVERSITY_HERFINDAHL: 0.9792942, RATIO_DIVERSITY_GINI: 0.0378782, RATIO_SHANNON_ENTROPY: 0.5627941, RATIO_AVERAGE_POPULARITY: 1.8681270, RATIO_NOVELTY: 0.0807997,
#
# SVD++: Epoch 10 of 500. Elapsed time 53.87 sec
# SVD++: Processed 640256 (100.0%) in 4.86 sec. MSE loss 7.20E-01. Sample per second: 131831
# SVD++: Epoch 11 of 500. Elapsed time 58.35 sec
# SVD++: Processed 640256 (100.0%) in 5.02 sec. MSE loss 6.89E-01. Sample per second: 127531
# SVD++: Epoch 12 of 500. Elapsed time 1.04 min
# SVD++: Processed 640256 (100.0%) in 4.35 sec. MSE loss 6.65E-01. Sample per second: 147127
# SVD++: Epoch 13 of 500. Elapsed time 1.11 min
# SVD++: Processed 640256 (100.0%) in 4.76 sec. MSE loss 6.42E-01. Sample per second: 134437
# SVD++: Epoch 14 of 500. Elapsed time 1.19 min
# SVD++: Processed 640256 (100.0%) in 4.69 sec. MSE loss 6.20E-01. Sample per second: 136371
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.67 sec. Users per second: 1064
# SVD++: CUTOFF: 10 - PRECISION: 0.0706917, PRECISION_RECALL_MIN_DEN: 0.0779918, RECALL: 0.0357867, MAP: 0.0310559, MAP_MIN_DEN: 0.0336590, MRR: 0.1929295, NDCG: 0.0726538, F1: 0.0475180, HIT_RATE: 0.4398739, ARHR_ALL_HITS: 0.2427172, NOVELTY: 0.0242589, AVERAGE_POPULARITY: 0.4754676, DIVERSITY_MEAN_INTER_LIST: 0.8649088, DIVERSITY_HERFINDAHL: 0.9864765, COVERAGE_ITEM: 0.0978625, COVERAGE_ITEM_HIT: 0.0468710, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.4390728, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0214684, SHANNON_ENTROPY: 6.7889294, RATIO_DIVERSITY_HERFINDAHL: 0.9872823, RATIO_DIVERSITY_GINI: 0.0613605, RATIO_SHANNON_ENTROPY: 0.6278169, RATIO_AVERAGE_POPULARITY: 1.7133390, RATIO_NOVELTY: 0.0821932,
#
# SVD++: Epoch 15 of 500. Elapsed time 1.35 min
# SVD++: Processed 640256 (100.0%) in 4.39 sec. MSE loss 5.97E-01. Sample per second: 145974
# SVD++: Epoch 16 of 500. Elapsed time 1.41 min
# SVD++: Processed 640256 (100.0%) in 4.85 sec. MSE loss 5.81E-01. Sample per second: 132114
# SVD++: Epoch 17 of 500. Elapsed time 1.49 min
# SVD++: Processed 640256 (100.0%) in 4.89 sec. MSE loss 5.65E-01. Sample per second: 131006
# SVD++: Epoch 18 of 500. Elapsed time 1.56 min
# SVD++: Processed 640256 (100.0%) in 5.44 sec. MSE loss 5.49E-01. Sample per second: 117757
# SVD++: Epoch 19 of 500. Elapsed time 1.63 min
# SVD++: Processed 640256 (100.0%) in 4.84 sec. MSE loss 5.36E-01. Sample per second: 132155
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.19 sec. Users per second: 1162
# SVD++: CUTOFF: 10 - PRECISION: 0.0685354, PRECISION_RECALL_MIN_DEN: 0.0746587, RECALL: 0.0330257, MAP: 0.0303656, MAP_MIN_DEN: 0.0326190, MRR: 0.1892737, NDCG: 0.0699040, F1: 0.0445728, HIT_RATE: 0.4294244, ARHR_ALL_HITS: 0.2377866, NOVELTY: 0.0244702, AVERAGE_POPULARITY: 0.4535806, DIVERSITY_MEAN_INTER_LIST: 0.9001965, DIVERSITY_HERFINDAHL: 0.9900047, COVERAGE_ITEM: 0.1326294, COVERAGE_ITEM_HIT: 0.0558846, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.4286424, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0295187, SHANNON_ENTROPY: 7.2481501, RATIO_DIVERSITY_HERFINDAHL: 0.9908133, RATIO_DIVERSITY_GINI: 0.0843695, RATIO_SHANNON_ENTROPY: 0.6702841, RATIO_AVERAGE_POPULARITY: 1.6344696, RATIO_NOVELTY: 0.0829091,
#
# SVD++: Epoch 20 of 500. Elapsed time 1.79 min
# SVD++: Processed 640256 (100.0%) in 4.54 sec. MSE loss 5.24E-01. Sample per second: 141113
# SVD++: Epoch 21 of 500. Elapsed time 1.87 min
# SVD++: Processed 640256 (100.0%) in 4.47 sec. MSE loss 5.12E-01. Sample per second: 143246
# SVD++: Epoch 22 of 500. Elapsed time 1.93 min
# SVD++: Processed 640256 (100.0%) in 4.98 sec. MSE loss 5.02E-01. Sample per second: 128573
# SVD++: Epoch 23 of 500. Elapsed time 2.01 min
# SVD++: Processed 640256 (100.0%) in 4.92 sec. MSE loss 4.90E-01. Sample per second: 130095
# SVD++: Epoch 24 of 500. Elapsed time 2.07 min
# SVD++: Processed 640256 (100.0%) in 5.42 sec. MSE loss 4.79E-01. Sample per second: 118140
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.20 sec. Users per second: 1160
# SVD++: CUTOFF: 10 - PRECISION: 0.0667441, PRECISION_RECALL_MIN_DEN: 0.0723704, RECALL: 0.0311871, MAP: 0.0288539, MAP_MIN_DEN: 0.0308127, MRR: 0.1792446, NDCG: 0.0664727, F1: 0.0425106, HIT_RATE: 0.4214629, ARHR_ALL_HITS: 0.2252685, NOVELTY: 0.0246992, AVERAGE_POPULARITY: 0.4309521, DIVERSITY_MEAN_INTER_LIST: 0.9207087, DIVERSITY_HERFINDAHL: 0.9920556, COVERAGE_ITEM: 0.1570950, COVERAGE_ITEM_HIT: 0.0656709, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.4206954, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0373800, SHANNON_ENTROPY: 7.5891850, RATIO_DIVERSITY_HERFINDAHL: 0.9928659, RATIO_DIVERSITY_GINI: 0.1068387, RATIO_SHANNON_ENTROPY: 0.7018218, RATIO_AVERAGE_POPULARITY: 1.5529280, RATIO_NOVELTY: 0.0836852,
#
# SVD++: Epoch 25 of 500. Elapsed time 2.24 min
# SVD++: Processed 640256 (100.0%) in 5.13 sec. MSE loss 4.71E-01. Sample per second: 124875
# SVD++: Epoch 26 of 500. Elapsed time 2.31 min
# SVD++: Processed 640256 (100.0%) in 4.47 sec. MSE loss 4.62E-01. Sample per second: 143391
# SVD++: Epoch 27 of 500. Elapsed time 2.38 min
# SVD++: Processed 640256 (100.0%) in 4.69 sec. MSE loss 4.56E-01. Sample per second: 136565
# SVD++: Epoch 28 of 500. Elapsed time 2.45 min
# SVD++: Processed 640256 (100.0%) in 5.17 sec. MSE loss 4.49E-01. Sample per second: 123892
# SVD++: Epoch 29 of 500. Elapsed time 2.53 min
# SVD++: Processed 640256 (100.0%) in 4.14 sec. MSE loss 4.42E-01. Sample per second: 154643
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.67 sec. Users per second: 1064
# SVD++: CUTOFF: 10 - PRECISION: 0.0656494, PRECISION_RECALL_MIN_DEN: 0.0709767, RECALL: 0.0299655, MAP: 0.0286084, MAP_MIN_DEN: 0.0303360, MRR: 0.1793765, NDCG: 0.0653604, F1: 0.0411487, HIT_RATE: 0.4125062, ARHR_ALL_HITS: 0.2244763, NOVELTY: 0.0248624, AVERAGE_POPULARITY: 0.4159644, DIVERSITY_MEAN_INTER_LIST: 0.9318412, DIVERSITY_HERFINDAHL: 0.9931687, COVERAGE_ITEM: 0.1789853, COVERAGE_ITEM_HIT: 0.0757147, ITEMS_IN_GT: 0.8815349, COVERAGE_USER: 0.9981788, COVERAGE_USER_HIT: 0.4117550, USERS_IN_GT: 0.9981788, DIVERSITY_GINI: 0.0441120, SHANNON_ENTROPY: 7.8245599, RATIO_DIVERSITY_HERFINDAHL: 0.9939799, RATIO_DIVERSITY_GINI: 0.1260797, RATIO_SHANNON_ENTROPY: 0.7235885, RATIO_AVERAGE_POPULARITY: 1.4989202, RATIO_NOVELTY: 0.0842379,
#
# SVD++: Convergence reached! Terminating at epoch 30. Best value for 'MAP' at epoch 5 is 0.0405. Elapsed time 2.69 min
# SVD++: Epoch 30 of 500. Elapsed time 2.69 min
# EvaluatorHoldout: Processed 6029 (100.0%) in 5.12 sec. Users per second: 1179
# [I 2023-11-25 12:33:24,963] Trial 49 finished with value: 0.04051036392884147 and parameters: {'num_factors': 24, 'sgd_mode': 'adam', 'batch_size': 128, 'item_reg': 0.0033609088844547197, 'user_reg': 3.094574389997406e-05, 'learning_rate': 0.0004074582253358145}. Best is trial 22 with value: 0.05505480784673042.

# %%
optuna_study.best_trial.params
# Out:
# {'num_factors': 3,
#  'sgd_mode': 'adagrad',
#  'batch_size': 16,
#  'item_reg': 0.0038538965529597707,
#  'user_reg': 3.484258935263262e-05,
#  'learning_rate': 0.00021378180951782999}

# %%
optuna_study.best_trial
# Out:
# FrozenTrial(number=22, state=TrialState.COMPLETE, values=[0.05505480784673042], datetime_start=datetime.datetime(2023, 11, 25, 2, 20, 15, 369645), datetime_complete=datetime.datetime(2023, 11, 25, 2, 34, 17, 441570), params={'num_factors': 3, 'sgd_mode': 'adagrad', 'batch_size': 16, 'item_reg': 0.0038538965529597707, 'user_reg': 3.484258935263262e-05, 'learning_rate': 0.00021378180951782999}, user_attrs={'epochs': 430, 'train_time (min)': 13.940159070491791}, system_attrs={}, intermediate_values={}, distributions={'num_factors': IntDistribution(high=200, log=False, low=1, step=1), 'sgd_mode': CategoricalDistribution(choices=('sgd', 'adagrad', 'adam')), 'batch_size': CategoricalDistribution(choices=(1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024)), 'item_reg': FloatDistribution(high=0.01, log=True, low=1e-05, step=None), 'user_reg': FloatDistribution(high=0.01, log=True, low=1e-05, step=None), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.0001, step=None)}, trial_id=22, value=None)

# %%
save_results.results_df
# Out:
#       result  train_time (min)  batch_size  epochs  item_reg  learning_rate  \
# 0   0.034490         26.488168      1024.0   500.0  0.000017       0.000474
# 1   0.045660         44.484622        32.0   115.0  0.007076       0.001295
# 2   0.041021         20.545199       256.0   135.0  0.000270       0.001409
# 3   0.010750         52.640930         8.0   170.0  0.000167       0.017469
# 4   0.017597          7.884509        16.0     5.0  0.000015       0.003300
# 5   0.017088         10.950843         4.0     5.0  0.000049       0.089961
# 6   0.039829          8.747753       512.0    70.0  0.003810       0.005547
# 7   0.043818          2.653221       128.0    25.0  0.000017       0.002793
# 8   0.002393         16.864489         4.0    30.0  0.000163       0.040066
# 9   0.020131         12.926190         2.0     5.0  0.000854       0.002855
# 10  0.044978         39.861297        32.0   500.0  0.008714       0.000175
# 11  0.051551         17.445344        32.0   500.0  0.009413       0.000120
# 12  0.046270         22.325408        32.0   495.0  0.009891       0.000105
# 13  0.047379         22.205742        64.0   500.0  0.002235       0.000127
# 14  0.043818         64.463415        64.0   500.0  0.001875       0.000256
# 15  0.040662         72.188279         1.0   500.0  0.001940       0.000408
# 16  0.049759         18.900514        64.0   500.0  0.003362       0.000142
# 17  0.047744         63.913531        64.0   500.0  0.000851       0.000339
# 18  0.048206         31.144158        16.0   220.0  0.004569       0.000758
# 19  0.043737         28.579730       128.0   500.0  0.004588       0.000220
# 20  0.010589         39.047726      1024.0   500.0  0.001097       0.000103
# 21  0.047328         55.611190        16.0   280.0  0.004553       0.000686
# 22  0.055055         13.940159        16.0   430.0  0.003854       0.000214
# 23  0.051536         14.842729         1.0   375.0  0.002769       0.000196
# 24  0.041544         50.774472         1.0   485.0  0.007620       0.000260
# 25  0.054142          5.778399         1.0   190.0  0.009915       0.000185
# 26  0.045914         54.977216       256.0   500.0  0.009430       0.000421
# 27  0.046567         34.301145         2.0   495.0  0.006070       0.000181
# 28  0.049969          0.833296         8.0    10.0  0.005449       0.000114
# 29  0.032129          6.649387       512.0     5.0  0.001516       0.000561
# 30  0.019529         53.452817      1024.0   500.0  0.002945       0.000303
# 31  0.045896         32.392163         1.0   495.0  0.003353       0.000200
# 32  0.054326          4.844230         1.0   155.0  0.006224       0.000180
# 33  0.049426         50.049326        32.0   500.0  0.006449       0.000383
# 34  0.053827         11.295787         1.0   395.0  0.009380       0.000101
# 35  0.039708         55.937494         1.0   315.0  0.005831       0.000552
# 36  0.018051        140.557630         1.0   500.0  0.006764       0.000164
# 37  0.039546          1.447416        16.0     5.0  0.004394       0.000281
# 38  0.025037          1.008078         1.0     5.0  0.002710       0.001013
# 39  0.054549          0.528293         1.0     5.0  0.006734       0.001078
# 40  0.031806          1.369911       256.0     5.0  0.003737       0.001296
# 41  0.053972          1.679590         1.0    70.0  0.007112       0.000255
# 42  0.047202          6.637262         1.0   120.0  0.006366       0.000522
# 43  0.047874         11.338376         1.0   255.0  0.007216       0.000324
# 44  0.050584          7.868498        16.0   100.0  0.005344       0.000885
# 45  0.039810         19.196637         8.0    35.0  0.009969       0.002054
# 46  0.047004          1.947230         4.0    10.0  0.003867       0.000157
# 47  0.048261         18.972409         1.0   350.0  0.002415       0.000241
# 48  0.053261          5.604014       512.0   200.0  0.007395       0.000593
# 49  0.040510          2.690263       128.0     5.0  0.003361       0.000407
#
#     num_factors sgd_mode  user_reg
# 0          90.0      sgd  0.003822
# 1         151.0  adagrad  0.002996
# 2         133.0      sgd  0.003847
# 3         101.0     adam  0.000803
# 4         127.0     adam  0.000027
# 5         199.0  adagrad  0.000419
# 6         182.0      sgd  0.000668
# 7          82.0      sgd  0.000021
# 8         150.0     adam  0.002242
# 9         181.0     adam  0.009589
# 10         24.0  adagrad  0.000078
# 11          5.0  adagrad  0.000096
# 12          9.0  adagrad  0.000205
# 13          9.0  adagrad  0.000131
# 14         46.0  adagrad  0.000131
# 15         51.0  adagrad  0.000063
# 16          6.0  adagrad  0.000012
# 17         45.0  adagrad  0.000010
# 18         63.0  adagrad  0.000038
# 19         24.0  adagrad  0.000010
# 20         27.0  adagrad  0.000053
# 21         68.0  adagrad  0.000028
# 22          3.0  adagrad  0.000035
# 23          5.0  adagrad  0.000018
# 24         32.0  adagrad  0.000020
# 25          1.0  adagrad  0.000044
# 26         38.0  adagrad  0.000043
# 27         18.0  adagrad  0.000092
# 28          2.0      sgd  0.000042
# 29         81.0     adam  0.000101
# 30         99.0      sgd  0.000210
# 31         16.0  adagrad  0.000019
# 32          1.0  adagrad  0.000064
# 33         32.0  adagrad  0.000061
# 34          1.0  adagrad  0.000037
# 35         59.0  adagrad  0.000034
# 36        117.0  adagrad  0.000057
# 37         17.0     adam  0.000030
# 38         38.0      sgd  0.000044
# 39          1.0  adagrad  0.000016
# 40         17.0     adam  0.000025
# 41          1.0  adagrad  0.000015
# 42         17.0  adagrad  0.000016
# 43         14.0  adagrad  0.000016
# 44         27.0  adagrad  0.000027
# 45        154.0  adagrad  0.000013
# 46         38.0      sgd  0.000024
# 47         10.0  adagrad  0.000022
# 48          1.0  adagrad  0.000015
# 49         24.0     adam  0.000031

# %%
best_index = save_results.results_df["result"].idxmax()
best_hyperparams = save_results.results_df.loc[best_index].to_dict()

del best_hyperparams["result"]
del best_hyperparams["train_time (min)"]
best_hyperparams
# Out:
# {'batch_size': 16.0,
#  'epochs': 430.0,
#  'item_reg': 0.0038538965529597707,
#  'learning_rate': 0.00021378180951782999,
#  'num_factors': 3.0,
#  'sgd_mode': 'adagrad',
#  'user_reg': 3.484258935263262e-05}

# %%
recommender_instance = MatrixFactorization_SVDpp_Cython(URM_train + URM_validation)
recommender_instance.fit(**best_hyperparams)

result_df, _ = evaluator_test.evaluateRecommender(recommender_instance)
result_df
# Out:
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 204 ( 5.3%) items with no interactions.
# SVD++: Processed 800176 (100.0%) in 1.17 sec. MSE loss 1.44E+01. Sample per second: 682963
# SVD++: Epoch 1 of 430.0. Elapsed time 1.01 sec
# SVD++: Processed 800176 (100.0%) in 1.19 sec. MSE loss 1.40E+01. Sample per second: 673314
# SVD++: Epoch 2 of 430.0. Elapsed time 2.03 sec
# SVD++: Processed 800176 (100.0%) in 1.21 sec. MSE loss 1.37E+01. Sample per second: 663929
# SVD++: Epoch 3 of 430.0. Elapsed time 3.05 sec
# SVD++: Processed 800176 (100.0%) in 1.21 sec. MSE loss 1.35E+01. Sample per second: 661346
# SVD++: Epoch 4 of 430.0. Elapsed time 4.05 sec
# SVD++: Processed 800176 (100.0%) in 1.20 sec. MSE loss 1.33E+01. Sample per second: 667654
# SVD++: Epoch 5 of 430.0. Elapsed time 5.03 sec
# SVD++: Processed 800176 (100.0%) in 1.21 sec. MSE loss 1.31E+01. Sample per second: 662294
# SVD++: Epoch 6 of 430.0. Elapsed time 6.04 sec
# SVD++: Processed 800176 (100.0%) in 0.88 sec. MSE loss 1.29E+01. Sample per second: 907123
# SVD++: Epoch 7 of 430.0. Elapsed time 6.72 sec
# SVD++: Processed 800176 (100.0%) in 1.73 sec. MSE loss 1.28E+01. Sample per second: 462811
# SVD++: Epoch 8 of 430.0. Elapsed time 7.56 sec
# SVD++: Processed 800176 (100.0%) in 1.74 sec. MSE loss 1.27E+01. Sample per second: 461030
# SVD++: Epoch 9 of 430.0. Elapsed time 8.57 sec
# SVD++: Processed 800176 (100.0%) in 1.74 sec. MSE loss 1.25E+01. Sample per second: 459269
# SVD++: Epoch 10 of 430.0. Elapsed time 9.58 sec
# SVD++: Processed 800176 (100.0%) in 1.75 sec. MSE loss 1.24E+01. Sample per second: 457429
# SVD++: Epoch 11 of 430.0. Elapsed time 10.59 sec
# SVD++: Processed 800176 (100.0%) in 1.77 sec. MSE loss 1.23E+01. Sample per second: 453088
# SVD++: Epoch 12 of 430.0. Elapsed time 11.60 sec
# SVD++: Processed 800176 (100.0%) in 1.78 sec. MSE loss 1.22E+01. Sample per second: 448828
# SVD++: Epoch 13 of 430.0. Elapsed time 12.62 sec
# SVD++: Processed 800176 (100.0%) in 1.80 sec. MSE loss 1.21E+01. Sample per second: 444779
# SVD++: Epoch 14 of 430.0. Elapsed time 13.63 sec
# SVD++: Processed 800176 (100.0%) in 1.83 sec. MSE loss 1.20E+01. Sample per second: 438262
# SVD++: Epoch 15 of 430.0. Elapsed time 14.66 sec
# SVD++: Processed 800176 (100.0%) in 1.85 sec. MSE loss 1.19E+01. Sample per second: 432009
# SVD++: Epoch 16 of 430.0. Elapsed time 15.69 sec
# SVD++: Processed 800176 (100.0%) in 1.69 sec. MSE loss 1.18E+01. Sample per second: 473828
# SVD++: Epoch 17 of 430.0. Elapsed time 16.52 sec
# SVD++: Processed 800176 (100.0%) in 1.38 sec. MSE loss 1.18E+01. Sample per second: 578151
# SVD++: Epoch 18 of 430.0. Elapsed time 17.22 sec
# SVD++: Processed 800176 (100.0%) in 1.40 sec. MSE loss 1.17E+01. Sample per second: 570446
# SVD++: Epoch 19 of 430.0. Elapsed time 18.24 sec
# SVD++: Processed 800176 (100.0%) in 1.43 sec. MSE loss 1.16E+01. Sample per second: 559848
# SVD++: Epoch 20 of 430.0. Elapsed time 19.26 sec
# SVD++: Processed 800176 (100.0%) in 1.45 sec. MSE loss 1.15E+01. Sample per second: 553403
# SVD++: Epoch 21 of 430.0. Elapsed time 20.28 sec
# SVD++: Processed 800176 (100.0%) in 1.46 sec. MSE loss 1.15E+01. Sample per second: 547166
# SVD++: Epoch 22 of 430.0. Elapsed time 21.30 sec
# SVD++: Processed 800176 (100.0%) in 1.47 sec. MSE loss 1.14E+01. Sample per second: 544670
# SVD++: Epoch 23 of 430.0. Elapsed time 22.30 sec
# SVD++: Processed 800176 (100.0%) in 1.48 sec. MSE loss 1.13E+01. Sample per second: 542144
# SVD++: Epoch 24 of 430.0. Elapsed time 23.31 sec
# SVD++: Processed 800176 (100.0%) in 1.48 sec. MSE loss 1.13E+01. Sample per second: 539650
# SVD++: Epoch 25 of 430.0. Elapsed time 24.32 sec
# SVD++: Processed 800176 (100.0%) in 1.50 sec. MSE loss 1.12E+01. Sample per second: 533719
# SVD++: Epoch 26 of 430.0. Elapsed time 25.34 sec
# SVD++: Processed 800176 (100.0%) in 1.49 sec. MSE loss 1.11E+01. Sample per second: 538682
# SVD++: Epoch 27 of 430.0. Elapsed time 26.32 sec
# SVD++: Processed 800176 (100.0%) in 1.14 sec. MSE loss 1.10E+01. Sample per second: 699819
# SVD++: Epoch 28 of 430.0. Elapsed time 26.98 sec
# SVD++: Processed 800176 (100.0%) in 1.05 sec. MSE loss 1.10E+01. Sample per second: 763269
# SVD++: Epoch 29 of 430.0. Elapsed time 27.89 sec
# SVD++: Processed 800176 (100.0%) in 1.07 sec. MSE loss 1.09E+01. Sample per second: 749974
# SVD++: Epoch 30 of 430.0. Elapsed time 28.90 sec
# SVD++: Processed 800176 (100.0%) in 1.08 sec. MSE loss 1.09E+01. Sample per second: 738680
# SVD++: Epoch 31 of 430.0. Elapsed time 29.92 sec
# SVD++: Processed 800176 (100.0%) in 1.09 sec. MSE loss 1.08E+01. Sample per second: 734079
# SVD++: Epoch 32 of 430.0. Elapsed time 30.93 sec
# SVD++: Processed 800176 (100.0%) in 1.10 sec. MSE loss 1.08E+01. Sample per second: 723013
# SVD++: Epoch 33 of 430.0. Elapsed time 31.94 sec
# SVD++: Processed 800176 (100.0%) in 1.10 sec. MSE loss 1.07E+01. Sample per second: 725190
# SVD++: Epoch 34 of 430.0. Elapsed time 32.94 sec
# SVD++: Processed 800176 (100.0%) in 1.11 sec. MSE loss 1.07E+01. Sample per second: 721230
# SVD++: Epoch 35 of 430.0. Elapsed time 33.95 sec
# SVD++: Processed 800176 (100.0%) in 1.13 sec. MSE loss 1.06E+01. Sample per second: 710580
# SVD++: Epoch 36 of 430.0. Elapsed time 34.96 sec
# SVD++: Processed 800176 (100.0%) in 1.15 sec. MSE loss 1.05E+01. Sample per second: 694302
# SVD++: Epoch 37 of 430.0. Elapsed time 35.99 sec
# SVD++: Processed 800176 (100.0%) in 0.94 sec. MSE loss 1.05E+01. Sample per second: 853008
# SVD++: Epoch 38 of 430.0. Elapsed time 36.78 sec
# SVD++: Processed 800176 (100.0%) in 1.70 sec. MSE loss 1.04E+01. Sample per second: 471124
# SVD++: Epoch 39 of 430.0. Elapsed time 37.53 sec
# SVD++: Processed 800176 (100.0%) in 1.71 sec. MSE loss 1.04E+01. Sample per second: 469288
# SVD++: Epoch 40 of 430.0. Elapsed time 38.55 sec
# SVD++: Processed 800176 (100.0%) in 1.72 sec. MSE loss 1.03E+01. Sample per second: 464790
# SVD++: Epoch 41 of 430.0. Elapsed time 39.56 sec
# SVD++: Processed 800176 (100.0%) in 1.74 sec. MSE loss 1.03E+01. Sample per second: 460324
# SVD++: Epoch 42 of 430.0. Elapsed time 40.57 sec
# SVD++: Processed 800176 (100.0%) in 1.76 sec. MSE loss 1.02E+01. Sample per second: 453384
# SVD++: Epoch 43 of 430.0. Elapsed time 41.60 sec
# SVD++: Processed 800176 (100.0%) in 1.77 sec. MSE loss 1.02E+01. Sample per second: 451656
# SVD++: Epoch 44 of 430.0. Elapsed time 42.61 sec
# SVD++: Processed 800176 (100.0%) in 1.79 sec. MSE loss 1.01E+01. Sample per second: 447464
# SVD++: Epoch 45 of 430.0. Elapsed time 43.62 sec
# SVD++: Processed 800176 (100.0%) in 1.80 sec. MSE loss 1.01E+01. Sample per second: 445745
# SVD++: Epoch 46 of 430.0. Elapsed time 44.64 sec
# SVD++: Processed 800176 (100.0%) in 1.81 sec. MSE loss 1.01E+01. Sample per second: 441720
# SVD++: Epoch 47 of 430.0. Elapsed time 45.65 sec
# SVD++: Processed 800176 (100.0%) in 1.74 sec. MSE loss 1.00E+01. Sample per second: 460409
# SVD++: Epoch 48 of 430.0. Elapsed time 46.57 sec
# SVD++: Processed 800176 (100.0%) in 1.39 sec. MSE loss 9.97E+00. Sample per second: 577344
# SVD++: Epoch 49 of 430.0. Elapsed time 47.22 sec
# SVD++: Processed 800176 (100.0%) in 1.37 sec. MSE loss 9.93E+00. Sample per second: 582787
# SVD++: Epoch 50 of 430.0. Elapsed time 48.21 sec
# SVD++: Processed 800176 (100.0%) in 1.43 sec. MSE loss 9.87E+00. Sample per second: 560415
# SVD++: Epoch 51 of 430.0. Elapsed time 49.26 sec
# SVD++: Processed 800176 (100.0%) in 1.44 sec. MSE loss 9.84E+00. Sample per second: 556948
# SVD++: Epoch 52 of 430.0. Elapsed time 50.27 sec
# SVD++: Processed 800176 (100.0%) in 1.45 sec. MSE loss 9.78E+00. Sample per second: 550551
# SVD++: Epoch 53 of 430.0. Elapsed time 51.29 sec
# SVD++: Processed 800176 (100.0%) in 1.48 sec. MSE loss 9.76E+00. Sample per second: 540498
# SVD++: Epoch 54 of 430.0. Elapsed time 52.32 sec
# SVD++: Processed 800176 (100.0%) in 1.51 sec. MSE loss 9.71E+00. Sample per second: 530956
# SVD++: Epoch 55 of 430.0. Elapsed time 53.34 sec
# SVD++: Processed 800176 (100.0%) in 1.51 sec. MSE loss 9.67E+00. Sample per second: 528543
# SVD++: Epoch 56 of 430.0. Elapsed time 54.35 sec
# SVD++: Processed 800176 (100.0%) in 1.52 sec. MSE loss 9.63E+00. Sample per second: 526293
# SVD++: Epoch 57 of 430.0. Elapsed time 55.36 sec
# SVD++: Processed 800176 (100.0%) in 1.53 sec. MSE loss 9.59E+00. Sample per second: 523920
# SVD++: Epoch 58 of 430.0. Elapsed time 56.36 sec
# SVD++: Processed 800176 (100.0%) in 1.22 sec. MSE loss 9.56E+00. Sample per second: 653216
# SVD++: Epoch 59 of 430.0. Elapsed time 57.06 sec
# SVD++: Processed 800176 (100.0%) in 1.03 sec. MSE loss 9.52E+00. Sample per second: 774992
# SVD++: Epoch 60 of 430.0. Elapsed time 57.87 sec
# SVD++: Processed 800176 (100.0%) in 1.05 sec. MSE loss 9.47E+00. Sample per second: 762507
# SVD++: Epoch 61 of 430.0. Elapsed time 58.88 sec
# SVD++: Processed 800176 (100.0%) in 1.08 sec. MSE loss 9.44E+00. Sample per second: 743630
# SVD++: Epoch 62 of 430.0. Elapsed time 59.91 sec
# SVD++: Processed 800176 (100.0%) in 1.08 sec. MSE loss 9.40E+00. Sample per second: 738982
# SVD++: Epoch 63 of 430.0. Elapsed time 1.02 min
# SVD++: Processed 800176 (100.0%) in 1.09 sec. MSE loss 9.36E+00. Sample per second: 734458
# SVD++: Epoch 64 of 430.0. Elapsed time 1.03 min
# SVD++: Processed 800176 (100.0%) in 1.11 sec. MSE loss 9.32E+00. Sample per second: 723098
# SVD++: Epoch 65 of 430.0. Elapsed time 1.05 min
# SVD++: Processed 800176 (100.0%) in 1.11 sec. MSE loss 9.29E+00. Sample per second: 718624
# SVD++: Epoch 66 of 430.0. Elapsed time 1.07 min
# SVD++: Processed 800176 (100.0%) in 1.12 sec. MSE loss 9.25E+00. Sample per second: 712088
# SVD++: Epoch 67 of 430.0. Elapsed time 1.08 min
# SVD++: Processed 800176 (100.0%) in 1.12 sec. MSE loss 9.23E+00. Sample per second: 712670
# SVD++: Epoch 68 of 430.0. Elapsed time 1.10 min
# SVD++: Processed 800176 (100.0%) in 0.99 sec. MSE loss 9.18E+00. Sample per second: 804590
# SVD++: Epoch 69 of 430.0. Elapsed time 1.11 min
# SVD++: Processed 800176 (100.0%) in 1.65 sec. MSE loss 9.15E+00. Sample per second: 486025
# SVD++: Epoch 70 of 430.0. Elapsed time 1.12 min
# SVD++: Processed 800176 (100.0%) in 1.62 sec. MSE loss 9.12E+00. Sample per second: 493003
# SVD++: Epoch 71 of 430.0. Elapsed time 1.14 min
# SVD++: Processed 800176 (100.0%) in 1.63 sec. MSE loss 9.09E+00. Sample per second: 491081
# SVD++: Epoch 72 of 430.0. Elapsed time 1.16 min
# SVD++: Processed 800176 (100.0%) in 1.64 sec. MSE loss 9.05E+00. Sample per second: 486734
# SVD++: Epoch 73 of 430.0. Elapsed time 1.17 min
# SVD++: Processed 800176 (100.0%) in 1.65 sec. MSE loss 9.02E+00. Sample per second: 484255
# SVD++: Epoch 74 of 430.0. Elapsed time 1.19 min
# SVD++: Processed 800176 (100.0%) in 1.69 sec. MSE loss 8.99E+00. Sample per second: 473694
# SVD++: Epoch 75 of 430.0. Elapsed time 1.21 min
# SVD++: Processed 800176 (100.0%) in 1.71 sec. MSE loss 8.96E+00. Sample per second: 469094
# SVD++: Epoch 76 of 430.0. Elapsed time 1.23 min
# SVD++: Processed 800176 (100.0%) in 1.72 sec. MSE loss 8.92E+00. Sample per second: 462391
# SVD++: Epoch 77 of 430.0. Elapsed time 1.24 min
# SVD++: Processed 800176 (100.0%) in 1.75 sec. MSE loss 8.90E+00. Sample per second: 457510
# SVD++: Epoch 78 of 430.0. Elapsed time 1.26 min
# SVD++: Processed 800176 (100.0%) in 1.77 sec. MSE loss 8.86E+00. Sample per second: 453192
# SVD++: Epoch 79 of 430.0. Elapsed time 1.28 min
# SVD++: Processed 800176 (100.0%) in 1.42 sec. MSE loss 8.83E+00. Sample per second: 562190
# SVD++: Epoch 80 of 430.0. Elapsed time 1.29 min
# SVD++: Processed 800176 (100.0%) in 1.30 sec. MSE loss 8.80E+00. Sample per second: 616729
# SVD++: Epoch 81 of 430.0. Elapsed time 1.30 min
# SVD++: Processed 800176 (100.0%) in 1.32 sec. MSE loss 8.77E+00. Sample per second: 607883
# SVD++: Epoch 82 of 430.0. Elapsed time 1.32 min
# SVD++: Processed 800176 (100.0%) in 1.32 sec. MSE loss 8.73E+00. Sample per second: 604792
# SVD++: Epoch 83 of 430.0. Elapsed time 1.34 min
# SVD++: Processed 800176 (100.0%) in 1.33 sec. MSE loss 8.72E+00. Sample per second: 601830
# SVD++: Epoch 84 of 430.0. Elapsed time 1.35 min
# SVD++: Processed 800176 (100.0%) in 1.34 sec. MSE loss 8.67E+00. Sample per second: 598800
# SVD++: Epoch 85 of 430.0. Elapsed time 1.37 min
# SVD++: Processed 800176 (100.0%) in 1.34 sec. MSE loss 8.65E+00. Sample per second: 595987
# SVD++: Epoch 86 of 430.0. Elapsed time 1.39 min
# SVD++: Processed 800176 (100.0%) in 1.35 sec. MSE loss 8.62E+00. Sample per second: 592988
# SVD++: Epoch 87 of 430.0. Elapsed time 1.40 min
# SVD++: Processed 800176 (100.0%) in 1.36 sec. MSE loss 8.59E+00. Sample per second: 590252
# SVD++: Epoch 88 of 430.0. Elapsed time 1.42 min
# SVD++: Processed 800176 (100.0%) in 1.36 sec. MSE loss 8.56E+00. Sample per second: 587230
# SVD++: Epoch 89 of 430.0. Elapsed time 1.44 min
# SVD++: Processed 800176 (100.0%) in 1.20 sec. MSE loss 8.54E+00. Sample per second: 668546
# SVD++: Epoch 90 of 430.0. Elapsed time 1.45 min
# SVD++: Processed 800176 (100.0%) in 0.88 sec. MSE loss 8.51E+00. Sample per second: 913627
# SVD++: Epoch 91 of 430.0. Elapsed time 1.46 min
# SVD++: Processed 800176 (100.0%) in 1.89 sec. MSE loss 8.47E+00. Sample per second: 422804
# SVD++: Epoch 92 of 430.0. Elapsed time 1.48 min
# SVD++: Processed 800176 (100.0%) in 1.91 sec. MSE loss 8.45E+00. Sample per second: 419165
# SVD++: Epoch 93 of 430.0. Elapsed time 1.50 min
# SVD++: Processed 800176 (100.0%) in 1.93 sec. MSE loss 8.41E+00. Sample per second: 415581
# SVD++: Epoch 94 of 430.0. Elapsed time 1.51 min
# SVD++: Processed 800176 (100.0%) in 1.94 sec. MSE loss 8.39E+00. Sample per second: 412044
# SVD++: Epoch 95 of 430.0. Elapsed time 1.53 min
# SVD++: Processed 800176 (100.0%) in 1.95 sec. MSE loss 8.37E+00. Sample per second: 410631
# SVD++: Epoch 96 of 430.0. Elapsed time 1.55 min
# SVD++: Processed 800176 (100.0%) in 1.98 sec. MSE loss 8.34E+00. Sample per second: 405090
# SVD++: Epoch 97 of 430.0. Elapsed time 1.56 min
# SVD++: Processed 800176 (100.0%) in 2.00 sec. MSE loss 8.31E+00. Sample per second: 399653
# SVD++: Epoch 98 of 430.0. Elapsed time 1.58 min
# SVD++: Processed 800176 (100.0%) in 1.03 sec. MSE loss 8.29E+00. Sample per second: 777877
# SVD++: Epoch 99 of 430.0. Elapsed time 1.60 min
# SVD++: Processed 800176 (100.0%) in 0.99 sec. MSE loss 8.27E+00. Sample per second: 804458
# SVD++: Epoch 100 of 430.0. Elapsed time 1.61 min
# SVD++: Processed 800176 (100.0%) in 0.65 sec. MSE loss 8.23E+00. Sample per second: 1229024
# SVD++: Epoch 101 of 430.0. Elapsed time 1.62 min
# SVD++: Processed 800176 (100.0%) in 1.55 sec. MSE loss 8.21E+00. Sample per second: 516782
# SVD++: Epoch 102 of 430.0. Elapsed time 1.64 min
# SVD++: Processed 800176 (100.0%) in 1.55 sec. MSE loss 8.19E+00. Sample per second: 514653
# SVD++: Epoch 103 of 430.0. Elapsed time 1.66 min
# SVD++: Processed 800176 (100.0%) in 1.56 sec. MSE loss 8.15E+00. Sample per second: 512481
# SVD++: Epoch 104 of 430.0. Elapsed time 1.67 min
# SVD++: Processed 800176 (100.0%) in 1.58 sec. MSE loss 8.13E+00. Sample per second: 507157
# SVD++: Epoch 105 of 430.0. Elapsed time 1.69 min
# SVD++: Processed 800176 (100.0%) in 1.59 sec. MSE loss 8.10E+00. Sample per second: 501715
# SVD++: Epoch 106 of 430.0. Elapsed time 1.71 min
# SVD++: Processed 800176 (100.0%) in 1.60 sec. MSE loss 8.08E+00. Sample per second: 499669
# SVD++: Epoch 107 of 430.0. Elapsed time 1.72 min
# SVD++: Processed 800176 (100.0%) in 1.62 sec. MSE loss 8.05E+00. Sample per second: 494439
# SVD++: Epoch 108 of 430.0. Elapsed time 1.74 min
# SVD++: Processed 800176 (100.0%) in 1.63 sec. MSE loss 8.03E+00. Sample per second: 489412
# SVD++: Epoch 109 of 430.0. Elapsed time 1.76 min
# SVD++: Processed 800176 (100.0%) in 1.66 sec. MSE loss 8.00E+00. Sample per second: 482063
# SVD++: Epoch 110 of 430.0. Elapsed time 1.77 min
# SVD++: Processed 800176 (100.0%) in 1.44 sec. MSE loss 7.98E+00. Sample per second: 556121
# SVD++: Epoch 111 of 430.0. Elapsed time 1.79 min
# SVD++: Processed 800176 (100.0%) in 1.19 sec. MSE loss 7.95E+00. Sample per second: 673888
# SVD++: Epoch 112 of 430.0. Elapsed time 1.80 min
# SVD++: Processed 800176 (100.0%) in 1.20 sec. MSE loss 7.93E+00. Sample per second: 664320
# SVD++: Epoch 113 of 430.0. Elapsed time 1.82 min
# SVD++: Processed 800176 (100.0%) in 1.19 sec. MSE loss 7.92E+00. Sample per second: 671834
# SVD++: Epoch 114 of 430.0. Elapsed time 1.83 min
# SVD++: Processed 800176 (100.0%) in 1.21 sec. MSE loss 7.89E+00. Sample per second: 662293
# SVD++: Epoch 115 of 430.0. Elapsed time 1.85 min
# SVD++: Processed 800176 (100.0%) in 1.23 sec. MSE loss 7.86E+00. Sample per second: 653179
# SVD++: Epoch 116 of 430.0. Elapsed time 1.87 min
# SVD++: Processed 800176 (100.0%) in 1.25 sec. MSE loss 7.84E+00. Sample per second: 639391
# SVD++: Epoch 117 of 430.0. Elapsed time 1.88 min
# SVD++: Processed 800176 (100.0%) in 1.27 sec. MSE loss 7.82E+00. Sample per second: 630918
# SVD++: Epoch 118 of 430.0. Elapsed time 1.90 min
# SVD++: Processed 800176 (100.0%) in 1.28 sec. MSE loss 7.80E+00. Sample per second: 622786
# SVD++: Epoch 119 of 430.0. Elapsed time 1.92 min
# SVD++: Processed 800176 (100.0%) in 1.30 sec. MSE loss 7.77E+00. Sample per second: 614747
# SVD++: Epoch 120 of 430.0. Elapsed time 1.94 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 7.75E+00. Sample per second: 646438
# SVD++: Epoch 121 of 430.0. Elapsed time 1.95 min
# SVD++: Processed 800176 (100.0%) in 0.89 sec. MSE loss 7.73E+00. Sample per second: 902708
# SVD++: Epoch 122 of 430.0. Elapsed time 1.96 min
# SVD++: Processed 800176 (100.0%) in 1.84 sec. MSE loss 7.70E+00. Sample per second: 434093
# SVD++: Epoch 123 of 430.0. Elapsed time 1.98 min
# SVD++: Processed 800176 (100.0%) in 1.86 sec. MSE loss 7.68E+00. Sample per second: 430261
# SVD++: Epoch 124 of 430.0. Elapsed time 1.99 min
# SVD++: Processed 800176 (100.0%) in 1.87 sec. MSE loss 7.65E+00. Sample per second: 428710
# SVD++: Epoch 125 of 430.0. Elapsed time 2.01 min
# SVD++: Processed 800176 (100.0%) in 1.88 sec. MSE loss 7.63E+00. Sample per second: 425308
# SVD++: Epoch 126 of 430.0. Elapsed time 2.03 min
# SVD++: Processed 800176 (100.0%) in 1.89 sec. MSE loss 7.62E+00. Sample per second: 423748
# SVD++: Epoch 127 of 430.0. Elapsed time 2.05 min
# SVD++: Processed 800176 (100.0%) in 1.90 sec. MSE loss 7.59E+00. Sample per second: 419631
# SVD++: Epoch 128 of 430.0. Elapsed time 2.06 min
# SVD++: Processed 800176 (100.0%) in 1.93 sec. MSE loss 7.57E+00. Sample per second: 413874
# SVD++: Epoch 129 of 430.0. Elapsed time 2.08 min
# SVD++: Processed 800176 (100.0%) in 1.95 sec. MSE loss 7.55E+00. Sample per second: 410415
# SVD++: Epoch 130 of 430.0. Elapsed time 2.10 min
# SVD++: Processed 800176 (100.0%) in 1.98 sec. MSE loss 7.53E+00. Sample per second: 404878
# SVD++: Epoch 131 of 430.0. Elapsed time 2.11 min
# SVD++: Processed 800176 (100.0%) in 1.70 sec. MSE loss 7.50E+00. Sample per second: 469772
# SVD++: Epoch 132 of 430.0. Elapsed time 2.13 min
# SVD++: Processed 800176 (100.0%) in 1.53 sec. MSE loss 7.48E+00. Sample per second: 523357
# SVD++: Epoch 133 of 430.0. Elapsed time 2.14 min
# SVD++: Processed 800176 (100.0%) in 1.55 sec. MSE loss 7.46E+00. Sample per second: 517107
# SVD++: Epoch 134 of 430.0. Elapsed time 2.16 min
# SVD++: Processed 800176 (100.0%) in 1.57 sec. MSE loss 7.44E+00. Sample per second: 508364
# SVD++: Epoch 135 of 430.0. Elapsed time 2.17 min
# SVD++: Processed 800176 (100.0%) in 1.59 sec. MSE loss 7.42E+00. Sample per second: 500547
# SVD++: Epoch 136 of 430.0. Elapsed time 2.19 min
# SVD++: Processed 800176 (100.0%) in 1.62 sec. MSE loss 7.40E+00. Sample per second: 494737
# SVD++: Epoch 137 of 430.0. Elapsed time 2.21 min
# SVD++: Processed 800176 (100.0%) in 1.65 sec. MSE loss 7.38E+00. Sample per second: 483787
# SVD++: Epoch 138 of 430.0. Elapsed time 2.22 min
# SVD++: Processed 800176 (100.0%) in 1.67 sec. MSE loss 7.36E+00. Sample per second: 478903
# SVD++: Epoch 139 of 430.0. Elapsed time 2.24 min
# SVD++: Processed 800176 (100.0%) in 1.68 sec. MSE loss 7.35E+00. Sample per second: 477008
# SVD++: Epoch 140 of 430.0. Elapsed time 2.26 min
# SVD++: Processed 800176 (100.0%) in 1.70 sec. MSE loss 7.32E+00. Sample per second: 469490
# SVD++: Epoch 141 of 430.0. Elapsed time 2.28 min
# SVD++: Processed 800176 (100.0%) in 1.55 sec. MSE loss 7.30E+00. Sample per second: 515875
# SVD++: Epoch 142 of 430.0. Elapsed time 2.29 min
# SVD++: Processed 800176 (100.0%) in 1.23 sec. MSE loss 7.28E+00. Sample per second: 650553
# SVD++: Epoch 143 of 430.0. Elapsed time 2.30 min
# SVD++: Processed 800176 (100.0%) in 1.23 sec. MSE loss 7.27E+00. Sample per second: 652412
# SVD++: Epoch 144 of 430.0. Elapsed time 2.32 min
# SVD++: Processed 800176 (100.0%) in 1.23 sec. MSE loss 7.24E+00. Sample per second: 648732
# SVD++: Epoch 145 of 430.0. Elapsed time 2.33 min
# SVD++: Processed 800176 (100.0%) in 1.23 sec. MSE loss 7.22E+00. Sample per second: 650686
# SVD++: Epoch 146 of 430.0. Elapsed time 2.35 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 7.21E+00. Sample per second: 647068
# SVD++: Epoch 147 of 430.0. Elapsed time 2.37 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 7.18E+00. Sample per second: 643541
# SVD++: Epoch 148 of 430.0. Elapsed time 2.38 min
# SVD++: Processed 800176 (100.0%) in 1.26 sec. MSE loss 7.15E+00. Sample per second: 634640
# SVD++: Epoch 149 of 430.0. Elapsed time 2.40 min
# SVD++: Processed 800176 (100.0%) in 1.28 sec. MSE loss 7.14E+00. Sample per second: 627335
# SVD++: Epoch 150 of 430.0. Elapsed time 2.42 min
# SVD++: Processed 800176 (100.0%) in 1.29 sec. MSE loss 7.13E+00. Sample per second: 618186
# SVD++: Epoch 151 of 430.0. Elapsed time 2.44 min
# SVD++: Processed 800176 (100.0%) in 1.31 sec. MSE loss 7.11E+00. Sample per second: 610454
# SVD++: Epoch 152 of 430.0. Elapsed time 2.45 min
# SVD++: Processed 800176 (100.0%) in 0.96 sec. MSE loss 7.09E+00. Sample per second: 833879
# SVD++: Epoch 153 of 430.0. Elapsed time 2.46 min
# SVD++: Processed 800176 (100.0%) in 1.84 sec. MSE loss 7.08E+00. Sample per second: 433814
# SVD++: Epoch 154 of 430.0. Elapsed time 2.48 min
# SVD++: Processed 800176 (100.0%) in 1.86 sec. MSE loss 7.05E+00. Sample per second: 429530
# SVD++: Epoch 155 of 430.0. Elapsed time 2.49 min
# SVD++: Processed 800176 (100.0%) in 1.88 sec. MSE loss 7.04E+00. Sample per second: 425695
# SVD++: Epoch 156 of 430.0. Elapsed time 2.51 min
# SVD++: Processed 800176 (100.0%) in 1.89 sec. MSE loss 7.02E+00. Sample per second: 422375
# SVD++: Epoch 157 of 430.0. Elapsed time 2.53 min
# SVD++: Processed 800176 (100.0%) in 1.90 sec. MSE loss 7.00E+00. Sample per second: 420419
# SVD++: Epoch 158 of 430.0. Elapsed time 2.55 min
# SVD++: Processed 800176 (100.0%) in 1.92 sec. MSE loss 6.99E+00. Sample per second: 416719
# SVD++: Epoch 159 of 430.0. Elapsed time 2.56 min
# SVD++: Processed 800176 (100.0%) in 1.94 sec. MSE loss 6.96E+00. Sample per second: 413523
# SVD++: Epoch 160 of 430.0. Elapsed time 2.58 min
# SVD++: Processed 800176 (100.0%) in 1.94 sec. MSE loss 6.95E+00. Sample per second: 411729
# SVD++: Epoch 161 of 430.0. Elapsed time 2.60 min
# SVD++: Processed 800176 (100.0%) in 1.96 sec. MSE loss 6.92E+00. Sample per second: 408214
# SVD++: Epoch 162 of 430.0. Elapsed time 2.61 min
# SVD++: Processed 800176 (100.0%) in 1.78 sec. MSE loss 6.91E+00. Sample per second: 450488
# SVD++: Epoch 163 of 430.0. Elapsed time 2.63 min
# SVD++: Processed 800176 (100.0%) in 1.51 sec. MSE loss 6.89E+00. Sample per second: 528285
# SVD++: Epoch 164 of 430.0. Elapsed time 2.64 min
# SVD++: Processed 800176 (100.0%) in 1.53 sec. MSE loss 6.88E+00. Sample per second: 522637
# SVD++: Epoch 165 of 430.0. Elapsed time 2.66 min
# SVD++: Processed 800176 (100.0%) in 1.56 sec. MSE loss 6.85E+00. Sample per second: 514305
# SVD++: Epoch 166 of 430.0. Elapsed time 2.67 min
# SVD++: Processed 800176 (100.0%) in 1.56 sec. MSE loss 6.83E+00. Sample per second: 511443
# SVD++: Epoch 167 of 430.0. Elapsed time 2.69 min
# SVD++: Processed 800176 (100.0%) in 1.58 sec. MSE loss 6.83E+00. Sample per second: 505747
# SVD++: Epoch 168 of 430.0. Elapsed time 2.71 min
# SVD++: Processed 800176 (100.0%) in 1.61 sec. MSE loss 6.80E+00. Sample per second: 498025
# SVD++: Epoch 169 of 430.0. Elapsed time 2.72 min
# SVD++: Processed 800176 (100.0%) in 1.62 sec. MSE loss 6.79E+00. Sample per second: 495291
# SVD++: Epoch 170 of 430.0. Elapsed time 2.74 min
# SVD++: Processed 800176 (100.0%) in 1.63 sec. MSE loss 6.77E+00. Sample per second: 490198
# SVD++: Epoch 171 of 430.0. Elapsed time 2.76 min
# SVD++: Processed 800176 (100.0%) in 1.64 sec. MSE loss 6.75E+00. Sample per second: 488235
# SVD++: Epoch 172 of 430.0. Elapsed time 2.77 min
# SVD++: Processed 800176 (100.0%) in 1.59 sec. MSE loss 6.73E+00. Sample per second: 504762
# SVD++: Epoch 173 of 430.0. Elapsed time 2.79 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 6.72E+00. Sample per second: 643072
# SVD++: Epoch 174 of 430.0. Elapsed time 2.80 min
# SVD++: Processed 800176 (100.0%) in 1.20 sec. MSE loss 6.70E+00. Sample per second: 666099
# SVD++: Epoch 175 of 430.0. Elapsed time 2.82 min
# SVD++: Processed 800176 (100.0%) in 1.22 sec. MSE loss 6.69E+00. Sample per second: 656985
# SVD++: Epoch 176 of 430.0. Elapsed time 2.83 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 6.66E+00. Sample per second: 643022
# SVD++: Epoch 177 of 430.0. Elapsed time 2.85 min
# SVD++: Processed 800176 (100.0%) in 1.27 sec. MSE loss 6.65E+00. Sample per second: 629446
# SVD++: Epoch 178 of 430.0. Elapsed time 2.87 min
# SVD++: Processed 800176 (100.0%) in 1.29 sec. MSE loss 6.64E+00. Sample per second: 621489
# SVD++: Epoch 179 of 430.0. Elapsed time 2.89 min
# SVD++: Processed 800176 (100.0%) in 1.31 sec. MSE loss 6.61E+00. Sample per second: 608916
# SVD++: Epoch 180 of 430.0. Elapsed time 2.90 min
# SVD++: Processed 800176 (100.0%) in 1.33 sec. MSE loss 6.60E+00. Sample per second: 602237
# SVD++: Epoch 181 of 430.0. Elapsed time 2.92 min
# SVD++: Processed 800176 (100.0%) in 1.34 sec. MSE loss 6.59E+00. Sample per second: 598261
# SVD++: Epoch 182 of 430.0. Elapsed time 2.94 min
# SVD++: Processed 800176 (100.0%) in 1.33 sec. MSE loss 6.57E+00. Sample per second: 599808
# SVD++: Epoch 183 of 430.0. Elapsed time 2.95 min
# SVD++: Processed 800176 (100.0%) in 1.05 sec. MSE loss 6.56E+00. Sample per second: 761419
# SVD++: Epoch 184 of 430.0. Elapsed time 2.96 min
# SVD++: Processed 800176 (100.0%) in 0.88 sec. MSE loss 6.53E+00. Sample per second: 910779
# SVD++: Epoch 185 of 430.0. Elapsed time 2.98 min
# SVD++: Processed 800176 (100.0%) in 1.89 sec. MSE loss 6.52E+00. Sample per second: 424464
# SVD++: Epoch 186 of 430.0. Elapsed time 3.00 min
# SVD++: Processed 800176 (100.0%) in 1.90 sec. MSE loss 6.52E+00. Sample per second: 420738
# SVD++: Epoch 187 of 430.0. Elapsed time 3.01 min
# SVD++: Processed 800176 (100.0%) in 1.91 sec. MSE loss 6.50E+00. Sample per second: 417563
# SVD++: Epoch 188 of 430.0. Elapsed time 3.03 min
# SVD++: Processed 800176 (100.0%) in 1.94 sec. MSE loss 6.48E+00. Sample per second: 413451
# SVD++: Epoch 189 of 430.0. Elapsed time 3.05 min
# SVD++: Processed 800176 (100.0%) in 1.96 sec. MSE loss 6.47E+00. Sample per second: 407784
# SVD++: Epoch 190 of 430.0. Elapsed time 3.06 min
# SVD++: Processed 800176 (100.0%) in 1.98 sec. MSE loss 6.45E+00. Sample per second: 403642
# SVD++: Epoch 191 of 430.0. Elapsed time 3.08 min
# SVD++: Processed 800176 (100.0%) in 2.01 sec. MSE loss 6.44E+00. Sample per second: 398016
# SVD++: Epoch 192 of 430.0. Elapsed time 3.10 min
# SVD++: Processed 800176 (100.0%) in 1.03 sec. MSE loss 6.42E+00. Sample per second: 775557
# SVD++: Epoch 193 of 430.0. Elapsed time 3.11 min
# SVD++: Processed 800176 (100.0%) in 0.89 sec. MSE loss 6.41E+00. Sample per second: 900347
# SVD++: Epoch 194 of 430.0. Elapsed time 3.13 min
# SVD++: Processed 800176 (100.0%) in 1.56 sec. MSE loss 6.39E+00. Sample per second: 514386
# SVD++: Epoch 195 of 430.0. Elapsed time 3.14 min
# SVD++: Processed 800176 (100.0%) in 1.56 sec. MSE loss 6.38E+00. Sample per second: 511669
# SVD++: Epoch 196 of 430.0. Elapsed time 3.16 min
# SVD++: Processed 800176 (100.0%) in 1.57 sec. MSE loss 6.36E+00. Sample per second: 509448
# SVD++: Epoch 197 of 430.0. Elapsed time 3.17 min
# SVD++: Processed 800176 (100.0%) in 1.57 sec. MSE loss 6.34E+00. Sample per second: 510579
# SVD++: Epoch 198 of 430.0. Elapsed time 3.19 min
# SVD++: Processed 800176 (100.0%) in 1.55 sec. MSE loss 6.33E+00. Sample per second: 512288
# SVD++: Epoch 199 of 430.0. Elapsed time 3.21 min
# SVD++: Processed 800176 (100.0%) in 1.56 sec. MSE loss 6.31E+00. Sample per second: 512845
# SVD++: Epoch 200 of 430.0. Elapsed time 3.22 min
# SVD++: Processed 800176 (100.0%) in 1.59 sec. MSE loss 6.30E+00. Sample per second: 504799
# SVD++: Epoch 201 of 430.0. Elapsed time 3.24 min
# SVD++: Processed 800176 (100.0%) in 1.60 sec. MSE loss 6.28E+00. Sample per second: 499017
# SVD++: Epoch 202 of 430.0. Elapsed time 3.26 min
# SVD++: Processed 800176 (100.0%) in 1.63 sec. MSE loss 6.27E+00. Sample per second: 490847
# SVD++: Epoch 203 of 430.0. Elapsed time 3.27 min
# SVD++: Processed 800176 (100.0%) in 1.65 sec. MSE loss 6.25E+00. Sample per second: 483545
# SVD++: Epoch 204 of 430.0. Elapsed time 3.29 min
# SVD++: Processed 800176 (100.0%) in 1.32 sec. MSE loss 6.24E+00. Sample per second: 604593
# SVD++: Epoch 205 of 430.0. Elapsed time 3.30 min
# SVD++: Processed 800176 (100.0%) in 1.17 sec. MSE loss 6.22E+00. Sample per second: 683554
# SVD++: Epoch 206 of 430.0. Elapsed time 3.32 min
# SVD++: Processed 800176 (100.0%) in 1.19 sec. MSE loss 6.21E+00. Sample per second: 669386
# SVD++: Epoch 207 of 430.0. Elapsed time 3.33 min
# SVD++: Processed 800176 (100.0%) in 1.20 sec. MSE loss 6.20E+00. Sample per second: 664470
# SVD++: Epoch 208 of 430.0. Elapsed time 3.35 min
# SVD++: Processed 800176 (100.0%) in 1.21 sec. MSE loss 6.18E+00. Sample per second: 659687
# SVD++: Epoch 209 of 430.0. Elapsed time 3.37 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 6.17E+00. Sample per second: 647583
# SVD++: Epoch 210 of 430.0. Elapsed time 3.38 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 6.16E+00. Sample per second: 643887
# SVD++: Epoch 211 of 430.0. Elapsed time 3.40 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 6.14E+00. Sample per second: 644704
# SVD++: Epoch 212 of 430.0. Elapsed time 3.42 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 6.12E+00. Sample per second: 642255
# SVD++: Epoch 213 of 430.0. Elapsed time 3.43 min
# SVD++: Processed 800176 (100.0%) in 1.26 sec. MSE loss 6.12E+00. Sample per second: 632887
# SVD++: Epoch 214 of 430.0. Elapsed time 3.45 min
# SVD++: Processed 800176 (100.0%) in 1.08 sec. MSE loss 6.09E+00. Sample per second: 740363
# SVD++: Epoch 215 of 430.0. Elapsed time 3.47 min
# SVD++: Processed 800176 (100.0%) in 0.78 sec. MSE loss 6.08E+00. Sample per second: 1026561
# SVD++: Epoch 216 of 430.0. Elapsed time 3.48 min
# SVD++: Processed 800176 (100.0%) in 1.79 sec. MSE loss 6.07E+00. Sample per second: 445551
# SVD++: Epoch 217 of 430.0. Elapsed time 3.49 min
# SVD++: Processed 800176 (100.0%) in 1.81 sec. MSE loss 6.06E+00. Sample per second: 441454
# SVD++: Epoch 218 of 430.0. Elapsed time 3.51 min
# SVD++: Processed 800176 (100.0%) in 1.83 sec. MSE loss 6.04E+00. Sample per second: 437458
# SVD++: Epoch 219 of 430.0. Elapsed time 3.53 min
# SVD++: Processed 800176 (100.0%) in 1.85 sec. MSE loss 6.02E+00. Sample per second: 431589
# SVD++: Epoch 220 of 430.0. Elapsed time 3.54 min
# SVD++: Processed 800176 (100.0%) in 1.87 sec. MSE loss 6.02E+00. Sample per second: 427311
# SVD++: Epoch 221 of 430.0. Elapsed time 3.56 min
# SVD++: Processed 800176 (100.0%) in 1.90 sec. MSE loss 6.01E+00. Sample per second: 421265
# SVD++: Epoch 222 of 430.0. Elapsed time 3.58 min
# SVD++: Processed 800176 (100.0%) in 1.91 sec. MSE loss 6.00E+00. Sample per second: 418063
# SVD++: Epoch 223 of 430.0. Elapsed time 3.60 min
# SVD++: Processed 800176 (100.0%) in 1.92 sec. MSE loss 5.97E+00. Sample per second: 416551
# SVD++: Epoch 224 of 430.0. Elapsed time 3.61 min
# SVD++: Processed 800176 (100.0%) in 1.89 sec. MSE loss 5.96E+00. Sample per second: 423580
# SVD++: Epoch 225 of 430.0. Elapsed time 3.63 min
# SVD++: Processed 800176 (100.0%) in 1.55 sec. MSE loss 5.95E+00. Sample per second: 516880
# SVD++: Epoch 226 of 430.0. Elapsed time 3.64 min
# SVD++: Processed 800176 (100.0%) in 1.46 sec. MSE loss 5.95E+00. Sample per second: 546242
# SVD++: Epoch 227 of 430.0. Elapsed time 3.66 min
# SVD++: Processed 800176 (100.0%) in 1.49 sec. MSE loss 5.92E+00. Sample per second: 536377
# SVD++: Epoch 228 of 430.0. Elapsed time 3.67 min
# SVD++: Processed 800176 (100.0%) in 1.52 sec. MSE loss 5.91E+00. Sample per second: 526966
# SVD++: Epoch 229 of 430.0. Elapsed time 3.69 min
# SVD++: Processed 800176 (100.0%) in 1.54 sec. MSE loss 5.90E+00. Sample per second: 521210
# SVD++: Epoch 230 of 430.0. Elapsed time 3.71 min
# SVD++: Processed 800176 (100.0%) in 1.58 sec. MSE loss 5.89E+00. Sample per second: 505921
# SVD++: Epoch 231 of 430.0. Elapsed time 3.72 min
# SVD++: Processed 800176 (100.0%) in 1.65 sec. MSE loss 5.87E+00. Sample per second: 485405
# SVD++: Epoch 232 of 430.0. Elapsed time 3.74 min
# SVD++: Processed 800176 (100.0%) in 1.72 sec. MSE loss 5.86E+00. Sample per second: 466543
# SVD++: Epoch 233 of 430.0. Elapsed time 3.76 min
# SVD++: Processed 800176 (100.0%) in 1.73 sec. MSE loss 5.84E+00. Sample per second: 461983
# SVD++: Epoch 234 of 430.0. Elapsed time 3.78 min
# SVD++: Processed 800176 (100.0%) in 1.75 sec. MSE loss 5.84E+00. Sample per second: 457588
# SVD++: Epoch 235 of 430.0. Elapsed time 3.79 min
# SVD++: Processed 800176 (100.0%) in 1.44 sec. MSE loss 5.82E+00. Sample per second: 553064
# SVD++: Epoch 236 of 430.0. Elapsed time 3.80 min
# SVD++: Processed 800176 (100.0%) in 1.26 sec. MSE loss 5.82E+00. Sample per second: 632691
# SVD++: Epoch 237 of 430.0. Elapsed time 3.82 min
# SVD++: Processed 800176 (100.0%) in 1.28 sec. MSE loss 5.80E+00. Sample per second: 624290
# SVD++: Epoch 238 of 430.0. Elapsed time 3.84 min
# SVD++: Processed 800176 (100.0%) in 1.30 sec. MSE loss 5.78E+00. Sample per second: 616231
# SVD++: Epoch 239 of 430.0. Elapsed time 3.85 min
# SVD++: Processed 800176 (100.0%) in 1.32 sec. MSE loss 5.78E+00. Sample per second: 608245
# SVD++: Epoch 240 of 430.0. Elapsed time 3.87 min
# SVD++: Processed 800176 (100.0%) in 1.34 sec. MSE loss 5.76E+00. Sample per second: 596123
# SVD++: Epoch 241 of 430.0. Elapsed time 3.89 min
# SVD++: Processed 800176 (100.0%) in 1.36 sec. MSE loss 5.75E+00. Sample per second: 588692
# SVD++: Epoch 242 of 430.0. Elapsed time 3.90 min
# SVD++: Processed 800176 (100.0%) in 1.36 sec. MSE loss 5.73E+00. Sample per second: 589837
# SVD++: Epoch 243 of 430.0. Elapsed time 3.92 min
# SVD++: Processed 800176 (100.0%) in 1.37 sec. MSE loss 5.72E+00. Sample per second: 582693
# SVD++: Epoch 244 of 430.0. Elapsed time 3.94 min
# SVD++: Processed 800176 (100.0%) in 1.39 sec. MSE loss 5.70E+00. Sample per second: 575794
# SVD++: Epoch 245 of 430.0. Elapsed time 3.95 min
# SVD++: Processed 800176 (100.0%) in 1.26 sec. MSE loss 5.70E+00. Sample per second: 636617
# SVD++: Epoch 246 of 430.0. Elapsed time 3.97 min
# SVD++: Processed 800176 (100.0%) in 0.92 sec. MSE loss 5.69E+00. Sample per second: 867170
# SVD++: Epoch 247 of 430.0. Elapsed time 3.98 min
# SVD++: Processed 800176 (100.0%) in 1.94 sec. MSE loss 5.67E+00. Sample per second: 412650
# SVD++: Epoch 248 of 430.0. Elapsed time 4.00 min
# SVD++: Processed 800176 (100.0%) in 1.94 sec. MSE loss 5.66E+00. Sample per second: 412910
# SVD++: Epoch 249 of 430.0. Elapsed time 4.01 min
# SVD++: Processed 800176 (100.0%) in 1.94 sec. MSE loss 5.65E+00. Sample per second: 411511
# SVD++: Epoch 250 of 430.0. Elapsed time 4.03 min
# SVD++: Processed 800176 (100.0%) in 1.95 sec. MSE loss 5.63E+00. Sample per second: 410053
# SVD++: Epoch 251 of 430.0. Elapsed time 4.05 min
# SVD++: Processed 800176 (100.0%) in 1.97 sec. MSE loss 5.62E+00. Sample per second: 406563
# SVD++: Epoch 252 of 430.0. Elapsed time 4.06 min
# SVD++: Processed 800176 (100.0%) in 1.98 sec. MSE loss 5.62E+00. Sample per second: 405120
# SVD++: Epoch 253 of 430.0. Elapsed time 4.08 min
# SVD++: Processed 800176 (100.0%) in 2.00 sec. MSE loss 5.61E+00. Sample per second: 398159
# SVD++: Epoch 254 of 430.0. Elapsed time 4.10 min
# SVD++: Processed 800176 (100.0%) in 1.04 sec. MSE loss 5.59E+00. Sample per second: 772264
# SVD++: Epoch 255 of 430.0. Elapsed time 4.11 min
# SVD++: Processed 800176 (100.0%) in 1.04 sec. MSE loss 5.58E+00. Sample per second: 766368
# SVD++: Epoch 256 of 430.0. Elapsed time 4.13 min
# SVD++: Processed 800176 (100.0%) in 0.70 sec. MSE loss 5.57E+00. Sample per second: 1140027
# SVD++: Epoch 257 of 430.0. Elapsed time 4.14 min
# SVD++: Processed 800176 (100.0%) in 1.59 sec. MSE loss 5.55E+00. Sample per second: 503629
# SVD++: Epoch 258 of 430.0. Elapsed time 4.16 min
# SVD++: Processed 800176 (100.0%) in 1.62 sec. MSE loss 5.55E+00. Sample per second: 492913
# SVD++: Epoch 259 of 430.0. Elapsed time 4.17 min
# SVD++: Processed 800176 (100.0%) in 1.63 sec. MSE loss 5.54E+00. Sample per second: 490457
# SVD++: Epoch 260 of 430.0. Elapsed time 4.19 min
# SVD++: Processed 800176 (100.0%) in 1.64 sec. MSE loss 5.52E+00. Sample per second: 488505
# SVD++: Epoch 261 of 430.0. Elapsed time 4.21 min
# SVD++: Processed 800176 (100.0%) in 1.66 sec. MSE loss 5.51E+00. Sample per second: 480692
# SVD++: Epoch 262 of 430.0. Elapsed time 4.23 min
# SVD++: Processed 800176 (100.0%) in 1.69 sec. MSE loss 5.49E+00. Sample per second: 473131
# SVD++: Epoch 263 of 430.0. Elapsed time 4.24 min
# SVD++: Processed 800176 (100.0%) in 1.71 sec. MSE loss 5.48E+00. Sample per second: 468533
# SVD++: Epoch 264 of 430.0. Elapsed time 4.26 min
# SVD++: Processed 800176 (100.0%) in 1.70 sec. MSE loss 5.48E+00. Sample per second: 469448
# SVD++: Epoch 265 of 430.0. Elapsed time 4.28 min
# SVD++: Processed 800176 (100.0%) in 1.70 sec. MSE loss 5.46E+00. Sample per second: 470406
# SVD++: Epoch 266 of 430.0. Elapsed time 4.29 min
# SVD++: Processed 800176 (100.0%) in 1.50 sec. MSE loss 5.45E+00. Sample per second: 534142
# SVD++: Epoch 267 of 430.0. Elapsed time 4.31 min
# SVD++: Processed 800176 (100.0%) in 1.22 sec. MSE loss 5.44E+00. Sample per second: 649348
# SVD++: Epoch 268 of 430.0. Elapsed time 4.32 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 5.43E+00. Sample per second: 644717
# SVD++: Epoch 269 of 430.0. Elapsed time 4.33 min
# SVD++: Processed 800176 (100.0%) in 1.27 sec. MSE loss 5.42E+00. Sample per second: 631131
# SVD++: Epoch 270 of 430.0. Elapsed time 4.35 min
# SVD++: Processed 800176 (100.0%) in 1.29 sec. MSE loss 5.41E+00. Sample per second: 617947
# SVD++: Epoch 271 of 430.0. Elapsed time 4.37 min
# SVD++: Processed 800176 (100.0%) in 1.33 sec. MSE loss 5.40E+00. Sample per second: 600926
# SVD++: Epoch 272 of 430.0. Elapsed time 4.39 min
# SVD++: Processed 800176 (100.0%) in 1.37 sec. MSE loss 5.39E+00. Sample per second: 584621
# SVD++: Epoch 273 of 430.0. Elapsed time 4.40 min
# SVD++: Processed 800176 (100.0%) in 1.41 sec. MSE loss 5.38E+00. Sample per second: 569400
# SVD++: Epoch 274 of 430.0. Elapsed time 4.42 min
# SVD++: Processed 800176 (100.0%) in 1.42 sec. MSE loss 5.36E+00. Sample per second: 559470
# SVD++: Epoch 275 of 430.0. Elapsed time 4.44 min
# SVD++: Processed 800176 (100.0%) in 1.45 sec. MSE loss 5.36E+00. Sample per second: 552305
# SVD++: Epoch 276 of 430.0. Elapsed time 4.45 min
# SVD++: Processed 800176 (100.0%) in 1.36 sec. MSE loss 5.35E+00. Sample per second: 586082
# SVD++: Epoch 277 of 430.0. Elapsed time 4.47 min
# SVD++: Processed 800176 (100.0%) in 1.01 sec. MSE loss 5.34E+00. Sample per second: 789601
# SVD++: Epoch 278 of 430.0. Elapsed time 4.48 min
# SVD++: Processed 800176 (100.0%) in 0.99 sec. MSE loss 5.32E+00. Sample per second: 810028
# SVD++: Epoch 279 of 430.0. Elapsed time 4.50 min
# SVD++: Processed 800176 (100.0%) in 2.00 sec. MSE loss 5.31E+00. Sample per second: 400802
# SVD++: Epoch 280 of 430.0. Elapsed time 4.51 min
# SVD++: Processed 800176 (100.0%) in 2.01 sec. MSE loss 5.30E+00. Sample per second: 397557
# SVD++: Epoch 281 of 430.0. Elapsed time 4.53 min
# SVD++: Processed 800176 (100.0%) in 1.03 sec. MSE loss 5.29E+00. Sample per second: 777354
# SVD++: Epoch 282 of 430.0. Elapsed time 4.55 min
# SVD++: Processed 800176 (100.0%) in 1.05 sec. MSE loss 5.28E+00. Sample per second: 765154
# SVD++: Epoch 283 of 430.0. Elapsed time 4.56 min
# SVD++: Processed 800176 (100.0%) in 1.07 sec. MSE loss 5.28E+00. Sample per second: 746051
# SVD++: Epoch 284 of 430.0. Elapsed time 4.58 min
# SVD++: Processed 800176 (100.0%) in 1.09 sec. MSE loss 5.27E+00. Sample per second: 736177
# SVD++: Epoch 285 of 430.0. Elapsed time 4.60 min
# SVD++: Processed 800176 (100.0%) in 1.11 sec. MSE loss 5.25E+00. Sample per second: 723710
# SVD++: Epoch 286 of 430.0. Elapsed time 4.62 min
# SVD++: Processed 800176 (100.0%) in 1.14 sec. MSE loss 5.24E+00. Sample per second: 701775
# SVD++: Epoch 287 of 430.0. Elapsed time 4.63 min
# SVD++: Processed 800176 (100.0%) in 0.84 sec. MSE loss 5.23E+00. Sample per second: 952948
# SVD++: Epoch 288 of 430.0. Elapsed time 4.64 min
# SVD++: Processed 800176 (100.0%) in 1.71 sec. MSE loss 5.22E+00. Sample per second: 468623
# SVD++: Epoch 289 of 430.0. Elapsed time 4.66 min
# SVD++: Processed 800176 (100.0%) in 1.73 sec. MSE loss 5.21E+00. Sample per second: 461230
# SVD++: Epoch 290 of 430.0. Elapsed time 4.68 min
# SVD++: Processed 800176 (100.0%) in 1.75 sec. MSE loss 5.20E+00. Sample per second: 456855
# SVD++: Epoch 291 of 430.0. Elapsed time 4.69 min
# SVD++: Processed 800176 (100.0%) in 1.77 sec. MSE loss 5.18E+00. Sample per second: 452505
# SVD++: Epoch 292 of 430.0. Elapsed time 4.71 min
# SVD++: Processed 800176 (100.0%) in 1.80 sec. MSE loss 5.17E+00. Sample per second: 443818
# SVD++: Epoch 293 of 430.0. Elapsed time 4.73 min
# SVD++: Processed 800176 (100.0%) in 1.83 sec. MSE loss 5.17E+00. Sample per second: 437341
# SVD++: Epoch 294 of 430.0. Elapsed time 4.74 min
# SVD++: Processed 800176 (100.0%) in 1.84 sec. MSE loss 5.16E+00. Sample per second: 435379
# SVD++: Epoch 295 of 430.0. Elapsed time 4.76 min
# SVD++: Processed 800176 (100.0%) in 1.84 sec. MSE loss 5.14E+00. Sample per second: 433861
# SVD++: Epoch 296 of 430.0. Elapsed time 4.78 min
# SVD++: Processed 800176 (100.0%) in 1.86 sec. MSE loss 5.14E+00. Sample per second: 430018
# SVD++: Epoch 297 of 430.0. Elapsed time 4.79 min
# SVD++: Processed 800176 (100.0%) in 1.68 sec. MSE loss 5.13E+00. Sample per second: 476909
# SVD++: Epoch 298 of 430.0. Elapsed time 4.81 min
# SVD++: Processed 800176 (100.0%) in 1.39 sec. MSE loss 5.12E+00. Sample per second: 577452
# SVD++: Epoch 299 of 430.0. Elapsed time 4.82 min
# SVD++: Processed 800176 (100.0%) in 1.40 sec. MSE loss 5.11E+00. Sample per second: 570486
# SVD++: Epoch 300 of 430.0. Elapsed time 4.84 min
# SVD++: Processed 800176 (100.0%) in 1.41 sec. MSE loss 5.10E+00. Sample per second: 564608
# SVD++: Epoch 301 of 430.0. Elapsed time 4.85 min
# SVD++: Processed 800176 (100.0%) in 1.42 sec. MSE loss 5.08E+00. Sample per second: 561114
# SVD++: Epoch 302 of 430.0. Elapsed time 4.87 min
# SVD++: Processed 800176 (100.0%) in 1.43 sec. MSE loss 5.07E+00. Sample per second: 558548
# SVD++: Epoch 303 of 430.0. Elapsed time 4.89 min
# SVD++: Processed 800176 (100.0%) in 1.46 sec. MSE loss 5.06E+00. Sample per second: 548234
# SVD++: Epoch 304 of 430.0. Elapsed time 4.90 min
# SVD++: Processed 800176 (100.0%) in 1.48 sec. MSE loss 5.06E+00. Sample per second: 542008
# SVD++: Epoch 305 of 430.0. Elapsed time 4.92 min
# SVD++: Processed 800176 (100.0%) in 1.49 sec. MSE loss 5.04E+00. Sample per second: 535854
# SVD++: Epoch 306 of 430.0. Elapsed time 4.94 min
# SVD++: Processed 800176 (100.0%) in 1.51 sec. MSE loss 5.04E+00. Sample per second: 527197
# SVD++: Epoch 307 of 430.0. Elapsed time 4.96 min
# SVD++: Processed 800176 (100.0%) in 1.48 sec. MSE loss 5.03E+00. Sample per second: 542146
# SVD++: Epoch 308 of 430.0. Elapsed time 4.97 min
# SVD++: Processed 800176 (100.0%) in 1.13 sec. MSE loss 5.02E+00. Sample per second: 705131
# SVD++: Epoch 309 of 430.0. Elapsed time 4.98 min
# SVD++: Processed 800176 (100.0%) in 1.04 sec. MSE loss 5.01E+00. Sample per second: 768277
# SVD++: Epoch 310 of 430.0. Elapsed time 5.00 min
# SVD++: Processed 800176 (100.0%) in 1.05 sec. MSE loss 5.00E+00. Sample per second: 763322
# SVD++: Epoch 311 of 430.0. Elapsed time 5.01 min
# SVD++: Processed 800176 (100.0%) in 1.07 sec. MSE loss 4.98E+00. Sample per second: 744534
# SVD++: Epoch 312 of 430.0. Elapsed time 5.03 min
# SVD++: Processed 800176 (100.0%) in 1.11 sec. MSE loss 4.98E+00. Sample per second: 719674
# SVD++: Epoch 313 of 430.0. Elapsed time 5.05 min
# SVD++: Processed 800176 (100.0%) in 1.14 sec. MSE loss 4.97E+00. Sample per second: 703403
# SVD++: Epoch 314 of 430.0. Elapsed time 5.07 min
# SVD++: Processed 800176 (100.0%) in 1.16 sec. MSE loss 4.96E+00. Sample per second: 691515
# SVD++: Epoch 315 of 430.0. Elapsed time 5.08 min
# SVD++: Processed 800176 (100.0%) in 1.19 sec. MSE loss 4.95E+00. Sample per second: 673639
# SVD++: Epoch 316 of 430.0. Elapsed time 5.10 min
# SVD++: Processed 800176 (100.0%) in 1.21 sec. MSE loss 4.94E+00. Sample per second: 658892
# SVD++: Epoch 317 of 430.0. Elapsed time 5.12 min
# SVD++: Processed 800176 (100.0%) in 1.24 sec. MSE loss 4.93E+00. Sample per second: 647655
# SVD++: Epoch 318 of 430.0. Elapsed time 5.13 min
# SVD++: Processed 800176 (100.0%) in 0.97 sec. MSE loss 4.92E+00. Sample per second: 823885
# SVD++: Epoch 319 of 430.0. Elapsed time 5.15 min
# SVD++: Processed 800176 (100.0%) in 1.78 sec. MSE loss 4.92E+00. Sample per second: 449322
# SVD++: Epoch 320 of 430.0. Elapsed time 5.16 min
# SVD++: Processed 800176 (100.0%) in 1.81 sec. MSE loss 4.90E+00. Sample per second: 442637
# SVD++: Epoch 321 of 430.0. Elapsed time 5.18 min
# SVD++: Processed 800176 (100.0%) in 1.83 sec. MSE loss 4.90E+00. Sample per second: 436662
# SVD++: Epoch 322 of 430.0. Elapsed time 5.19 min
# SVD++: Processed 800176 (100.0%) in 1.84 sec. MSE loss 4.89E+00. Sample per second: 434576
# SVD++: Epoch 323 of 430.0. Elapsed time 5.21 min
# SVD++: Processed 800176 (100.0%) in 1.86 sec. MSE loss 4.88E+00. Sample per second: 430740
# SVD++: Epoch 324 of 430.0. Elapsed time 5.23 min
# SVD++: Processed 800176 (100.0%) in 1.87 sec. MSE loss 4.87E+00. Sample per second: 425098
# SVD++: Epoch 325 of 430.0. Elapsed time 5.25 min
# SVD++: Processed 800176 (100.0%) in 1.90 sec. MSE loss 4.86E+00. Sample per second: 421419
# SVD++: Epoch 326 of 430.0. Elapsed time 5.26 min
# SVD++: Processed 800176 (100.0%) in 1.92 sec. MSE loss 4.85E+00. Sample per second: 417310
# SVD++: Epoch 327 of 430.0. Elapsed time 5.28 min
# SVD++: Processed 800176 (100.0%) in 1.93 sec. MSE loss 4.84E+00. Sample per second: 413813
# SVD++: Epoch 328 of 430.0. Elapsed time 5.30 min
# SVD++: Processed 800176 (100.0%) in 1.80 sec. MSE loss 4.84E+00. Sample per second: 442604
# SVD++: Epoch 329 of 430.0. Elapsed time 5.31 min
# SVD++: Processed 800176 (100.0%) in 1.49 sec. MSE loss 4.83E+00. Sample per second: 537834
# SVD++: Epoch 330 of 430.0. Elapsed time 5.32 min
# SVD++: Processed 800176 (100.0%) in 1.50 sec. MSE loss 4.81E+00. Sample per second: 531927
# SVD++: Epoch 331 of 430.0. Elapsed time 5.34 min
# SVD++: Processed 800176 (100.0%) in 1.52 sec. MSE loss 4.80E+00. Sample per second: 526145
# SVD++: Epoch 332 of 430.0. Elapsed time 5.36 min
# SVD++: Processed 800176 (100.0%) in 1.55 sec. MSE loss 4.80E+00. Sample per second: 517667
# SVD++: Epoch 333 of 430.0. Elapsed time 5.37 min
# SVD++: Processed 800176 (100.0%) in 1.57 sec. MSE loss 4.79E+00. Sample per second: 508219
# SVD++: Epoch 334 of 430.0. Elapsed time 5.39 min
# SVD++: Processed 800176 (100.0%) in 1.60 sec. MSE loss 4.78E+00. Sample per second: 499576
# SVD++: Epoch 335 of 430.0. Elapsed time 5.41 min
# SVD++: Processed 800176 (100.0%) in 1.63 sec. MSE loss 4.78E+00. Sample per second: 491339
# SVD++: Epoch 336 of 430.0. Elapsed time 5.42 min
# SVD++: Processed 800176 (100.0%) in 1.66 sec. MSE loss 4.77E+00. Sample per second: 483420
# SVD++: Epoch 337 of 430.0. Elapsed time 5.44 min
# SVD++: Processed 800176 (100.0%) in 1.68 sec. MSE loss 4.75E+00. Sample per second: 475833
# SVD++: Epoch 338 of 430.0. Elapsed time 5.46 min
# SVD++: Processed 800176 (100.0%) in 1.67 sec. MSE loss 4.74E+00. Sample per second: 479749
# SVD++: Epoch 339 of 430.0. Elapsed time 5.48 min
# SVD++: Processed 800176 (100.0%) in 1.32 sec. MSE loss 4.73E+00. Sample per second: 603737
# SVD++: Epoch 340 of 430.0. Elapsed time 5.49 min
# SVD++: Processed 800176 (100.0%) in 1.25 sec. MSE loss 4.72E+00. Sample per second: 638925
# SVD++: Epoch 341 of 430.0. Elapsed time 5.50 min
# SVD++: Processed 800176 (100.0%) in 1.27 sec. MSE loss 4.71E+00. Sample per second: 630642
# SVD++: Epoch 342 of 430.0. Elapsed time 5.52 min
# SVD++: Processed 800176 (100.0%) in 1.29 sec. MSE loss 4.71E+00. Sample per second: 622457
# SVD++: Epoch 343 of 430.0. Elapsed time 5.54 min
# SVD++: Processed 800176 (100.0%) in 1.31 sec. MSE loss 4.69E+00. Sample per second: 609859
# SVD++: Epoch 344 of 430.0. Elapsed time 5.55 min
# SVD++: Processed 800176 (100.0%) in 1.34 sec. MSE loss 4.69E+00. Sample per second: 597700
# SVD++: Epoch 345 of 430.0. Elapsed time 5.57 min
# SVD++: Processed 800176 (100.0%) in 1.35 sec. MSE loss 4.68E+00. Sample per second: 591214
# SVD++: Epoch 346 of 430.0. Elapsed time 5.59 min
# SVD++: Processed 800176 (100.0%) in 1.37 sec. MSE loss 4.68E+00. Sample per second: 583157
# SVD++: Epoch 347 of 430.0. Elapsed time 5.60 min
# SVD++: Processed 800176 (100.0%) in 1.39 sec. MSE loss 4.67E+00. Sample per second: 576263
# SVD++: Epoch 348 of 430.0. Elapsed time 5.62 min
# SVD++: Processed 800176 (100.0%) in 1.41 sec. MSE loss 4.66E+00. Sample per second: 569465
# SVD++: Epoch 349 of 430.0. Elapsed time 5.64 min
# SVD++: Processed 800176 (100.0%) in 1.14 sec. MSE loss 4.65E+00. Sample per second: 700413
# SVD++: Epoch 350 of 430.0. Elapsed time 5.65 min
# SVD++: Processed 800176 (100.0%) in 0.93 sec. MSE loss 4.64E+00. Sample per second: 859960
# SVD++: Epoch 351 of 430.0. Elapsed time 5.66 min
# SVD++: Processed 800176 (100.0%) in 1.94 sec. MSE loss 4.63E+00. Sample per second: 413058
# SVD++: Epoch 352 of 430.0. Elapsed time 5.68 min
# SVD++: Processed 800176 (100.0%) in 1.93 sec. MSE loss 4.63E+00. Sample per second: 413868
# SVD++: Epoch 353 of 430.0. Elapsed time 5.70 min
# SVD++: Processed 800176 (100.0%) in 1.95 sec. MSE loss 4.62E+00. Sample per second: 410360
# SVD++: Epoch 354 of 430.0. Elapsed time 5.71 min
# SVD++: Processed 800176 (100.0%) in 1.98 sec. MSE loss 4.61E+00. Sample per second: 404842
# SVD++: Epoch 355 of 430.0. Elapsed time 5.73 min
# SVD++: Processed 800176 (100.0%) in 2.00 sec. MSE loss 4.60E+00. Sample per second: 399424
# SVD++: Epoch 356 of 430.0. Elapsed time 5.75 min
# SVD++: Processed 800176 (100.0%) in 1.00 sec. MSE loss 4.59E+00. Sample per second: 800326
# SVD++: Epoch 357 of 430.0. Elapsed time 5.76 min
# SVD++: Processed 800176 (100.0%) in 2.00 sec. MSE loss 4.58E+00. Sample per second: 400740
# SVD++: Epoch 358 of 430.0. Elapsed time 5.78 min
# SVD++: Processed 800176 (100.0%) in 2.01 sec. MSE loss 4.58E+00. Sample per second: 397435
# SVD++: Epoch 359 of 430.0. Elapsed time 5.80 min
# SVD++: Processed 800176 (100.0%) in 0.92 sec. MSE loss 4.58E+00. Sample per second: 869628
# SVD++: Epoch 360 of 430.0. Elapsed time 5.81 min
# SVD++: Processed 800176 (100.0%) in 1.69 sec. MSE loss 4.56E+00. Sample per second: 473927
# SVD++: Epoch 361 of 430.0. Elapsed time 5.83 min
# SVD++: Processed 800176 (100.0%) in 1.75 sec. MSE loss 4.56E+00. Sample per second: 457321
# SVD++: Epoch 362 of 430.0. Elapsed time 5.84 min
# SVD++: Processed 800176 (100.0%) in 1.96 sec. MSE loss 4.55E+00. Sample per second: 408841
# SVD++: Epoch 363 of 430.0. Elapsed time 5.86 min
# SVD++: Processed 800176 (100.0%) in 2.00 sec. MSE loss 4.54E+00. Sample per second: 399555
# SVD++: Epoch 364 of 430.0. Elapsed time 5.88 min
# SVD++: Processed 800176 (100.0%) in 1.01 sec. MSE loss 4.53E+00. Sample per second: 791545
# SVD++: Epoch 365 of 430.0. Elapsed time 5.90 min
# SVD++: Processed 800176 (100.0%) in 1.03 sec. MSE loss 4.52E+00. Sample per second: 778762
# SVD++: Epoch 366 of 430.0. Elapsed time 5.91 min
# SVD++: Processed 800176 (100.0%) in 1.03 sec. MSE loss 4.52E+00. Sample per second: 773811
# SVD++: Epoch 367 of 430.0. Elapsed time 5.93 min
# SVD++: Processed 800176 (100.0%) in 1.03 sec. MSE loss 4.51E+00. Sample per second: 776160
# SVD++: Epoch 368 of 430.0. Elapsed time 5.95 min
# SVD++: Processed 800176 (100.0%) in 1.05 sec. MSE loss 4.50E+00. Sample per second: 763803
# SVD++: Epoch 369 of 430.0. Elapsed time 5.96 min
# SVD++: Processed 800176 (100.0%) in 0.97 sec. MSE loss 4.49E+00. Sample per second: 821025
# SVD++: Epoch 370 of 430.0. Elapsed time 5.98 min
# SVD++: Processed 800176 (100.0%) in 1.63 sec. MSE loss 4.48E+00. Sample per second: 490315
# SVD++: Epoch 371 of 430.0. Elapsed time 5.99 min
# SVD++: Processed 800176 (100.0%) in 1.61 sec. MSE loss 4.47E+00. Sample per second: 496640
# SVD++: Epoch 372 of 430.0. Elapsed time 6.01 min
# SVD++: Processed 800176 (100.0%) in 1.64 sec. MSE loss 4.46E+00. Sample per second: 488608
# SVD++: Epoch 373 of 430.0. Elapsed time 6.02 min
# SVD++: Processed 800176 (100.0%) in 1.67 sec. MSE loss 4.46E+00. Sample per second: 478483
# SVD++: Epoch 374 of 430.0. Elapsed time 6.04 min
# SVD++: Processed 800176 (100.0%) in 1.69 sec. MSE loss 4.45E+00. Sample per second: 473297
# SVD++: Epoch 375 of 430.0. Elapsed time 6.06 min
# SVD++: Processed 800176 (100.0%) in 1.71 sec. MSE loss 4.45E+00. Sample per second: 469282
# SVD++: Epoch 376 of 430.0. Elapsed time 6.08 min
# SVD++: Processed 800176 (100.0%) in 1.72 sec. MSE loss 4.43E+00. Sample per second: 464841
# SVD++: Epoch 377 of 430.0. Elapsed time 6.09 min
# SVD++: Processed 800176 (100.0%) in 1.73 sec. MSE loss 4.43E+00. Sample per second: 462548
# SVD++: Epoch 378 of 430.0. Elapsed time 6.11 min
# SVD++: Processed 800176 (100.0%) in 1.74 sec. MSE loss 4.42E+00. Sample per second: 460905
# SVD++: Epoch 379 of 430.0. Elapsed time 6.13 min
# SVD++: Processed 800176 (100.0%) in 1.75 sec. MSE loss 4.41E+00. Sample per second: 457101
# SVD++: Epoch 380 of 430.0. Elapsed time 6.14 min
# SVD++: Processed 800176 (100.0%) in 1.44 sec. MSE loss 4.40E+00. Sample per second: 555982
# SVD++: Epoch 381 of 430.0. Elapsed time 6.15 min
# SVD++: Processed 800176 (100.0%) in 1.27 sec. MSE loss 4.41E+00. Sample per second: 631483
# SVD++: Epoch 382 of 430.0. Elapsed time 6.17 min
# SVD++: Processed 800176 (100.0%) in 1.28 sec. MSE loss 4.39E+00. Sample per second: 623452
# SVD++: Epoch 383 of 430.0. Elapsed time 6.19 min
# SVD++: Processed 800176 (100.0%) in 1.32 sec. MSE loss 4.39E+00. Sample per second: 606060
# SVD++: Epoch 384 of 430.0. Elapsed time 6.20 min
# SVD++: Processed 800176 (100.0%) in 1.35 sec. MSE loss 4.37E+00. Sample per second: 594119
# SVD++: Epoch 385 of 430.0. Elapsed time 6.22 min
# SVD++: Processed 800176 (100.0%) in 1.37 sec. MSE loss 4.36E+00. Sample per second: 582469
# SVD++: Epoch 386 of 430.0. Elapsed time 6.24 min
# SVD++: Processed 800176 (100.0%) in 1.39 sec. MSE loss 4.36E+00. Sample per second: 575483
# SVD++: Epoch 387 of 430.0. Elapsed time 6.25 min
# SVD++: Processed 800176 (100.0%) in 1.40 sec. MSE loss 4.36E+00. Sample per second: 572701
# SVD++: Epoch 388 of 430.0. Elapsed time 6.27 min
# SVD++: Processed 800176 (100.0%) in 1.41 sec. MSE loss 4.34E+00. Sample per second: 566028
# SVD++: Epoch 389 of 430.0. Elapsed time 6.29 min
# SVD++: Processed 800176 (100.0%) in 1.43 sec. MSE loss 4.34E+00. Sample per second: 559509
# SVD++: Epoch 390 of 430.0. Elapsed time 6.30 min
# SVD++: Processed 800176 (100.0%) in 1.27 sec. MSE loss 4.33E+00. Sample per second: 631540
# SVD++: Epoch 391 of 430.0. Elapsed time 6.32 min
# SVD++: Processed 800176 (100.0%) in 0.96 sec. MSE loss 4.32E+00. Sample per second: 837515
# SVD++: Epoch 392 of 430.0. Elapsed time 6.33 min
# SVD++: Processed 800176 (100.0%) in 1.96 sec. MSE loss 4.31E+00. Sample per second: 407798
# SVD++: Epoch 393 of 430.0. Elapsed time 6.35 min
# SVD++: Processed 800176 (100.0%) in 1.97 sec. MSE loss 4.31E+00. Sample per second: 406438
# SVD++: Epoch 394 of 430.0. Elapsed time 6.36 min
# SVD++: Processed 800176 (100.0%) in 1.97 sec. MSE loss 4.30E+00. Sample per second: 407150
# SVD++: Epoch 395 of 430.0. Elapsed time 6.38 min
# SVD++: Processed 800176 (100.0%) in 1.96 sec. MSE loss 4.29E+00. Sample per second: 407838
# SVD++: Epoch 396 of 430.0. Elapsed time 6.40 min
# SVD++: Processed 800176 (100.0%) in 1.98 sec. MSE loss 4.28E+00. Sample per second: 404446
# SVD++: Epoch 397 of 430.0. Elapsed time 6.41 min
# SVD++: Processed 800176 (100.0%) in 2.00 sec. MSE loss 4.28E+00. Sample per second: 399535
# SVD++: Epoch 398 of 430.0. Elapsed time 6.43 min
# SVD++: Processed 800176 (100.0%) in 1.02 sec. MSE loss 4.28E+00. Sample per second: 783372
# SVD++: Epoch 399 of 430.0. Elapsed time 6.45 min
# SVD++: Processed 800176 (100.0%) in 1.05 sec. MSE loss 4.26E+00. Sample per second: 765062
# SVD++: Epoch 400 of 430.0. Elapsed time 6.46 min
# SVD++: Processed 800176 (100.0%) in 1.05 sec. MSE loss 4.26E+00. Sample per second: 760457
# SVD++: Epoch 401 of 430.0. Elapsed time 6.48 min
# SVD++: Processed 800176 (100.0%) in 0.70 sec. MSE loss 4.25E+00. Sample per second: 1139075
# SVD++: Epoch 402 of 430.0. Elapsed time 6.49 min
# SVD++: Processed 800176 (100.0%) in 1.62 sec. MSE loss 4.24E+00. Sample per second: 494063
# SVD++: Epoch 403 of 430.0. Elapsed time 6.51 min
# SVD++: Processed 800176 (100.0%) in 1.65 sec. MSE loss 4.23E+00. Sample per second: 486052
# SVD++: Epoch 404 of 430.0. Elapsed time 6.52 min
# SVD++: Processed 800176 (100.0%) in 1.67 sec. MSE loss 4.23E+00. Sample per second: 478253
# SVD++: Epoch 405 of 430.0. Elapsed time 6.54 min
# SVD++: Processed 800176 (100.0%) in 1.71 sec. MSE loss 4.22E+00. Sample per second: 468013
# SVD++: Epoch 406 of 430.0. Elapsed time 6.56 min
# SVD++: Processed 800176 (100.0%) in 1.73 sec. MSE loss 4.21E+00. Sample per second: 463460
# SVD++: Epoch 407 of 430.0. Elapsed time 6.58 min
# SVD++: Processed 800176 (100.0%) in 1.74 sec. MSE loss 4.21E+00. Sample per second: 459019
# SVD++: Epoch 408 of 430.0. Elapsed time 6.59 min
# SVD++: Processed 800176 (100.0%) in 1.75 sec. MSE loss 4.20E+00. Sample per second: 457779
# SVD++: Epoch 409 of 430.0. Elapsed time 6.61 min
# SVD++: Processed 800176 (100.0%) in 1.76 sec. MSE loss 4.19E+00. Sample per second: 455581
# SVD++: Epoch 410 of 430.0. Elapsed time 6.63 min
# SVD++: Processed 800176 (100.0%) in 1.76 sec. MSE loss 4.19E+00. Sample per second: 453834
# SVD++: Epoch 411 of 430.0. Elapsed time 6.64 min
# SVD++: Processed 800176 (100.0%) in 1.54 sec. MSE loss 4.18E+00. Sample per second: 519602
# SVD++: Epoch 412 of 430.0. Elapsed time 6.66 min
# SVD++: Processed 800176 (100.0%) in 1.31 sec. MSE loss 4.17E+00. Sample per second: 611790
# SVD++: Epoch 413 of 430.0. Elapsed time 6.67 min
# SVD++: Processed 800176 (100.0%) in 1.32 sec. MSE loss 4.17E+00. Sample per second: 604224
# SVD++: Epoch 414 of 430.0. Elapsed time 6.69 min
# SVD++: Processed 800176 (100.0%) in 1.34 sec. MSE loss 4.16E+00. Sample per second: 596795
# SVD++: Epoch 415 of 430.0. Elapsed time 6.70 min
# SVD++: Processed 800176 (100.0%) in 1.37 sec. MSE loss 4.15E+00. Sample per second: 586130
# SVD++: Epoch 416 of 430.0. Elapsed time 6.72 min
# SVD++: Processed 800176 (100.0%) in 1.38 sec. MSE loss 4.15E+00. Sample per second: 578270
# SVD++: Epoch 417 of 430.0. Elapsed time 6.74 min
# SVD++: Processed 800176 (100.0%) in 1.40 sec. MSE loss 4.14E+00. Sample per second: 571487
# SVD++: Epoch 418 of 430.0. Elapsed time 6.75 min
# SVD++: Processed 800176 (100.0%) in 1.42 sec. MSE loss 4.13E+00. Sample per second: 561609
# SVD++: Epoch 419 of 430.0. Elapsed time 6.77 min
# SVD++: Processed 800176 (100.0%) in 1.44 sec. MSE loss 4.12E+00. Sample per second: 554409
# SVD++: Epoch 420 of 430.0. Elapsed time 6.79 min
# SVD++: Processed 800176 (100.0%) in 1.45 sec. MSE loss 4.12E+00. Sample per second: 551870
# SVD++: Epoch 421 of 430.0. Elapsed time 6.80 min
# SVD++: Processed 800176 (100.0%) in 1.34 sec. MSE loss 4.11E+00. Sample per second: 595129
# SVD++: Epoch 422 of 430.0. Elapsed time 6.82 min
# SVD++: Processed 800176 (100.0%) in 0.99 sec. MSE loss 4.11E+00. Sample per second: 804952
# SVD++: Epoch 423 of 430.0. Elapsed time 6.83 min
# SVD++: Processed 800176 (100.0%) in 1.95 sec. MSE loss 4.09E+00. Sample per second: 410244
# SVD++: Epoch 424 of 430.0. Elapsed time 6.85 min
# SVD++: Processed 800176 (100.0%) in 1.97 sec. MSE loss 4.09E+00. Sample per second: 405172
# SVD++: Epoch 425 of 430.0. Elapsed time 6.86 min
# SVD++: Processed 800176 (100.0%) in 1.98 sec. MSE loss 4.08E+00. Sample per second: 403433
# SVD++: Epoch 426 of 430.0. Elapsed time 6.88 min
# SVD++: Processed 800176 (100.0%) in 2.00 sec. MSE loss 4.08E+00. Sample per second: 400146
# SVD++: Epoch 427 of 430.0. Elapsed time 6.90 min
# SVD++: Processed 800176 (100.0%) in 2.01 sec. MSE loss 4.07E+00. Sample per second: 398816
# SVD++: Epoch 428 of 430.0. Elapsed time 6.91 min
# SVD++: Processed 800176 (100.0%) in 1.02 sec. MSE loss 4.06E+00. Sample per second: 782206
# SVD++: Epoch 429 of 430.0. Elapsed time 6.93 min
# SVD++: Processed 800176 (100.0%) in 1.04 sec. MSE loss 4.06E+00. Sample per second: 769669
# SVD++: Epoch 430 of 430.0. Elapsed time 6.95 min
# SVD++: Terminating at epoch 430. Elapsed time 6.95 min
# EvaluatorHoldout: Processed 6038 (100.0%) in 5.26 sec. Users per second: 1148
#        PRECISION PRECISION_RECALL_MIN_DEN    RECALL      MAP MAP_MIN_DEN  \
# cutoff
# 10      0.176797                 0.186625  0.067832  0.10396    0.107968
#
#             MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                       ...
# 10      0.36828  0.155435  0.098046  0.675886      0.589942  ...
#
#        COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
# cutoff
# 10          0.999669          0.675662    0.999669       0.005479
#
#        SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
# cutoff
# 10            4.738564                   0.955001             0.015663
#
#        RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
# cutoff
# 10                   0.43821                 2.692208      0.060196
#
# [1 rows x 27 columns]

# %% [markdown]
# The RandomForestRegressor does not handle string data (cardinal data) so we can only use numerical columns

# %%
regr = RandomForestRegressor(max_depth=2)

result_df = save_results.results_df.copy()

numerical_cols = result_df.mean().notna()
numerical_cols = numerical_cols.index[numerical_cols]

numerical_df = result_df[numerical_cols]
numerical_df = (numerical_df - numerical_df.mean())/(numerical_df.std() +1e-6)

y_train = numerical_df["result"]
X_train = numerical_df.copy()
X_train = X_train.drop(columns=["result"])

regr.fit(X_train, y_train)

plt.bar(X_train.columns, regr.feature_importances_)
plt.show()
